# %% [markdown]
# CMOS의 NFET, PFET data의 Gaussian 함수로 구현

# %% [markdown]
# covariance 값을 조정하여 nFET와 pFET 간의 상관관계를 원하는 값으로 설정 가능. 상관관계와 공분산 관계
#
# 따라서, 주어진 correlation factor로부터 covariance 값은 다음과 같이 설정
#
# Correlation
# =$\frac{Cov}{STD:NFET*STD:pFET}$
#
# ==> Cov=$ Correlation \times STD_nFET \times STD_pFET$

# %% [markdown]
# #### Covariance Matrix
#
# NFET Ion: Mean = 600, Standard Deviation = 100
# PFET Ion: Mean = 500, Standard Deviation = 150 라 두면,<br>
#
#
# Covariance Matrix =
# \begin{equation}
#    \begin{bmatrix}
#    𝜎^2(nFET) & Cov(nFET:pFET)  \\
#    Cov(nFET:pFET) & 𝜎^2(pFET)  \\
#    \end{bmatrix}
# \end{equation}
#
# , where Cov(nFET:pFET)=$ Correlation \times 𝜎(nFET) \times 𝜎(pFET)$ <br>
# <br><br><br>
#
# 𝜎(nFET)=$100^2$=10000 <br>
# 𝜎(pFET)=$150^2$=22500 <br>
#
# Covariance Matrix =
# \begin{equation}
#    \begin{bmatrix}
#    10000 & Correlation\times100\times150   \\
#    Correlation\times100\times150 & 22500  \\
#    \end{bmatrix}
# \end{equation}
# <br><br><br>
# #### Eigen Value & Eigen Vector
# Covariance Matrix =
# \begin{equation}
#    \begin{bmatrix}
#    C_{11} & C_{12}  \\
#    C_{21} & C_{22}  \\
#    \end{bmatrix}
# \end{equation} 라 두면, <br>
# <br>
# <br>
#
# ##### [Eigen Value]
#
# Eigen-values=$λ_{1},λ_{2} $
#
# det(Σ−λI)=0 <br>
# ==> $(λ−C_{11}) \times (λ−C_{22})-C_{12} \times C_{21} = 0$ 식을 만족하는 $λ_{1},λ_{2} $ <br>
#
# <br>
# <br>
#
# ##### [Eigen Vector]
# 각각의 $λ_{1},λ_{2} $ 에 대해서
# (Σ−λI)V=0 를 만족하는 V를 찾음 (V: Eigen Vector)

# %%
from PIL import Image
import matplotlib.pyplot as plt

# Replace 'image_name.jpg' with your image file's name
image = Image.open('/content/drive/MyDrive/KITA_2024/자료DB/분산_Variance.jpg')
plt.figure(figsize=(5, 2.5))
plt.imshow(image)
plt.axis('off')  # Turn off axis numbers
plt.show()

# %%
x=np.array([-5, 2, 6, 16,21, 26])
meanx=np.mean(x)
stdx=np.std(x)
x_prime=x-x.mean()
for i in -

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import math

# 데이터 프레임 생성
DF = pd.DataFrame({
    'X': [-5, 2, 6, 16,21, 26],
    'Y': [27, 34, 26, 33, 39, 36]
})
[-15, -8, -4, 6, 11, 16]
Xmean=DF['X'].mean()
Ymean=DF['Y'].mean()
Xstd=DF['X'].std()
Ystd=DF['Y'].std()
Xvar=DF['X'].var()
Yvar=DF['Y'].var()
Cov=DF['X'].cov(DF['Y'])
Corr=DF['X'].corr(DF['Y'])

print("MEAN: ",Xmean,Ymean)
print("STD: ",Xstd,Ystd)
print("VAR: ",Xvar,Yvar)
print("COV: ",Cov)
print("Correlation: ",Corr)

CovMat = np.cov(DF['X'], DF['Y'])
print("Covariance Matrix:")
print(CovMat)

EigenValues, EigenVectors = np.linalg.eigh(CovMat)
#### Manulally 계산한 값과 정확히 일치 1/(n-1) 공식 기준
print("Eigen Values:")
print(EigenValues)
print("\nEigen Vectors:")
print(EigenVectors)

# 산점도 그리기
plt.figure(figsize=(6, 5))
sns.scatterplot(x=DF['X'], y=DF['Y'], alpha=0.3, marker='o', s=100)
plt.axhline(0, color='black', linewidth=0.8)  # y축을 0을 지나도록
plt.axvline(0, color='black', linewidth=0.8)  # x축을 0을 지나도록
# plt.xlim(-30, 30)  # x축의 범위 설정
# plt.ylim(-15, 15)  # y축의 범위 설정
# plt.xticks(np.arange(-200, 51, 50))  # x축 주요 눈금 설정
# plt.yticks(np.arange(-60, 21, 20))  # y축 주요 눈금 설정
plt.grid(True, which='both', linestyle='--', linewidth=0.3)  # 주 그리드와 보조 그리드 모두 설정
plt.minorticks_on()  # 보조 그리드 활성화
#plt.grid(True, which='major', axis='both', linestyle='-', linewidth=0.3)  # 주 그리드 설정
#plt.grid(True, which='minor', axis='both', linestyle=':', linewidth=0.2)  # 보조 그리드 설정
plt.title('Scatter Plot of X vs. Y')
plt.xlabel('X')
plt.ylabel('Y')
################################################# DATA Plot 완료

principal_component_index = np.argmax(np.abs(EigenValues))
Xmean = DF['X'].mean()
Ymean = DF['Y'].mean()

############ PLT.ARROW(X1, Y1, del_X, del_Y)
plt.arrow(Xmean, Ymean, 3 * Ystd * EigenVectors[0, 0], 3 * Ystd * EigenVectors[1, 0], color='b', width=0.1, head_width=2, head_length=2, alpha=0.7, label='Principal Component 1')
plt.arrow(Xmean, Ymean, 3 * Xstd * EigenVectors[0, 1], 3 * Xstd * EigenVectors[1, 1], color='r', width=0.1, head_width=2, head_length=2, alpha=0.7, label='Principal Component 2')

plt.legend()
plt.show()

x1, y1 = Xmean, Ymean
x2, y2 = Xmean+3 * Ystd * EigenVectors[0, 0], Ymean+3 * Ystd * EigenVectors[1, 0]
# 거리 계산
distance1 = math.dist((x1, y1), (x2, y2))
print(distance1,3 * Ystd )

x3, y3 = Xmean+3 * Xstd * EigenVectors[0, 0], Ymean+3 * Xstd * EigenVectors[1, 0]
# 거리 계산
distance2 = math.dist((x1, y1), (x3, y3))
print(distance2, 3*Xstd)
# Out:
# MEAN:  11.0 32.5
# STD:  11.933147112141038 5.089204259999788
# VAR:  142.4 25.9
# COV:  45.400000000000006
# Correlation:  0.7475684703405983
# Covariance Matrix:
# [[142.4  45.4]
#  [ 45.4  25.9]]
# Eigen Values:
# [ 10.29729186 158.00270814]
#
# Eigen Vectors:
# [[ 0.32501379 -0.94570928]
#  [-0.94570928 -0.32501379]]
# 15.267612779999366 15.267612779999364
# 35.79944133642312 35.799441336423115

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import math

# 데이터 프레임 생성
DF = pd.DataFrame({
    'X': [-15, -8, -4, 6, 11, 16],
    'Y': [-3, 4, -4, 3, 9, 6]
})

Xmean=DF['X'].mean()
Ymean=DF['Y'].mean()
Xstd=DF['X'].std()
Ystd=DF['Y'].std()
Xvar=DF['X'].var()
Yvar=DF['Y'].var()
Cov=DF['X'].cov(DF['Y'])
Corr=DF['X'].corr(DF['Y'])

print("MEAN: ",Xmean,Ymean)
print("STD: ",Xstd,Ystd)
print("VAR: ",Xvar,Yvar)
print("COV: ",Cov)
print("Correlation: ",Corr)

CovMat = np.cov(DF['X'], DF['Y'])
print("Covariance Matrix:")
print(CovMat)

EigenValues, EigenVectors = np.linalg.eigh(CovMat)
#### Manulally 계산한 값과 정확히 일치 1/(n-1) 공식 기준
print("Eigen Values:")
print(EigenValues)
print("\nEigen Vectors:")
print(EigenVectors)

# 산점도 그리기
plt.figure(figsize=(6, 5))
sns.scatterplot(x=DF['X'], y=DF['Y'], alpha=0.3, marker='o', s=100)
plt.axhline(0, color='black', linewidth=0.8)  # y축을 0을 지나도록
plt.axvline(0, color='black', linewidth=0.8)  # x축을 0을 지나도록
# plt.xlim(-30, 30)  # x축의 범위 설정
# plt.ylim(-15, 15)  # y축의 범위 설정
# plt.xticks(np.arange(-200, 51, 50))  # x축 주요 눈금 설정
# plt.yticks(np.arange(-60, 21, 20))  # y축 주요 눈금 설정
plt.grid(True, which='both', linestyle='--', linewidth=0.3)  # 주 그리드와 보조 그리드 모두 설정
plt.minorticks_on()  # 보조 그리드 활성화
#plt.grid(True, which='major', axis='both', linestyle='-', linewidth=0.3)  # 주 그리드 설정
#plt.grid(True, which='minor', axis='both', linestyle=':', linewidth=0.2)  # 보조 그리드 설정
plt.title('Scatter Plot of X vs. Y')
plt.xlabel('X')
plt.ylabel('Y')
################################################# DATA Plot 완료

principal_component_index = np.argmax(np.abs(EigenValues))
Xmean = DF['X'].mean()
Ymean = DF['Y'].mean()

plt.arrow(Xmean, Ymean, Xmean+3 * Ystd * EigenVectors[0, 0], Ymean+3 * Ystd * EigenVectors[1, 0], color='b', width=0.1, head_width=2, head_length=2, alpha=0.7, label='Principal Component 1')
plt.arrow(Xmean, Ymean, Xmean+3 * Xstd * EigenVectors[0, 1], Ymean+3 * Xstd * EigenVectors[1, 1], color='r', width=0.1, head_width=2, head_length=2, alpha=0.7, label='Principal Component 2')

plt.legend()
plt.show()

x1, y1 = Xmean, Ymean
x2, y2 = Xmean+3 * Ystd * EigenVectors[0, 0], Ymean+3 * Ystd * EigenVectors[1, 0]
# 거리 계산
distance1 = math.dist((x1, y1), (x2, y2))
print(distance1,3 * Ystd )

x3, y3 = Xmean+3 * Xstd * EigenVectors[0, 0], Ymean+3 * Xstd * EigenVectors[1, 0]
# 거리 계산
distance2 = math.dist((x1, y1), (x3, y3))
print(distance2, 3*Xstd)
# Out:
# MEAN:  1.0 2.5
# STD:  11.933147112141038 5.089204259999788
# VAR:  142.4 25.9
# COV:  45.400000000000006
# Correlation:  0.7475684703405983
# Covariance Matrix:
# [[142.4  45.4]
#  [ 45.4  25.9]]
# Eigen Values:
# [ 10.29729186 158.00270814]
#
# Eigen Vectors:
# [[ 0.32501379 -0.94570928]
#  [-0.94570928 -0.32501379]]
# 15.267612779999366 15.267612779999364
# 35.79944133642312 35.799441336423115

# %%
# Eigen Vectors:
# [[ 0.32501379 -0.94570928]
#  [-0.94570928 -0.32501379]]

result1=np.sqrt(0.32501379**2+0.94570928**2)
result2=np.sqrt(0.94570928**2+0.32501379**2)
print(result1,result2)
# Out:
# 1.0000000029841412 1.0000000029841412

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 데이터 프레임 생성
DF = pd.DataFrame({
    'X': [-15, -8, -4, 6, 11, 16],
    'Y': [-3, 4, -4, 3, 9, 6]
})

Xmean=DF['X'].mean()
Ymean=DF['Y'].mean()
Xstd=DF['X'].std()
Ystd=DF['Y'].std()
Xvar=DF['X'].var()
Yvar=DF['Y'].var()
Cov=DF['X'].cov(DF['Y'])
Corr=DF['X'].corr(DF['Y'])

print("MEAN: ",Xmean,Ymean)
print("STD: ",Xstd,Ystd)
print("VAR: ",Xvar,Yvar)
print("COV: ",Cov)
print("Correlation: ",Corr)

CovMat = np.cov(DF['X'], DF['Y'])
print("Covariance Matrix:")
print(CovMat)

EigenValues, EigenVectors = np.linalg.eigh(CovMat)
#### Manulally 계산한 값과 정확히 일치 1/(n-1) 공식 기준
print("Eigen Values:")
print(EigenValues)
print("\nEigen Vectors:")
print(EigenVectors)

# 산점도 그리기
plt.figure(figsize=(6, 5))
sns.scatterplot(x=DF['X'], y=DF['Y'], alpha=0.3, marker='o', s=100)
plt.axhline(0, color='black', linewidth=0.8)  # y축을 0을 지나도록
plt.axvline(0, color='black', linewidth=0.8)  # x축을 0을 지나도록
plt.xlim(-30, 30)  # x축의 범위 설정
plt.ylim(-15, 15)  # y축의 범위 설정
plt.xticks(np.arange(-200, 51, 50))  # x축 주요 눈금 설정
plt.yticks(np.arange(-60, 21, 20))  # y축 주요 눈금 설정
plt.grid(True, which='both', linestyle='--', linewidth=0.3)  # 주 그리드와 보조 그리드 모두 설정
plt.minorticks_on()  # 보조 그리드 활성화
#plt.grid(True, which='major', axis='both', linestyle='-', linewidth=0.3)  # 주 그리드 설정
#plt.grid(True, which='minor', axis='both', linestyle=':', linewidth=0.2)  # 보조 그리드 설정
plt.title('Scatter Plot of X vs. Y')
plt.xlabel('X')
plt.ylabel('Y')
################################################# DATA Plot 완료

principal_component_index = np.argmax(np.abs(EigenValues))
principal_component_vector = EigenVectors[:, principal_component_index]

Xmean = DF['X'].mean()
Ymean = DF['Y'].mean()
plt.arrow(Xmean, Ymean, principal_component_vector[0]*EigenValues[principal_component_index], principal_component_vector[1]*EigenValues[principal_component_index], color='red', width=0.5, head_width=2, head_length=2, alpha=0.7, label='Principal Component')

# 나머지 고유벡터 그리기
for i, v in enumerate(EigenVectors.T):
    if i != principal_component_index:
        plt.arrow(Xmean, Ymean, v[0]*EigenValues[i], v[1]*EigenValues[i], color='blue', linestyle='--',head_width=2, head_length=2, alpha=0.7, label=f'Eigenvector {i+1}')

plt.legend()

plt.show()
# Out:
# MEAN:  1.0 2.5
# STD:  11.933147112141038 5.089204259999788
# VAR:  142.4 25.9
# COV:  45.400000000000006
# Correlation:  0.7475684703405983
# Covariance Matrix:
# [[142.4  45.4]
#  [ 45.4  25.9]]
# Eigen Values:
# [ 10.29729186 158.00270814]
#
# Eigen Vectors:
# [[ 0.32501379 -0.94570928]
#  [-0.94570928 -0.32501379]]

# %%
Xmean=DF['X'].mean()
Ymean=DF['Y'].mean()
Xstd=DF['X'].std()
Ystd=DF['Y'].std()
Xvar=DF['X'].var()
Yvar=DF['Y'].var()
Cov=DF['X'].cov(DF['Y'])
Corr=DF['X'].corr(DF['Y'])

print("MEAN: ",Xmean,Ymean)
print("STD: ",Xstd,Ystd)
print("VAR: ",Xvar,Yvar)
print("COV: ",Cov)
print("Correlation: ",Corr)

CovMat = np.cov(DF['X'], DF['Y'])
print("Covariance Matrix:")
print(CovMat)

EigenValues, EigenVectors = np.linalg.eigh(CovMat)
#### Manulally 계산한 값과 정확히 일치 1/(n-1) 공식 기준
print("Eigen Values:")
print(EigenValues)
print("\nEigen Vectors:")
print(EigenVectors)

mult_vec=CovMat @ EigenVectors
mult_value=EigenValues*EigenVectors
print(f"\ncovariance_matrix @ Eigen_vector: \n {mult_vec}\n")
print(f"\nEigen_value @ Eigen_vector: \n {mult_value}\n")
# Out:
# MEAN:  1.0 2.5
# STD:  11.933147112141038 5.089204259999788
# VAR:  142.4 25.9
# COV:  45.400000000000006
# Correlation:  0.7475684703405983
# Covariance Matrix:
# [[142.4  45.4]
#  [ 45.4  25.9]]
# Eigen Values:
# [ 10.29729186 158.00270814]
#
# Eigen Vectors:
# [[ 0.32501379 -0.94570928]
#  [-0.94570928 -0.32501379]]
#
# covariance_matrix @ Eigen_vector:
#  [[   3.34676181 -149.4246271 ]
#  [  -9.73824445  -51.35305828]]
#
#
# Eigen_value @ Eigen_vector:
#  [[   3.34676181 -149.4246271 ]
#  [  -9.73824445  -51.35305828]]

# %%
print(np.sqrt(3.34676181))
print(np.sqrt(51.35305828))
print(np.sqrt(9.73824445))
print(np.sqrt(149.4246271))
# Out:
# 1.829415701802081
# 7.166104819216644
# 3.1206160369388605
# 12.223936644960167

# %%
#### Final Version
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.patches import Ellipse

np.random.seed(0)

## Group-1
# CMOS Characteristics On-Currents
# Only Random Components
NFET_Ion_1 = np.random.randn(100000) * 100 + 600
PFET_Ion_1 = np.random.randn(100000) * 150 + 500


## Group-2
# Implementing Systematic Variation Components Using Co-Variance
# 평균 및 표준편차
mean = [600, 500]     # Mean values of nFET and pFET
std_dev = [100, 150]  # Standard Deviations of nFET and pFET
correlation = 0.5  # 원하는 상관관계
covariance = correlation * std_dev[0] * std_dev[1]
cov_matrix = [[std_dev[0]**2, covariance], [covariance, std_dev[1]**2]]
# 다변량 정규 분포에서 샘플 생성
FET_Ion = np.random.multivariate_normal(mean, cov_matrix, size=100000)

## Group-3
random_nFET = np.random.randn(100000)  # Un-Correlated
random_pFET = np.random.randn(100000)  # Un-Correlated
systematic_variation = np.random.randn(100000)  # Systematic Variation

NFET_Ion_3 = (random_nFET + systematic_variation)*100 + 600
PFET_Ion_3 = (random_pFET + systematic_variation)*150 + 500


# Group-4 with specified correlation coefficient
# Generate uncorrelated random variables

mean4 = [600, 500]     # Mean values of nFET and pFET
std_dev4 = [100, 150]  # Standard Deviations of nFET and pFET
random_nFET4 = np.random.randn(100000)
random_pFET4 = np.random.randn(100000)

# Introduce correlation
correlation4 = 0.5
random_pFET4 = correlation4 * random_nFET4 + np.sqrt(1 - correlation4**2) * random_pFET4
# Systematic variation
systematic_variation4 = np.random.randn(100000)

# Create final variables with specified means and std deviations
NFET_Ion_4 = (random_nFET4 * std_dev4[0] + mean4[0]) + systematic_variation4
PFET_Ion_4 = (random_pFET4 * std_dev4[1] + mean4[1]) + systematic_variation4

DF_CMOS = pd.DataFrame({
    'nFET-1': NFET_Ion_1, 'pFET-1': PFET_Ion_1,
    'nFET-2': FET_Ion[:,0], 'pFET-2': FET_Ion[:,1],
    'nFET-3': NFET_Ion_3, 'pFET-3': PFET_Ion_3,
    'nFET-4': NFET_Ion_4, 'pFET-4': PFET_Ion_4
})

# Scatter plot 생성
fig, axes = plt.subplots(2, 2, figsize=(10, 7))

# 첫 번째 subplot
ax1 = axes[0,0]
sns.scatterplot(x=DF_CMOS['nFET-1'], y=DF_CMOS['pFET-1'], alpha=0.1, color='c', label='Group-1', ax=ax1, s=5)
ax1.set_title('CMOS Ion Distribution n-/p-FET Correlation')
ax1.set_xlabel("nFET's Ion")
ax1.set_ylabel("pFET's Ion")
ax1.legend()

# 두 번째 subplot
ax2 = axes[0,1]
sns.scatterplot(x=DF_CMOS['nFET-2'], y=DF_CMOS['pFET-2'], alpha=0.1, color='b', label='Group-2', ax=ax2, s=5)
ax2.set_title('CMOS Ion Distribution n-/p-FET Correlation')
ax2.set_xlabel("nFET's Ion")
ax2.set_ylabel("pFET's Ion")
ax2.legend()

# 세 번째 subplot
ax3 = axes[1,0]
sns.scatterplot(x=DF_CMOS['nFET-3'], y=DF_CMOS['pFET-3'], alpha=0.1, color='m', label='Group-3', ax=ax3, s=5)
ax3.set_title('CMOS Ion Distribution n-/p-FET Correlation')
ax3.set_xlabel("nFET's Ion")
ax3.set_ylabel("pFET's Ion")
ax3.legend()

# 네 번째 subplot
ax4 = axes[1,1]
sns.scatterplot(x=DF_CMOS['nFET-4'], y=DF_CMOS['pFET-4'], alpha=0.1, color='g', label='Group-4', ax=ax4, s=5)
ax4.set_title('CMOS Ion Distribution n-/p-FET Correlation')
ax4.set_xlabel("nFET's Ion")
ax4.set_ylabel("pFET's Ion")
ax4.legend()

# Median 및 Mean 계산
median_1 = DF_CMOS['nFET-1'].median(), DF_CMOS['pFET-1'].median()
median_2 = DF_CMOS['nFET-2'].median(), DF_CMOS['pFET-2'].median()
median_3 = DF_CMOS['nFET-3'].median(), DF_CMOS['pFET-3'].median()
median_4 = DF_CMOS['nFET-4'].median(), DF_CMOS['pFET-4'].median()

mean_1 = DF_CMOS['nFET-1'].mean(), DF_CMOS['pFET-1'].mean()
mean_2 = DF_CMOS['nFET-2'].mean(), DF_CMOS['pFET-2'].mean()
mean_3 = DF_CMOS['nFET-3'].mean(), DF_CMOS['pFET-3'].mean()
mean_4 = DF_CMOS['nFET-4'].mean(), DF_CMOS['pFET-4'].mean()

sigma3_1 = 3*DF_CMOS['nFET-1'].std(), 3*DF_CMOS['pFET-1'].std()
sigma3_2 = 3*DF_CMOS['nFET-2'].std(), 3*DF_CMOS['pFET-2'].std()
sigma3_3 = 3*DF_CMOS['nFET-3'].std(), 3*DF_CMOS['pFET-3'].std()
sigma3_4 = 3*DF_CMOS['nFET-4'].std(), 3*DF_CMOS['pFET-4'].std()

# Deviation Contour Plot
def plot_3sigma(ax, mean, cov, sigma3, color):
    eigenvalues, eigenvectors = np.linalg.eigh(cov)
    order = eigenvalues.argsort()[::-1]
    eigenvalues = eigenvalues[order]
    eigenvectors = eigenvectors[:, order]  # eigenvectors의 순서를 변경
    scaling_factor=2.3
    std_deviation = np.sqrt(eigenvalues) * 3

    ### Corner Points
    FF = (mean[0] + sigma3[0], mean[1] + sigma3[1])
    SS = (mean[0] - sigma3[0], mean[1] - sigma3[1])
    FSE = (mean[0] + sigma3[0], mean[1] - sigma3[1])
    FS = (mean[0] + scaling_factor/3*sigma3[0], mean[1] - scaling_factor/3*sigma3[1])
    # FS = mean - 2.5 * std_deviation[0] * eigenvectors[:, 1]

    SFE = (mean[0] - sigma3[0], mean[1] + sigma3[1])
    SF = (mean[0] - scaling_factor/3*sigma3[0], mean[1] + scaling_factor/3*sigma3[1])
    # SF = mean + 2.5 * std_deviation[0] * eigenvectors[:, 1]

    NN = (mean[0], mean[1])

    ellipse = Ellipse(xy=mean, width=std_deviation[0] * 2, height=std_deviation[1] * 2,
                      angle=np.degrees(np.arctan2(*eigenvectors[:, 0][::-1])),
                      edgecolor=color, fc='None', lw=1, linestyle='--')
    ax.add_patch(ellipse)

    # NN, FF, SS, FS, SF Corner Points Plot
    ax.plot(FF[0], FF[1], 'o', color='red')
    ax.text(FF[0], FF[1], 'FF', fontsize=12, ha='right', va='bottom')

    ax.plot(SS[0], SS[1], 'o', color='blue')
    ax.text(SS[0], SS[1], 'SS', fontsize=12, ha='right', va='top')

    ax.plot(FS[0], FS[1], 'o', color='green')
    ax.text(FS[0], FS[1], 'FS', fontsize=12, ha='right', va='top')

    ax.plot(FSE[0], FSE[1], 'o', color='green')
    ax.text(FSE[0], FSE[1], 'FSE', fontsize=12, ha='right', va='top')

    ax.plot(SF[0], SF[1], 'o', color='purple')
    ax.text(SF[0], SF[1], 'SF', fontsize=12, ha='left', va='bottom')

    ax.plot(SFE[0], SFE[1], 'o', color='purple')
    ax.text(SFE[0], SFE[1], 'SFE', fontsize=12, ha='left', va='bottom')

    # Nominal Corner Plot
    ax.plot(NN[0], NN[1], 'o', color='black')
    ax.text(NN[0], NN[1], 'NN', fontsize=12, ha='right', va='bottom')

    # Corner Box Plot
    rect_x = [FF[0], SFE[0], SS[0], FSE[0], FF[0]]
    rect_y = [FF[1], SFE[1], SS[1], FSE[1], FF[1]]
    ax.plot(rect_x, rect_y, linestyle='--', color='gray', linewidth=0.4)

    # Plot eigen-vector lines
    ax.plot([mean[0], SFE[0]], [mean[1], SFE[1]], color='k', linestyle='--', linewidth=0.2)
    ax.plot([mean[0], FSE[0]], [mean[1], FSE[1]], color='k', linestyle='--', linewidth=0.2)
    ax.plot([mean[0], FF[0]], [mean[1], FF[1]], color='k', linestyle='--', linewidth=0.2)
    ax.plot([mean[0], SS[0]], [mean[1], SS[1]], color='k', linestyle='--', linewidth=0.2)


# 3시그마 범위 계산 및 그리기
cov_1 = np.cov(DF_CMOS[['nFET-1', 'pFET-1']], rowvar=False)
cov_2 = np.cov(DF_CMOS[['nFET-2', 'pFET-2']], rowvar=False)
cov_3 = np.cov(DF_CMOS[['nFET-3', 'pFET-3']], rowvar=False)
cov_4 = np.cov(DF_CMOS[['nFET-4', 'pFET-4']], rowvar=False)

plot_3sigma(ax1, mean_1, cov_1, sigma3_1, 'c')  # 첫 번째 subplot에 타원 그리기
plot_3sigma(ax2, mean_2, cov_2, sigma3_2, 'b')  # 두 번째 subplot에 타원 그리기
plot_3sigma(ax3, mean_3, cov_3, sigma3_3, 'm')  # 세 번째 subplot에 타원 그리기
plot_3sigma(ax4, mean_4, cov_4, sigma3_4, 'b')  # 네 번째 subplot에 타원 그리기

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters
mean = [600, 500]     # Mean values of nFET and pFET
std_dev = [100, 150]  # Standard Deviations of nFET and pFET
correlation = -0.5    # Desired correlation coefficient

# Generate uncorrelated random variables
random_nFET = np.random.randn(100000)
random_pFET = np.random.randn(100000)

# Introduce correlation
random_pFET = correlation * random_nFET + np.sqrt(1 - correlation**2) * random_pFET

# Systematic variation
systematic_variation = np.random.randn(100000)

# Create final variables with specified means and std deviations
NFET_Ion_4 = (random_nFET * std_dev[0] + mean[0]) + systematic_variation
PFET_Ion_4 = (random_pFET * std_dev[1] + mean[1]) + systematic_variation

# Scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(NFET_Ion_3, PFET_Ion_3, alpha=0.3, marker='o', s=5)
plt.title('Scatter Plot of nFET vs. pFET')
plt.xlabel('nFET Ion')
plt.ylabel('pFET Ion')
plt.grid(True)
plt.show()

# %% [markdown]
# random한 nFET 데이터를 생성
# 이 데이터를 이용하여 원하는 correlation coefficient (여기서는 0.3)를 갖는 pFET 데이터를 생성
# systematic variation을 더해주고, 각각의 평균과 표준편차를 곱하여 최종적으로 NFET_Ion_3과 PFET_Ion_3를 생성
# 이 데이터를 시각화하고, 3 시그마 범위의 타원 생성

# %%
from PIL import Image
import matplotlib.pyplot as plt

# 이미지 파일 경로 설정
image_path1 = '/content/drive/MyDrive/KITA_2024/자료DB/System_Random01.png'
image_path2 = '/content/drive/MyDrive/KITA_2024/자료DB/System_Random02.png'
image_path3 = '/content/drive/MyDrive/KITA_2024/자료DB/System_Random03.png'

# 이미지 불러오기
image1 = Image.open(image_path1)
image2 = Image.open(image_path2)
image3 = Image.open(image_path3)

# subplot 생성
fig, axes = plt.subplots(3, 1, figsize=(8, 15))

# 첫 번째 subplot에 이미지 표시
axes[0].imshow(image1)
axes[0].axis('off')
axes[0].set_title('Image 1')

# 두 번째 subplot에 이미지 표시
axes[1].imshow(image2)
axes[1].axis('off')
axes[1].set_title('Image 2')

# 세 번째 subplot에 이미지 표시
axes[2].imshow(image3)
axes[2].axis('off')
axes[2].set_title('Image 3')

# subplot 간의 간격 조정 및 출력
plt.tight_layout()
plt.show()

# %%
import numpy as np
import pandas as pd

np.random.seed(0)
################# CMOS Characteristics On-Currents
NFET_Ion_1=np.random.normal(loc=600, scale=100, size=100000)
PFET_Ion_1=np.random.normal(loc=500, scale=150, size=100000)

################# CMOS Characteristics On-Currents (randn)
NFET_Ion_2=np.random.randn(100000)*100+600
PFET_Ion_2=np.random.randn(100000)*150+500

DF_CMOS = pd.DataFrame({
    'nFET-1': NFET_Ion_1, 'pFET-1': PFET_Ion_1,
    'nFET-2' : NFET_Ion_2, 'pFET-2': PFET_Ion_2
})

# %%
DF_CMOS.head()
# Out:
#        nFET-1      pFET-1      nFET-2      pFET-2
# 0  776.405235  427.430376  603.950990  740.860566
# 1  640.015721  693.208560  633.837761  335.793549
# 2  697.873798  480.518193  515.781681  688.755836
# 3  824.089320  470.288242  595.036772  718.713608
# 4  786.755799  449.826861  476.975464  456.169520

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.patches import Ellipse

np.random.seed(0)

# CMOS Characteristics On-Currents
################# CMOS Characteristics On-Currents
NFET_Ion_1=np.random.normal(loc=600, scale=100, size=100000)
PFET_Ion_1=np.random.normal(loc=500, scale=150, size=100000)

################# CMOS Characteristics On-Currents (randn)
NFET_Ion_2=np.random.randn(100000)*100+600
PFET_Ion_2=np.random.randn(100000)*150+500

DF_CMOS = pd.DataFrame({
    'nFET-1': NFET_Ion_1, 'pFET-1': PFET_Ion_1,
    'nFET-2': NFET_Ion_2, 'pFET-2': PFET_Ion_2
})

# Scatter plot 생성
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# 첫 번째 subplot
ax1 = axes[0]
sns.scatterplot(x=DF_CMOS['nFET-1'], y=DF_CMOS['pFET-1'], alpha=0.1, color='c', label='Group-1', ax=ax1)
ax1.set_title('CMOS Ion Distribution n-/p-FET Correlation')
ax1.set_xlabel("nFET's Ion")
ax1.set_ylabel("pFET's Ion")
ax1.legend()

# 두 번째 subplot
ax2 = axes[1]
sns.scatterplot(x=DF_CMOS['nFET-2'], y=DF_CMOS['pFET-2'], alpha=0.1, color='b', label='Group-2', ax=ax2)
ax2.set_title('CMOS Ion Distribution n-/p-FET Correlation')
ax2.set_xlabel("nFET's Ion")
ax2.set_ylabel("pFET's Ion")
ax2.legend()

# Median 및 Mean 계산
median_1 = DF_CMOS['nFET-1'].median(), DF_CMOS['pFET-1'].median()
median_2 = DF_CMOS['nFET-2'].median(), DF_CMOS['pFET-2'].median()

mean_1 = DF_CMOS['nFET-1'].mean(), DF_CMOS['pFET-1'].mean()
mean_2 = DF_CMOS['nFET-2'].mean(), DF_CMOS['pFET-2'].mean()

sigma3_1 = 3*DF_CMOS['nFET-1'].std(), 3*DF_CMOS['pFET-1'].std()
sigma3_2 = 3*DF_CMOS['nFET-2'].std(), 3*DF_CMOS['pFET-2'].std()

# Deviation Contour Plot
def plot_3sigma(ax, mean, cov, sigma3, color):
    eigenvalues, eigenvectors = np.linalg.eigh(cov)
    order = eigenvalues.argsort()[::-1]
    eigenvalues = eigenvalues[order]
    eigenvectors = eigenvectors[:, order]  # eigenvectors의 순서를 변경

    std_deviation = np.sqrt(eigenvalues) * 3

    ### Corner Points
    FF = (mean[0] + sigma3[0], mean[1] + sigma3[1])
    SS = (mean[0] - sigma3[0], mean[1] - sigma3[1])
    FS = (mean[0] + sigma3[0], mean[1] - sigma3[1])
    SF = (mean[0] - sigma3[0], mean[1] + sigma3[1])
    NN = (mean[0], mean[1])

    ellipse = Ellipse(xy=mean, width=std_deviation[0] * 2, height=std_deviation[1] * 2,
                      angle=np.degrees(np.arctan2(*eigenvectors[:, 0][::-1])),
                      edgecolor=color, fc='None', lw=1, linestyle='--')
    ax.add_patch(ellipse)

    # NN, FF, SS, FS, SF Corner Points Plot
    ax.plot(FF[0], FF[1], 'o', color='red')
    ax.text(FF[0], FF[1], 'FF', fontsize=12, ha='right', va='bottom')

    ax.plot(SS[0], SS[1], 'o', color='blue')
    ax.text(SS[0], SS[1], 'SS', fontsize=12, ha='right', va='top')

    ax.plot(FS[0], FS[1], 'o', color='green')
    ax.text(FS[0], FS[1], 'FS', fontsize=12, ha='left', va='top')

    ax.plot(SF[0], SF[1], 'o', color='purple')
    ax.text(SF[0], SF[1], 'SF', fontsize=12, ha='left', va='bottom')

    # Nominal Corner Plot
    ax.plot(NN[0], NN[1], 'o', color='black')
    ax.text(NN[0], NN[1], 'NN', fontsize=12, ha='right', va='bottom')

    # Corner Box Plot
    rect_x = [FF[0], SF[0], SS[0], FS[0], FF[0]]
    rect_y = [FF[1], SF[1], SS[1], FS[1], FF[1]]
    ax.plot(rect_x, rect_y, linestyle='--', color='gray')

# 3시그마 범위 계산 및 그리기
cov_1 = np.cov(DF_CMOS[['nFET-1', 'pFET-1']], rowvar=False)
cov_2 = np.cov(DF_CMOS[['nFET-2', 'pFET-2']], rowvar=False)


plot_3sigma(ax1, mean_1, cov_1, sigma3_1, 'red')  # 첫 번째 subplot에 타원 그리기
plot_3sigma(ax2, mean_2, cov_2, sigma3_2, 'green')  # 두 번째 subplot에 타원 그리기

plt.tight_layout()
plt.show()

# %%
##### 잘못된 구현

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.patches import Ellipse

np.random.seed(0)

## Group-1
# CMOS Characteristics On-Currents
# Only Random Components
NFET_Ion_1 = np.random.randn(100000) * 100 + 600
PFET_Ion_1 = np.random.randn(100000) * 150 + 500


## Group-2
# Implementing Systematic Variation Components Using Co-Variance
# 평균 및 표준편차
mean = [600, 500]     # Mean values of nFET and pFET
std_dev = [100, 150]  # Standard Deviations of nFET and pFET
correlation = -0.5  # 원하는 상관관계
covariance = correlation * std_dev[0] * std_dev[1]
cov_matrix = [[std_dev[0]**2, covariance], [covariance, std_dev[1]**2]]
# 다변량 정규 분포에서 샘플 생성
FET_Ion = np.random.multivariate_normal(mean, cov_matrix, size=100000)

## Group-3
random_nFET = np.random.randn(100000)  # Un-Correlated
random_pFET = np.random.randn(100000)  # Un-Correlated
systematic_variation = np.random.randn(100000)  # Systematic Variation

NFET_Ion_3 = (random_nFET + systematic_variation)*100 + 600
PFET_Ion_3 = (random_pFET + systematic_variation)*150 + 500


## Group-4
## Variation Characteristics with specified correlation coefficient
mean_nFET = 600; mean_pFET = 500; std_dev_nFET = 100; std_dev_pFET = 150

# Define correlation coefficient
correlation_coefficient = -0.5

# Generate correlated random_pFET
random_nFET = np.random.randn(100000)  # Un-Correlated

##### 잘못된 부분
random_pFET = correlation_coefficient * random_nFET + np.sqrt(1 - correlation_coefficient**2) * np.random.randn(100000)
##### 잘못된 부분


systematic_variation = np.random.randn(100000)  # Systematic Variation

# Create NFET_Ion_4 and PFET_Ion_4 with correlation
NFET_Ion_4 = (random_nFET + systematic_variation) * std_dev_nFET + mean_nFET
PFET_Ion_4 = (random_pFET + systematic_variation) * std_dev_pFET + mean_pFET

DF_CMOS = pd.DataFrame({
    'nFET-1': NFET_Ion_1, 'pFET-1': PFET_Ion_1,
    'nFET-2': FET_Ion[:,0], 'pFET-2': FET_Ion[:,1],
    'nFET-3': NFET_Ion_3, 'pFET-3': PFET_Ion_3,
    'nFET-4': NFET_Ion_4, 'pFET-4': PFET_Ion_4
})

# Scatter plot 생성
fig, axes = plt.subplots(2, 2, figsize=(10, 7))

# 첫 번째 subplot
ax1 = axes[0,0]
sns.scatterplot(x=DF_CMOS['nFET-1'], y=DF_CMOS['pFET-1'], alpha=0.1, color='c', label='Group-1', ax=ax1)
ax1.set_title('CMOS Ion Distribution n-/p-FET Correlation')
ax1.set_xlabel("nFET's Ion")
ax1.set_ylabel("pFET's Ion")
ax1.legend()

# 두 번째 subplot
ax2 = axes[0,1]
sns.scatterplot(x=DF_CMOS['nFET-2'], y=DF_CMOS['pFET-2'], alpha=0.1, color='b', label='Group-2', ax=ax2)
ax2.set_title('CMOS Ion Distribution n-/p-FET Correlation')
ax2.set_xlabel("nFET's Ion")
ax2.set_ylabel("pFET's Ion")
ax2.legend()

# 세 번째 subplot
ax3 = axes[1,0]
sns.scatterplot(x=DF_CMOS['nFET-3'], y=DF_CMOS['pFET-3'], alpha=0.1, color='m', label='Group-3', ax=ax3)
ax3.set_title('CMOS Ion Distribution n-/p-FET Correlation')
ax3.set_xlabel("nFET's Ion")
ax3.set_ylabel("pFET's Ion")
ax3.legend()

# 네 번째 subplot
ax4 = axes[1,1]
sns.scatterplot(x=DF_CMOS['nFET-4'], y=DF_CMOS['pFET-4'], alpha=0.1, color='g', label='Group-4', ax=ax4)
ax4.set_title('CMOS Ion Distribution n-/p-FET Correlation')
ax4.set_xlabel("nFET's Ion")
ax4.set_ylabel("pFET's Ion")
ax4.legend()

# Median 및 Mean 계산
median_1 = DF_CMOS['nFET-1'].median(), DF_CMOS['pFET-1'].median()
median_2 = DF_CMOS['nFET-2'].median(), DF_CMOS['pFET-2'].median()
median_3 = DF_CMOS['nFET-3'].median(), DF_CMOS['pFET-3'].median()
median_4 = DF_CMOS['nFET-4'].median(), DF_CMOS['pFET-4'].median()

mean_1 = DF_CMOS['nFET-1'].mean(), DF_CMOS['pFET-1'].mean()
mean_2 = DF_CMOS['nFET-2'].mean(), DF_CMOS['pFET-2'].mean()
mean_3 = DF_CMOS['nFET-3'].mean(), DF_CMOS['pFET-3'].mean()
mean_4 = DF_CMOS['nFET-4'].mean(), DF_CMOS['pFET-4'].mean()

sigma3_1 = 3*DF_CMOS['nFET-1'].std(), 3*DF_CMOS['pFET-1'].std()
sigma3_2 = 3*DF_CMOS['nFET-2'].std(), 3*DF_CMOS['pFET-2'].std()
sigma3_3 = 3*DF_CMOS['nFET-3'].std(), 3*DF_CMOS['pFET-3'].std()
sigma3_4 = 3*DF_CMOS['nFET-4'].std(), 3*DF_CMOS['pFET-4'].std()

# Deviation Contour Plot
def plot_3sigma(ax, mean, cov, sigma3, color):
    eigenvalues, eigenvectors = np.linalg.eigh(cov)
    order = eigenvalues.argsort()[::-1]
    eigenvalues = eigenvalues[order]
    eigenvectors = eigenvectors[:, order]  # eigenvectors의 순서를 변경

    std_deviation = np.sqrt(eigenvalues) * 3

    ### Corner Points
    FF = (mean[0] + sigma3[0], mean[1] + sigma3[1])
    SS = (mean[0] - sigma3[0], mean[1] - sigma3[1])
    FS = (mean[0] + sigma3[0], mean[1] - sigma3[1])
    SF = (mean[0] - sigma3[0], mean[1] + sigma3[1])
    NN = (mean[0], mean[1])

    ellipse = Ellipse(xy=mean, width=std_deviation[0] * 2, height=std_deviation[1] * 2,
                      angle=np.degrees(np.arctan2(*eigenvectors[:, 0][::-1])),
                      edgecolor=color, fc='None', lw=1, linestyle='--')
    ax.add_patch(ellipse)

    # NN, FF, SS, FS, SF Corner Points Plot
    ax.plot(FF[0], FF[1], 'o', color='red')
    ax.text(FF[0], FF[1], 'FF', fontsize=12, ha='right', va='bottom')

    ax.plot(SS[0], SS[1], 'o', color='blue')
    ax.text(SS[0], SS[1], 'SS', fontsize=12, ha='right', va='top')

    ax.plot(FS[0], FS[1], 'o', color='green')
    ax.text(FS[0], FS[1], 'FS', fontsize=12, ha='left', va='top')

    ax.plot(SF[0], SF[1], 'o', color='purple')
    ax.text(SF[0], SF[1], 'SF', fontsize=12, ha='left', va='bottom')

    # Nominal Corner Plot
    ax.plot(NN[0], NN[1], 'o', color='black')
    ax.text(NN[0], NN[1], 'NN', fontsize=12, ha='right', va='bottom')

    # Corner Box Plot
    rect_x = [FF[0], SF[0], SS[0], FS[0], FF[0]]
    rect_y = [FF[1], SF[1], SS[1], FS[1], FF[1]]
    ax.plot(rect_x, rect_y, linestyle='--', color='gray')

# 3시그마 범위 계산 및 그리기
cov_1 = np.cov(DF_CMOS[['nFET-1', 'pFET-1']], rowvar=False)
cov_2 = np.cov(DF_CMOS[['nFET-2', 'pFET-2']], rowvar=False)
cov_3 = np.cov(DF_CMOS[['nFET-3', 'pFET-3']], rowvar=False)
cov_4 = np.cov(DF_CMOS[['nFET-4', 'pFET-4']], rowvar=False)

plot_3sigma(ax1, mean_1, cov_1, sigma3_1, 'red')  # 첫 번째 subplot에 타원 그리기
plot_3sigma(ax2, mean_2, cov_2, sigma3_2, 'green')  # 두 번째 subplot에 타원 그리기
plot_3sigma(ax3, mean_3, cov_3, sigma3_3, 'b')  # 세 번째 subplot에 타원 그리기
plot_3sigma(ax4, mean_4, cov_4, sigma3_4, 'b')  # 네 번째 subplot에 타원 그리기

plt.tight_layout()
plt.show()

# %%
import numpy as np
import pandas as pd
from scipy.stats import gaussian_kde
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.patches import Ellipse

np.random.seed(0)
################# CMOS Characteristics On-Currents
NFET_Ion_1=np.random.normal(loc=600, scale=100, size=100000)
PFET_Ion_1=np.random.normal(loc=500, scale=150, size=100000)

################# CMOS Characteristics On-Currents (randn)
NFET_Ion_2=np.random.randn(100000)*100+600
PFET_Ion_2=np.random.randn(100000)*150+500

DF_CMOS = pd.DataFrame({
    'nFET-1': NFET_Ion_1, 'pFET-1': PFET_Ion_1,
    'nFET-2' : NFET_Ion_2, 'pFET-2': PFET_Ion_2
})

# Scatter plot 생성
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
ax1 = plt.gca()  # 첫 번째 subplot의 축 가져오기
sns.scatterplot(x=DF_CMOS['nFET-1'] , y=DF_CMOS['pFET-1'], alpha=0.1, color='c', label='Group-1')
plt.title('CMOS Ion Distribution n-/p-FET Correlation')
plt.xlabel("nFET's Ion")
plt.ylabel("pFET's Ion")
plt.legend()

plt.subplot(1, 2, 2)
ax2 = plt.gca()  # 첫 번째 subplot의 축 가져오기
sns.scatterplot(x=DF_CMOS['nFET-2'] , y=DF_CMOS['pFET-2'], alpha=0.1, color='b', label='Group-2')
plt.title('CMOS Ion Distribution n-/p-FET Correlation')
plt.xlabel("nFET's Ion")
plt.ylabel("pFET's Ion")
plt.legend()

# Median 및 Mean 계산
median_1 = DF_CMOS['nFET-1'].median(), DF_CMOS['pFET-1'].median()
median_2 = DF_CMOS['nFET-2'].median(), DF_CMOS['pFET-2'].median()

mean_1 = DF_CMOS['nFET-1'].mean(), DF_CMOS['pFET-1'].mean()
mean_2 = DF_CMOS['nFET-2'].mean(), DF_CMOS['pFET-2'].mean()

# 3시그마 범위에 해당하는 타원 그리기
def plot_3sigma(ax, mean, cov, color):
    sigma_x = np.sqrt(cov[0, 0])
    sigma_y = np.sqrt(cov[1, 1])
    sigma_xy = cov[0, 1]

    theta = np.arctan2(2 * sigma_xy, (sigma_x**2 - sigma_y**2)) / 2

    width = 2 * np.sqrt(2 * np.log(2) * (sigma_x**2 + sigma_y**2 +
                                         np.sqrt((sigma_x**2 - sigma_y**2)**2 + (2*sigma_xy)**2)))
    height = 2 * np.sqrt(2 * np.log(2) * (sigma_x**2 + sigma_y**2 -
                                          np.sqrt((sigma_x**2 - sigma_y**2)**2 + (2*sigma_xy)**2)))
    ellipse = Ellipse(xy=mean, width=width, height=height, angle=np.degrees(theta),
                      edgecolor=color, fc='None', lw=2)
    ax.add_patch(ellipse)

# 3시그마 범위 계산 및 그리기
cov_1 = np.cov(DF_CMOS[['nFET-1', 'pFET-1']], rowvar=False)
cov_2 = np.cov(DF_CMOS[['nFET-2', 'pFET-2']], rowvar=False)

plot_3sigma(ax1, mean_1, cov_1, 'red')  # 첫 번째 subplot에 타원 그리기
plot_3sigma(ax2, mean_2, cov_2, 'green') # 두 번째 subplot에 타원 그리기

plt.tight_layout()
plt.show()

# %% [markdown]
# plot_3sigma 함수 정의: <br>
#
# 이 함수는 타원을 그리는데 사용 <br>
# 함수는 네 개의 매개변수를 가짐: <br>
# ax: 타원을 그릴 서브플롯의 축 <br>
# mean: 타원의 중심 좌표. <br>
# cov: 공분산 행렬. <br>
# color: 타원의 선 색상. <br>
# 함수 내에서는 다음을 수행: <br>
# np.linalg.eigh(cov)를 사용하여 공분산 행렬의 고유값과 고유벡터를 계산 <br>
# 고유값을 크기순으로 정렬. <br>
# 고유값에 3을 곱한 후, 해당 값을 표준편차로 사용하여 타원의 크기를 계산. <br>
# Ellipse 객체를 생성하여 타원을 그림 <br>
# cov_1 및 cov_2 계산: <br>
#
# np.cov 함수를 사용하여 각각의 CMOS 특성 변수에 대한 공분산 행렬을 계산 <br>
# plot_3sigma 함수 호출: <br>
#
# 각 서브플롯에 대해 plot_3sigma 함수를 호출하여 3시그마 범위의 타원을 그림 <br>
# 각 호출에서는 각각의 subplot의 축 ax1 및 ax2, 해당 subplot의 특성 변수에 대한 평균값 mean_1 및 mean_2, 그리고 공분산 행렬 cov_1 및 cov_2가 전달 <br>
# 두 개의 subplot에 대해 각각 다른 색상으로 타원이 그려짐. <br>

# %% [markdown]
# 일반적으로 표준형태의 타원의 방정식:
# (x - h)^2 / a^2 + (y - k)^2 / b^2 = 1
#
# (h,k)는 타원의 중심점이고, <br>
# 𝑎: x-축 방향의 반축길이(타원의 가로 반지름), <br>
# 𝑏: y-축 방향의 반축길이(타원의 세로 반지름) <br>
# 이렇게 표현된 타원의 방정식에서 𝑎와 𝑏가 같으면, 타원은 원. <br>
#
# 이러한 표준형태의 타원 방정식에서 𝑎와 𝑏는 타원의 크기와 형태를 결정하며, (ℎ,𝑘)는 타원의 위치를 나타냄 <br>

# %%
DF_CMOS.head()
# Out:
#        nFET-1      pFET-1      nFET-2      pFET-2
# 0  776.405235  427.430376  603.950990  740.860566
# 1  640.015721  693.208560  633.837761  335.793549
# 2  697.873798  480.518193  515.781681  688.755836
# 3  824.089320  470.288242  595.036772  718.713608
# 4  786.755799  449.826861  476.975464  456.169520

# %%
# 그래프 생성
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# 3-sigma boundary 계산
nfet1_mean, nfet1_std = DF_CMOS['nFET-1'].mean(), DF_CMOS['nFET-1'].std()
pfet1_mean, pfet1_std = DF_CMOS['pFET-1'].mean(), DF_CMOS['pFET-1'].std()
nfet2_mean, nfet2_std = DF_CMOS['nFET-2'].mean(), DF_CMOS['nFET-2'].std()
pfet2_mean, pfet2_std = DF_CMOS['pFET-2'].mean(), DF_CMOS['pFET-2'].std()

nfet1_upper, nfet1_lower = nfet1_mean + 3 * nfet1_std, nfet1_mean - 3 * nfet1_std
pfet1_upper, pfet1_lower = pfet1_mean + 3 * pfet1_std, pfet1_mean - 3 * pfet1_std
nfet2_upper, nfet2_lower = nfet2_mean + 3 * nfet2_std, nfet2_mean - 3 * nfet2_std
pfet2_upper, pfet2_lower = pfet2_mean + 3 * pfet2_std, pfet2_mean - 3 * pfet2_std

# subplot 1
#sns.kdeplot(data=DF_CMOS, x='nFET-1', y='pFET-1', ax=axes[0], fill=True)
axes[0].axvline(nfet1_upper, color='r', linestyle='--', linewidth=1)
axes[0].axvline(nfet1_lower, color='r', linestyle='--', linewidth=1)
axes[0].axhline(pfet1_upper, color='r', linestyle='--', linewidth=1)
axes[0].axhline(pfet1_lower, color='r', linestyle='--', linewidth=1)
axes[0].set_title('nFET-1 vs pFET-1')

# subplot 2
#sns.kdeplot(data=DF_CMOS, x='nFET-2', y='pFET-2', ax=axes[1], fill=True)
axes[1].axvline(nfet2_upper, color='r', linestyle='--', linewidth=1)
axes[1].axvline(nfet2_lower, color='r', linestyle='--', linewidth=1)
axes[1].axhline(pfet2_upper, color='r', linestyle='--', linewidth=1)
axes[1].axhline(pfet2_lower, color='r', linestyle='--', linewidth=1)
axes[1].set_title('nFET-2 vs pFET-2')

plt.tight_layout()
plt.show()

# %%
############################################################################################## sns.kdeplot의 예제

import pandas as pd
from scipy.stats import gaussian_kde
import matplotlib.pyplot as plt
import seaborn as sns

# 예제 데이터 생성
data = {
    'nFET-1': [1, 2, 3, 4, 5],
    'pFET-1': [2, 3, 5, 7, 6]
}
DF_CMOS = pd.DataFrame(data)

# figure와 axes 생성
fig, axes = plt.subplots(1, 2, figsize=(10, 5))

# KDE plot 그리기
sns.kdeplot(x=DF_CMOS['nFET-1'], y=DF_CMOS['pFET-1'], ax=axes[0], fill=True)                                      # 아래처럼해도 가능 둘다 가능
#sns.kdeplot(data=DF_CMOS, x='nFET-1', y='pFET-1', ax=axes[0], fill=True)

# scatter plot 그리기
#sns.scatterplot(x=DF_CMOS['nFET-1'], y=DF_CMOS['pFET-1'], alpha=0.2, color='c', label='Group-1', ax=axes[1])     # 아래처럼해도 가능 둘다 가능
sns.scatterplot(data=DF_CMOS, x='nFET-1', y='pFET-1', alpha=0.2, color='c', label='Group-1', ax=axes[1])

plt.show()
