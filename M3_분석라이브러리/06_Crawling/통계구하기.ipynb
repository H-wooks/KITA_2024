# %%
import pandas as pd

# Load the Excel file with a limited number of rows to avoid timeout
file_path = 'C:/Users/Administrator/Desktop/patents_data.xlsx'
df = pd.read_excel(file_path)

df.head()
# Out:
#   status                                              title         ap_num  \
# 0     등록  자동화 폐기물 수거함의 딥러닝 기반 인공지능 운영 시스템 및 방법(OPERATION...  1020200078616
# 1     등록  인공지능(AI)을 통한 딥러닝훈련모듈과, 순위화프레임워크모듈을 활용하여, 법률전문가...  1020170099431
# 2     공개  인공지능을 이용한 품질검사 시스템 및 방법(System and method for ...  1020220014151
# 3     공개  파이썬 딥러닝 기반 인공지능(AI) 부동산 컨설팅 매물장(Python deep le...  1020210106993
# 4     거절  PI 기반 빅데이터 퍼스널 컬러 진단 인공지능 딥러닝 알고리즘 시스템 운영방법(PI...  1020230034713
#
#    application_date         applicant representative     final_owner  \
# 0          20200626    (주)에이씨아이케미칼아시아            고영갑  (주)에이씨아이케미칼아시아
# 1          20170807               강준철            이영규             강소라
# 2          20220203  모던에이아이비전솔루션 주식회사            김정수             NaN
# 3          20210812               조국환            NaN             NaN
# 4          20230316         주식회사 오콜로르            박상열             NaN
#
#    priority_date  international_filing_date  \
# 0            NaN                        NaN
# ...

# %%
# 제너럴 키워드 리스트 
keywords = [
    '기술', '테크놀로지', '기술 혁신', '첨단 기술', '신기술', '정보기술', 'IT', 'ICT', 'AI', '인공지능', 
    '머신러닝', '딥러닝', '로봇', '로봇공학', '자동화', '스마트 기술', 'IoT', '사물인터넷', '빅데이터', 
    '데이터 과학', '클라우드 컴퓨팅', '블록체인', '사이버 보안', '디지털 전환', '가상 현실', 'VR', 
    '증강 현실', 'AR', '혼합 현실', 'MR', '3D 프린팅', '3D 기술', '나노 기술', '바이오 기술', '유전 공학', 
    '재생 에너지', '청정 에너지', '에너지 저장', '배터리 기술', '전기차', '자율 주행', '드론', '무인 항공기', 
    '위성 기술', '우주 기술', '항공 우주', '반도체', '전자 기기', '통신 기술', '5G', '6G', '네트워크', 
    '모바일 기술', '스마트폰', '웨어러블', '헬스 테크', '헬스케어 기술', '의료 기술', '생명 과학', '유전자 기술', 
    '식품 기술', '농업 기술', '환경 기술', '수자원 관리', '해양 기술', '해양 공학', '건설 기술', '토목 공학', 
    '재료 과학', '신소재', '고분자 과학', '나노소재', '화학 기술', '물리학 기술', '공학 기술', '전기 공학', 
    '전자 공학', '기계 공학', '산업 공학', '시스템 공학', '제어 공학', '소프트웨어 공학', '프로그래밍', 
    '코딩', '알고리즘', '데이터베이스', '네트워크 보안', '정보 보안', '웹 개발', '앱 개발', '게임 개발', 
    '가상화 기술', '디지털 미디어', '멀티미디어', '영상 처리', '음성 인식', '이미지 인식', '자연어 처리', 
    '컴퓨터 비전', '인공 지능 윤리', '기술 규제', '기술 표준', '기술 특허', '기술 상용화', '기술 창업', 
    '기술 사업화', '기술 이전', '기술 투자', '기술 금융', '기술 정책', '기술 교육', '기술 훈련', 
    '기술 인력', '기술 인재', '기술 협력', '기술 네트워크', '기술 컨퍼런스', '기술 워크샵', '기술 세미나', 
    '기술 포럼', '기술 블로그', '기술 뉴스', '기술 매거진', '기술 미디어', '기술 리뷰', '기술 평가', 
    '기술 트렌드', '기술 전망', '기술 보고서', '기술 연구', '기술 개발', '기술 혁신', '기술 창의성', 
    '기술 솔루션', '기술 지원', '기술 상담', '기술 서비스', '기술 관리', '기술 운영', '기술 전략', 
    '기술 분석', '기술 데이터', '기술 인사이트', '기술 인프라', '기술 설비', '기술 장비', '기술 도구', 
    '기술 장치', '기술 설계', '기술 구현', '기술 실험', '기술 테스트', '기술 평가', '기술 검증', 
    '기술 인증', '기술 표준화', '기술 협회', '기술 기구', '기술 조직', '기술 산업', '기술 기업', 
    '기술 비즈니스', '기술 마케팅', '기술 판매', '기술 구매', '기술 유통', '기술 물류', '기술 공급망', 
    '기술 제조', '기술 생산', '기술 품질', '기술 관리', '기술 재고', '기술 유지 보수', '기술 지원', 
    '기술 개발자', '기술 엔지니어', '기술 디자이너', '기술 관리자', '기술 컨설턴트', '기술 전문가', 
    '기술 교수', '기술 학생', '기술 연구원', '기술 교육자', '기술 학자', '기술 저널', '기술 논문', 
    '기술 보고서', '기술 사례 연구', '기술 백서', '기술 발표', '기술 강의', '기술 연수', '기술 이력서', 
    '기술 포트폴리오', '기술 인증서', '기술 수료증', '기술 경력', '기술 자격', '기술 지식', '기술 능력', 
    '기술 역량', '기술 학습', '기술 훈련', '기술 개발 계획', '기술 프로젝트', '기술 과제', '기술 목표', 
    '기술 성과', '기술 평가 시스템', '기술 보고 시스템', '기술 통계', '기술 데이터 분석', '기술 인사이트', 
    '기술 트렌드 분석', '기술 전망 분석', '기술 전략 분석', '기술 관리 시스템', '기술 운영 시스템', 
    '기술 지원 시스템', '기술 서비스 시스템', '기술 솔루션 시스템', '기술 설계 시스템', '기술 실험 시스템', 
    '기술 평가 시스템', '기술 인증 시스템', '기술 표준 시스템', '기술 협력 시스템', '기술 네트워크 시스템', 
    '기술 교육 시스템', '기술 훈련 시스템', '기술 인력 시스템', '기술 인재 시스템', '기술 창의성 시스템', 
    '기술 혁신 시스템', '기술 연구 시스템', '기술 개발 시스템', '기술 상용화 시스템', '기술 사업화 시스템', 
    '기술 이전 시스템', '기술 투자 시스템', '기술 금융 시스템', '기술 정책 시스템', '기술 규제 시스템', 
    '기술 법률 시스템', '기술 관리 체계', '기술 운영 체계', '기술 지원 체계', '기술 서비스 체계', 
    '기술 솔루션 체계', '기술 설계 체계', '기술 실험 체계', '기술 평가 체계', '기술 인증 체계', 
    '기술 표준 체계', '기술 협력 체계', '기술 네트워크 체계', '기술 교육 체계', '기술 훈련 체계', 
    '기술 인력 체계', '기술 인재 체계', '기술 창의성 체계', '기술 혁신 체계', '기술 연구 체계', 
    '기술 개발 체계', '기술 상용화 체계', '기술 사업화 체계', '기술 이전 체계', '기술 투자 체계', 
    '기술 금융 체계', '기술 정책 체계', '기술 규제 체계', '기술 법률 체계', '기술 관리 시스템', 
    '기술 운영 시스템', '기술 지원 시스템', '기술 서비스 시스템', '기술 솔루션 시스템', '기술 설계 시스템', 
    '기술 실험 시스템', '기술 평가 시스템', '기술 인증 시스템', '기술 표준 시스템', '기술 협력 시스템', 
    '기술 네트워크 시스템', '기술 교육 시스템', '기술 훈련 시스템', '기술 인력 시스템', '기술 인재 시스템', 
    '기술 창의성 시스템', '기술 혁신 시스템', '기술 연구 시스템', '기술 개발 시스템', '기술 상용화 시스템', 
    '기술 사업화 시스템', '기술 이전 시스템', '기술 투자 시스템', '기술 금융 시스템', '기술 정책 시스템', 
    '기술 규제 시스템', '기술 법률 시스템'
]

# 연도 컬럼과 키워드가 포함된 타이틀의 개수를 저장할 딕셔너리 초기화
yearly_counts = {year: 0 for year in range(2013, 2025)}

# 각 연도별로 키워드가 포함된 타이틀의 개수를 계산
for index, row in df.iterrows():
    title = row['title']
    application_date = row['application_date']  # 연도 컬럼 이름이 'application_date'라고 가정
    if pd.notna(title) and pd.notna(application_date):
        year = int(str(application_date)[:4])  # 날짜의 앞 4자리를 연도로 추출
        if 2013 <= year <= 2024:
            for keyword in keywords:
                if keyword in title:
                    yearly_counts[year] += 1
                    break  # 한 번 카운트되면 다른 키워드는 확인하지 않음

print(yearly_counts)
# Out:
# {2013: 8148, 2014: 14486, 2015: 14658, 2016: 14057, 2017: 15116, 2018: 16356, 2019: 18752, 2020: 21534, 2021: 24557, 2022: 23663, 2023: 5508, 2024: 501}

# %%
# 의료와 관련된 키워드 리스트
keywords = [
    '의료', '헬스', '헬스케어', '건강', '치료', '병원', '의학', '약물', '수술', '재활', '임상', 
    '의사', '환자', '간호', '응급', '진단', '치과', '정신건강', '보건', '약국', '의료기기', 
    '바이오', '유전자', '백신', '의료정보', '의료관리', '피부과', '내과', '외과', '소아과', 
    '산부인과', '정형외과', '안과', '이비인후과', '비뇨기과', '신경과', '심장과', '혈액과',
    '감염', '면역', '영양', '정신과', '물리치료', '약학', '생리학', '병리학', '방사선', 
    '영상의학', '핵의학', '미생물학', '생명공학', '줄기세포', '암', '종양', '응급의학',
    '가정의학', '노인의학', '소화기내과', '호흡기내과', '신장내과', '내분비내과', '류마티스내과',
    '감염내과', '알레르기', '임상약리학', '산업의학', '법의학', '중환자의학', '재활의학',
    '통증의학', '피부과학', '성형외과', '재생의학', '생체공학', '유전공학', '노화', '치매',
    '파킨슨병', '알츠하이머병', '뇌졸중', '심부전', '당뇨병', '고혈압', '비만', '치료법',
    '질병', '건강관리', '의료서비스', '의료기술', '의료소프트웨어', '원격의료', '디지털헬스',
    '치료제', '임상시험', '의료용로봇', '의료용인공지능', '의료데이터', '의료통계', '보건의료',
    '의약품', '의료분야', '의료산업', '의료정책', '의료법', '건강보험', '의료윤리', '임상연구',
    '의료시스템', '건강증진', '예방의학', '의료비용', '의료품질', '의료시설', '의료서비스',
    '건강정보', '의료커뮤니케이션', '의료교육', '의료훈련', '의료전문가', '건강생활', '의료용어',
    '의료혁신', '의료과학', '보건정책', '보건기술', '보건관리', '공공보건', '글로벌헬스', '지역보건',
    '심장', '폐', '간', '신장', '췌장', '피부', '뼈', '근육', '관절', '신경', '혈관', '혈액', 
    '소화', '호흡', '순환', '대사', '면역', '재활', '정신', '소아', '노인', '여성', '남성', 
    '장애', '치매', '인지', '운동', '수면', '통증', '스트레스', '우울증', '불안', '정신병', 
    '정신질환', '자폐', 'ADHD', '학습장애', '언어치료', '감각치료', '물리치료', '작업치료', 
    '놀이치료', '음악치료', '예술치료', '가족치료', '부부치료', '심리치료', '상담치료', 
    '인지치료', '행동치료', '정서치료', '사회치료', '자원봉사', '사회복지', '재활치료', 
    '직업재활', '사회재활', '정신재활', '약물치료', '전기치료', '방사선치료', '화학치료', 
    '면역치료', '유전자치료', '세포치료', '줄기세포치료', '재생치료', '나노의학', '인공장기', 
    '의료로봇', '로봇수술', '원격수술', '스마트헬스케어', '헬스모니터링', '바이오센서', 
    '의료기술평가', '건강평가', '리스크평가', '의료비평가', '보험평가', '보험심사', '의료법규', 
    '의료정책', '의료보험', '의료관리', '의료행정', '의료마케팅', '의료홍보', '의료재무', 
    '의료경영', '의료경영학', '의료산업', '의료경제', '의료통계', '의료정보', '의료정보학', 
    '의료정보시스템', '의료정보관리', '의료데이터', '의료데이터분석', '의료빅데이터', 
    '의료데이터보호', '의료사이버보안', '의료IT', '의료IoT', '의료모바일', '모바일헬스', 
    '의료앱', '헬스앱', '건강앱', '디지털헬스케어', '디지털의료', '디지털진단', '디지털치료', 
    '디지털약물', '디지털백신', '디지털재활', '디지털건강관리', '디지털의료기기', '디지털임상', 
    '디지털환자관리', '디지털헬스기술', '디지털헬스혁신', '디지털헬스서비스', '디지털헬스산업', 
    '디지털헬스정책', '디지털헬스보험', '디지털헬스비용', '디지털헬스품질', '디지털헬스시설', 
    '디지털헬스전문가', '디지털헬스연구', '디지털헬스기반시설', '디지털헬스학습', '디지털헬스커뮤니케이션'
]

# 연도 컬럼과 키워드가 포함된 타이틀의 개수를 저장할 딕셔너리 초기화
yearly_counts = {year: 0 for year in range(2013, 2025)}

# 각 연도별로 키워드가 포함된 타이틀의 개수를 계산
for index, row in df.iterrows():
    title = row['title']
    application_date = row['application_date']  # 연도 컬럼 이름이 'application_date'라고 가정
    if pd.notna(title) and pd.notna(application_date):
        year = int(str(application_date)[:4])  # 날짜의 앞 4자리를 연도로 추출
        if 2013 <= year <= 2024:
            for keyword in keywords:
                if keyword in title:
                    yearly_counts[year] += 1
                    break  # 한 번 카운트되면 다른 키워드는 확인하지 않음

print(yearly_counts)
# Out:
# {2013: 1704, 2014: 2942, 2015: 2854, 2016: 2990, 2017: 3386, 2018: 3808, 2019: 4365, 2020: 5262, 2021: 6087, 2022: 5900, 2023: 1422, 2024: 156}

# %%
# 전자상거래 키워드 리스트
keywords = [
    '전자상거래','거래','결제', '온라인 쇼핑', '이커머스', '인터넷 쇼핑', '전자 거래', '전자상거래 플랫폼', 
    '온라인 마켓플레이스', '쇼핑몰', '온라인 스토어', '전자 상점', '디지털 상거래', '모바일 상거래', 
    'm커머스', '이커머스 웹사이트', 'e쇼핑', 'e커머스', '전자 판매', '전자 구매', '전자 상거래 시스템', 
    '전자 상거래 솔루션', '전자 상거래 서비스', '전자 상거래 기술', '온라인 판매', '온라인 구매', 
    '전자 지불', '온라인 결제', '전자 송장', '전자 청구', '전자 상거래 관리', '전자 상거래 운영', 
    '전자 상거래 전략', '전자 상거래 분석', '전자 상거래 마케팅', '전자 상거래 광고', '전자 상거래 SEO', 
    '전자 상거래 최적화', '전자 상거래 고객 서비스', '전자 상거래 CRM', '전자 상거래 물류', '전자 상거래 배송', 
    '전자 상거래 반품', '전자 상거래 환불', '전자 상거래 보안', '전자 상거래 규제', '전자 상거래 법규', 
    '전자 상거래 법률', '전자 상거래 정책', '전자 상거래 트렌드', '전자 상거래 혁신', '전자 상거래 기술', 
    '전자 상거래 데이터', '전자 상거래 빅데이터', '전자 상거래 분석', '전자 상거래 통계', '전자 상거래 보고서', 
    '전자 상거래 연구', '전자 상거래 학습', '전자 상거래 교육', '전자 상거래 훈련', '전자 상거래 전문가', 
    '전자 상거래 네트워크', '전자 상거래 커뮤니티', '전자 상거래 이벤트', '전자 상거래 컨퍼런스', '전자 상거래 전시회', 
    '전자 상거래 워크샵', '전자 상거래 세미나', '전자 상거래 웹비나', '전자 상거래 포럼', '전자 상거래 블로그', 
    '전자 상거래 뉴스', '전자 상거래 매거진', '전자 상거래 미디어', '전자 상거래 소셜 미디어', '전자 상거래 앱', 
    '전자 상거래 모바일 앱', '전자 상거래 플랫폼 개발', '전자 상거래 플랫폼 디자인', '전자 상거래 UX', '전자 상거래 UI', 
    '전자 상거래 사용자 경험', '전자 상거래 사용자 인터페이스', '전자 상거래 사용자 조사', '전자 상거래 사용자 피드백', 
    '전자 상거래 사용자 테스트', '전자 상거래 고객 만족', '전자 상거래 고객 유지', '전자 상거래 고객 충성도', 
    '전자 상거래 고객 획득', '전자 상거래 고객 전환', '전자 상거래 고객 분석', '전자 상거래 고객 인사이트', 
    '전자 상거래 고객 피드백', '전자 상거래 고객 리뷰', '전자 상거래 고객 평가', '전자 상거래 고객 상담', 
    '전자 상거래 고객 지원', '전자 상거래 고객 서비스', '전자 상거래 고객 경험', '전자 상거래 고객 관계', 
    '전자 상거래 고객 참여', '전자 상거래 고객 반응', '전자 상거래 고객 기대', '전자 상거래 고객 요구', 
    '전자 상거래 고객 요구사항', '전자 상거래 고객 중심', '전자 상거래 고객 기반', '전자 상거래 고객 중심 전략', 
    '전자 상거래 고객 중심 서비스', '전자 상거래 고객 중심 제품', '전자 상거래 고객 중심 운영', '전자 상거래 고객 중심 마케팅', 
    '전자 상거래 고객 중심 광고', '전자 상거래 고객 중심 커뮤니케이션', '전자 상거래 고객 중심 소셜 미디어', 
    '전자 상거래 고객 중심 웹사이트', '전자 상거래 고객 중심 모바일 앱', '전자 상거래 고객 중심 플랫폼', 
    '전자 상거래 고객 중심 시스템', '전자 상거래 고객 중심 솔루션', '전자 상거래 고객 중심 데이터', '전자 상거래 고객 중심 분석', 
    '전자 상거래 고객 중심 보고서', '전자 상거래 고객 중심 연구', '전자 상거래 고객 중심 학습', '전자 상거래 고객 중심 교육', 
    '전자 상거래 고객 중심 훈련', '전자 상거래 고객 중심 전문가', '전자 상거래 고객 중심 네트워크', '전자 상거래 고객 중심 커뮤니티', 
    '전자 상거래 고객 중심 이벤트', '전자 상거래 고객 중심 컨퍼런스', '전자 상거래 고객 중심 전시회', '전자 상거래 고객 중심 워크샵', 
    '전자 상거래 고객 중심 세미나', '전자 상거래 고객 중심 웹비나', '전자 상거래 고객 중심 포럼', '전자 상거래 고객 중심 블로그', 
    '전자 상거래 고객 중심 뉴스', '전자 상거래 고객 중심 매거진', '전자 상거래 고객 중심 미디어', '전자 상거래 고객 중심 소셜 미디어',
    '디지털 상거래', '온라인 거래', '인터넷 마케팅', '디지털 마케팅', '온라인 프로모션', 'SEO', 'SEM', 'PPC 광고', '콘텐츠 마케팅',
    '소셜 미디어 마케팅', '이메일 마케팅', '어필리에이트 마케팅', '퍼포먼스 마케팅', '브랜드 마케팅', '인터넷 광고', '디지털 광고',
    '온라인 광고', '마케팅 자동화', '고객 데이터 플랫폼', '고객 관계 관리', '데이터 분석', '고객 행동 분석', '고객 경험 관리',
    '옴니채널 전략', '멀티채널 마케팅', '전자상거래 웹 개발', '전자상거래 플랫폼 구축', '쇼핑카트 시스템', '지불 게이트웨이 통합',
    '배송 추적', '재고 관리', '물류 관리', '운송 관리', '리버스 물류', '고객 피드백 시스템', '리뷰 관리', '고객 지원 시스템',
    '챗봇', '인공지능 고객 서비스', '추천 시스템', '개인화 마케팅', '로열티 프로그램', '프로모션 전략', '할인 코드', '쿠폰',
    '블랙프라이데이', '사이버 먼데이', '쇼핑 축제', '판매 촉진', '구매 전환율', '리타겟팅', '리마케팅', '장바구니 포기율',
    '구매자 행동', '고객 여정', '사이트 트래픽', '방문자 분석', '페이지뷰', '세션 시간', '이탈률', '방문자 유지', '이메일 구독',
    '뉴스레터', '이메일 캠페인', '푸시 알림', '모바일 마케팅', '앱 마케팅', '앱 설치 광고', '앱 사용 분석', '앱 리뷰',
    '모바일 결제', '모바일 쇼핑', '모바일 쿠폰', 'QR 코드', '위치 기반 서비스', '위치 기반 마케팅', '위치 추적', '지도 통합',
    '음성 검색 최적화', '비디오 마케팅', '라이브 스트리밍', '웹 세미나', '웹 컨퍼런스', '온라인 이벤트', '가상 전시회',
    '가상 현실 쇼핑', '증강 현실 쇼핑', '3D 제품 보기', '제품 시뮬레이션', '가상 피팅룸', '온라인 고객 커뮤니티', '포럼',
    '온라인 지원 그룹', '온라인 상담', '소셜 미디어 통합', '페이스북 쇼핑', '인스타그램 쇼핑', '핀터레스트 쇼핑', '유튜브 마케팅',
    '틱톡 마케팅', '트위터 마케팅', '링크드인 마케팅', '스냅챗 마케팅', '크로스 채널 마케팅', '연관 상품 추천', '번들 판매',
    '구독 서비스', '멤버십 프로그램', '충성 고객 프로그램', '고객 생애 가치', '고객 획득 비용', '고객 유지 비용', '마케팅 ROI',
    '고객 유지 전략', '고객 참여 전략', '고객 충성도 프로그램', '고객 피드백 시스템', '리뷰 관리 시스템', '고객 서비스 센터',
    '글로벌 마케팅', '국제 배송', '통관 서비스', '관세 계산', '환율 변동']

    # 키워드가 포함된 타이틀의 개수를 저장할 변수

# 연도 컬럼과 키워드가 포함된 타이틀의 개수를 저장할 딕셔너리 초기화
yearly_counts = {year: 0 for year in range(2013, 2025)}

# 각 연도별로 키워드가 포함된 타이틀의 개수를 계산
for index, row in df.iterrows():
    title = row['title']
    application_date = row['application_date']  # 연도 컬럼 이름이 'application_date'라고 가정
    if pd.notna(title) and pd.notna(application_date):
        year = int(str(application_date)[:4])  # 날짜의 앞 4자리를 연도로 추출
        if 2013 <= year <= 2024:
            for keyword in keywords:
                if keyword in title:
                    yearly_counts[year] += 1
                    break  # 한 번 카운트되면 다른 키워드는 확인하지 않음

print(yearly_counts)
# Out:
# {2013: 648, 2014: 1260, 2015: 1224, 2016: 1056, 2017: 1224, 2018: 1323, 2019: 1434, 2020: 1643, 2021: 1900, 2022: 1849, 2023: 577, 2024: 45}

# %%
# 자동차 관련 키워드 리스트
keywords = [
    '자동차', '차량', '자율 주행', '전기차', '하이브리드', '내연기관', '연료전지', 
    '자율주행차', '커넥티드카', '스마트카', '무인차', '운전 보조 시스템', 'ADAS', 
    '차량용 센서', '차량 네트워크', 'V2X', '차량 통신', '차량 제어', '차량 전장', 
    '차량 보안', '차량 안전', '차량 설계', '차량 제조', '차량 유지보수', '차량 검사', 
    '자동차 부품', '엔진', '모터', '배터리', '충전', '충전소', '자동차 기술', '자동차 혁신', 
    '차량 공유', '카셰어링', '라이드셰어링', '모빌리티', '이동성', '운송', '물류', '운전', 
    '운전자', '운전 보조', '주차', '자동 주차', '차량 인터페이스', 'HMI', '계기판', '헤드업 디스플레이', 
    '차량 내비게이션', '차량 인포테인먼트', '차량 디스플레이', '차량 오디오', '차량 통합 시스템', '차량 데이터', 
    '차량 분석', '차량 진단', '차량 관리', '차량 모니터링', '차량 제어 시스템', '차량 통합 제어', 
    '차량 네트워크 보안', '차량 해킹 방지', '차량 사이버 보안', '차량 통신 보안', '차량 데이터 보호', 
    '차량 연결성', '차량 IoT', '차량 통신 기술', '차량 무선 통신', '차량 GPS', '차량 위치 추적', 
    '차량 이동성', '차량 스마트 시스템', '차량 자동화', '차량 컴퓨팅', '차량 소프트웨어', '차량 앱', 
    '차량 관리 시스템', '차량 유지보수 시스템', '차량 검사 시스템', '차량 안전 시스템', '차량 보호 시스템', 
    '차량 설계 시스템', '차량 제조 시스템', '차량 유지보수 관리', '차량 검사 관리', '자동차 시장', '자동차 산업', 
    '자동차 정책', '자동차 규제', '자동차 법률', '자동차 보험', '자동차 금융', '자동차 판매', '자동차 구매', 
    '자동차 유통', '자동차 서비스', '자동차 판매 관리', '자동차 구매 관리', '자동차 유통 관리', 
    '자동차 서비스 관리', '자동차 고객 관리', '자동차 마케팅', '자동차 광고', '자동차 프로모션', 
    '자동차 브랜딩', '자동차 시장 분석', '자동차 소비자 분석', '자동차 트렌드', '자동차 전망', 
    '자동차 보고서', '자동차 연구', '자동차 개발', '자동차 혁신', '자동차 창의성', '자동차 솔루션', 
    '자동차 지원', '자동차 상담', '자동차 서비스 시스템', '자동차 관리 시스템', '자동차 운영 시스템', 
    '자동차 전략', '자동차 분석', '자동차 데이터', '자동차 인사이트', '자동차 인프라', '자동차 설비', 
    '자동차 장비', '자동차 도구', '자동차 장치', '자동차 설계 시스템', '자동차 구현 시스템', 
    '자동차 실험 시스템', '자동차 테스트 시스템', '자동차 평가 시스템', '자동차 인증 시스템', 
    '자동차 표준 시스템', '자동차 협력 시스템', '자동차 네트워크 시스템', '자동차 교육 시스템', 
    '자동차 훈련 시스템', '자동차 인력 시스템', '자동차 인재 시스템', '자동차 창의성 시스템', 
    '자동차 혁신 시스템', '자동차 연구 시스템', '자동차 개발 시스템', '자동차 상용화 시스템', 
    '자동차 사업화 시스템', '자동차 이전 시스템', '자동차 투자 시스템', '자동차 금융 시스템', 
    '자동차 정책 시스템', '자동차 규제 시스템', '자동차 법률 시스템'
]

# 연도 컬럼과 키워드가 포함된 타이틀의 개수를 저장할 딕셔너리 초기화
yearly_counts = {year: 0 for year in range(2013, 2025)}

# 각 연도별로 키워드가 포함된 타이틀의 개수를 계산
for index, row in df.iterrows():
    title = row['title']
    application_date = row['application_date']  # 연도 컬럼 이름이 'application_date'라고 가정
    if pd.notna(title) and pd.notna(application_date):
        year = int(str(application_date)[:4])  # 날짜의 앞 4자리를 연도로 추출
        if 2013 <= year <= 2024:
            for keyword in keywords:
                if keyword in title:
                    yearly_counts[year] += 1
                    break  # 한 번 카운트되면 다른 키워드는 확인하지 않음

print(yearly_counts)
# Out:
# {2013: 2813, 2014: 4009, 2015: 3977, 2016: 3857, 2017: 3781, 2018: 3733, 2019: 4346, 2020: 5011, 2021: 5659, 2022: 4940, 2023: 645, 2024: 67}

# %%
# 금융 관련 키워드 리스트
keywords = [
    '금융','간편결제','자동결제','입금','출금', '재정', '은행', '투자', '보험', '경제', '자산', '자산 관리', '부채', '대출', 
    '신용', '이자', '지불', '결제', '송금', '환율', '외환', '주식', '채권', '증권', '펀드', 
    '연금', '퇴직금', '저축', '예금', '지급 보증', '금융 서비스', '금융 기술', '핀테크', 
    '디지털 금융', '모바일 금융', '온라인 뱅킹', '인터넷 뱅킹', '금융 거래', '전자 금융', 
    '전자 결제', '모바일 결제', 'P2P 대출', '크라우드 펀딩', '크립토커런시', '비트코인', 
    '블록체인 금융', '분산 원장', '금융 보안', '사이버 보안', '금융 데이터', '금융 분석', 
    '금융 보고서', '금융 통계', '금융 예측', '리스크 관리', '금융 규제', '금융 법률', 
    '금융 정책', '금융 감독', '금융 감사', '금융 사기', '금융 범죄', '자금 세탁', 
    '금융 윤리', '금융 교육', '금융 훈련', '금융 인력', '금융 인재', '금융 시장', 
    '금융 상품', '금융 거래소', '증권 거래소', '금융 기관', '중앙 은행', '상업 은행', 
    '투자 은행', '보험 회사', '자산 운용사', '연금 기금', '헤지 펀드', '사모 펀드', 
    '벤처 캐피털', '기업 금융', '소비자 금융', '소매 금융', '기업 대출', '소비자 대출', 
    '모기지', '자동차 대출', '학자금 대출', '개인 금융', '개인 자산 관리', '금융 상담', 
    '재정 계획', '세무 계획', '상속 계획', '재정 자문', '금융 컨설팅', '재정 분석', 
    '투자 분석', '경제 분석', '시장 분석', '포트폴리오 관리', '자산 배분', '자산 평가', 
    '금융 상품 개발', '금융 혁신', '금융 연구', '금융 개발', '금융 플랫폼', '금융 앱', 
    '금융 소프트웨어', '금융 알고리즘', '금융 모델링', '금융 시뮬레이션', '금융 인프라', 
    '금융 네트워크', '금융 시스템', '금융 데이터베이스', '금융 클라우드', '금융 API', 
    '금융 인터페이스', '금융 사용자 경험', '금융 고객 서비스', '금융 고객 관리', '금융 CRM', 
    '금융 마케팅', '금융 광고', '금융 프로모션', '금융 브랜딩', '금융 커뮤니케이션', 
    '금융 미디어', '금융 뉴스', '금융 블로그', '금융 포럼', '금융 컨퍼런스', '금융 워크샵', 
    '금융 세미나', '금융 이벤트', '금융 네트워킹', '금융 협력', '금융 파트너십', '금융 계약', 
    '금융 분쟁', '금융 해결', '금융 중재', '금융 컴플라이언스', '금융 규제 준수', 
    '금융 리스크 평가', '금융 리스크 분석', '금융 리스크 관리 시스템', '금융 리스크 모니터링', 
    '금융 리스크 예측', '금융 리스크 완화', '금융 리스크 대응', '금융 리스크 전략', '금융 리스크 솔루션', 
    '금융 리스크 지원', '금융 리스크 자문', '금융 리스크 서비스', '금융 리스크 평가 시스템', 
    '금융 리스크 관리 시스템', '금융 리스크 모니터링 시스템', '금융 리스크 예측 시스템', 
    '금융 리스크 완화 시스템', '금융 리스크 대응 시스템', '금융 리스크 전략 시스템', 
    '금융 리스크 솔루션 시스템', '금융 리스크 지원 시스템', '금융 리스크 자문 시스템', 
    '금융 리스크 서비스 시스템'
]

# 연도 컬럼과 키워드가 포함된 타이틀의 개수를 저장할 딕셔너리 초기화
yearly_counts = {year: 0 for year in range(2013, 2025)}

# 각 연도별로 키워드가 포함된 타이틀의 개수를 계산
for index, row in df.iterrows():
    title = row['title']
    application_date = row['application_date']  # 연도 컬럼 이름이 'application_date'라고 가정
    if pd.notna(title) and pd.notna(application_date):
        year = int(str(application_date)[:4])  # 날짜의 앞 4자리를 연도로 추출
        if 2013 <= year <= 2024:
            for keyword in keywords:
                if keyword in title:
                    yearly_counts[year] += 1
                    break  # 한 번 카운트되면 다른 키워드는 확인하지 않음

print(yearly_counts)
# Out:
# {2013: 74, 2014: 161, 2015: 158, 2016: 165, 2017: 201, 2018: 196, 2019: 272, 2020: 284, 2021: 369, 2022: 472, 2023: 146, 2024: 9}

# %%
# 교육 관련 키워드 리스트
keywords = [
    '교육', '자기주도학습', '학교', '대학', '강의', '교수', '학생', '교실', '온라인 교육', 'e러닝', 
    '원격 교육', '교육 기술', '에듀테크', '학습 관리 시스템', 'LMS', '교육 소프트웨어', 
    '교육 앱', '교육 플랫폼', '가상 교실', '디지털 교과서', '교육 콘텐츠', '교육 자료', 
    '교육 과정', '교육 프로그램', '교육 훈련', '교사', '교육자', '교육자원', '교육 연구', 
    '교육 개발', '교육 혁신', '교육 정책', '교육 행정', '교육 평가', '교육 심리학', 
    '교육 방법', '교육 전략', '교육 계획', '교육 기획', '교육 마케팅', '교육 홍보', 
    '교육 재정', '교육 기금', '교육 투자', '교육 관리', '교육 운영', '교육 지원', 
    '교육 서비스', '교육 상담', '진로 상담', '교육 인프라', '교육 시설', '교육 환경', 
    '교육 장비', '교육 도구', '교육 기술 장비', '교육 자재', '교육 시스템', '교육 네트워크', 
    '교육 커뮤니티', '교육 협력', '교육 파트너십', '교육 행사', '교육 세미나', '교육 워크샵', 
    '교육 포럼', '교육 컨퍼런스', '교육 전시회', '교육 이벤트', '교육 포털', '교육 웹사이트', 
    '교육 블로그', '교육 뉴스', '교육 미디어', '교육 비디오', '교육 자료실', '교육 도서관', 
    '교육 연구소', '교육 센터', '교육 기관', '교육 단체', '교육 협회', '교육 법률', '교육 규제', 
    '교육 표준', '교육 인증', '교육 자격', '교육 수료증', '교육 인증서', '교육 성과', 
    '교육 평가 시스템', '교육 분석', '교육 데이터', '교육 통계', '교육 보고서', '교육 인사이트', 
    '교육 트렌드', '교육 전망', '교육 혁신 시스템', '교육 창의성', '교육 방법론', '교육 이론', 
    '교육 철학', '교육 모델', '교육 프레임워크', '교육 패러다임', '교육 패턴', '교육 방법론', 
    '교육 연구 방법', '교육 사례 연구', '교육 실험', '교육 검증', '교육 실습', '교육 연수', 
    '교사 연수', '교사 훈련', '교사 교육', '교사 평가', '교사 지원', '교사 상담', '교사 자격', 
    '교사 인증', '교사 수료증', '교사 포트폴리오', '교사 경력', '교사 개발', '교사 학습', 
    '교사 인사이트', '교사 혁신', '교사 창의성', '교사 리더십', '교사 전략', '교사 계획', 
    '교사 기획', '교사 마케팅', '교사 홍보', '교사 재정', '교사 기금', '교사 투자', '교사 관리', 
    '교사 운영', '교사 지원', '교사 서비스', '교사 상담', '진로 상담', '학생 상담', '학생 지원', 
    '학생 서비스', '학생 관리', '학생 운영', '학생 활동', '학생 행사', '학생 세미나', '학생 워크샵', 
    '학생 포럼', '학생 컨퍼런스', '학생 전시회', '학생 이벤트', '학생 포털', '학생 웹사이트', 
    '학생 블로그', '학생 뉴스', '학생 미디어', '학생 비디오', '학생 자료실', '학생 도서관', 
    '학생 연구소', '학생 센터', '학생 기관', '학생 단체', '학생 협회', '학생 법률', '학생 규제', 
    '학생 표준', '학생 인증', '학생 자격', '학생 수료증', '학생 인증서', '학생 성과', '학생 평가 시스템'
]

# 연도 컬럼과 키워드가 포함된 타이틀의 개수를 저장할 딕셔너리 초기화
yearly_counts = {year: 0 for year in range(2013, 2025)}

# 각 연도별로 키워드가 포함된 타이틀의 개수를 계산
for index, row in df.iterrows():
    title = row['title']
    application_date = row['application_date']  # 연도 컬럼 이름이 'application_date'라고 가정
    if pd.notna(title) and pd.notna(application_date):
        year = int(str(application_date)[:4])  # 날짜의 앞 4자리를 연도로 추출
        if 2013 <= year <= 2024:
            for keyword in keywords:
                if keyword in title:
                    yearly_counts[year] += 1
                    break  # 한 번 카운트되면 다른 키워드는 확인하지 않음

print(yearly_counts)
# Out:
# {2013: 37, 2014: 63, 2015: 86, 2016: 64, 2017: 84, 2018: 135, 2019: 138, 2020: 177, 2021: 246, 2022: 231, 2023: 61, 2024: 7}

# %%
# 농업 관련 키워드 리스트
keywords = [
    '농업', '농사', '농업 기술', '스마트 농업', '스마트팜', '농업 혁신', '농업 자동화', '농업 로봇', 
    '농업 기계', '농기계', '농업 장비', '농업 도구', '농업 시스템', '농업 관리', '농업 운영', 
    '농업 데이터', '농업 분석', '농업 통계', '농업 예측', '농업 관리 시스템', '농업 지원', 
    '농업 서비스', '농업 상담', '농업 교육', '농업 훈련', '농업 인력', '농업 인재', 
    '농업 네트워크', '농업 협력', '농업 파트너십', '농업 협회', '농업 단체', '농업 연구', 
    '농업 개발', '농업 혁신', '농업 창의성', '농업 솔루션', '농업 프로젝트', '농업 계획', 
    '농업 기획', '농업 전략', '농업 마케팅', '농업 홍보', '농업 투자', '농업 재정', 
    '농업 기금', '농업 정책', '농업 규제', '농업 법률', '농업 표준', '농업 인증', '농업 자격', 
    '농업 수료증', '농업 인증서', '농업 성과', '농업 평가', '농업 보고서', '농업 인사이트', 
    '농업 트렌드', '농업 전망', '농업 환경', '농업 기후', '농업 날씨', '농업 물 관리', 
    '농업 토양', '농업 비료', '농업 자재', '농업 식물', '농업 작물', '농업 생산', '농업 품질', 
    '농업 수확', '농업 가공', '농업 유통', '농업 판매', '농업 시장', '농업 가격', '농업 비용', 
    '농업 효율성', '농업 생태계', '농업 바이오', '농업 생명공학', '농업 유전자', '농업 품종', 
    '농업 개량', '농업 실험', '농업 연구소', '농업 센터', '농업 기관', '농업 조직', '농업 교육 기관', 
    '농업 학교', '농업 대학교', '농업 학회', '농업 저널', '농업 논문', '농업 도서관', '농업 자료실', 
    '농업 미디어', '농업 뉴스', '농업 블로그', '농업 포럼', '농업 컨퍼런스', '농업 워크샵', 
    '농업 세미나', '농업 이벤트', '농업 전시회', '농업 포털', '농업 웹사이트', '농업 플랫폼', 
    '농업 앱', '농업 소프트웨어', '농업 솔루션 시스템', '농업 데이터베이스', '농업 클라우드', 
    '농업 인공지능', '농업 AI', '농업 머신러닝', '농업 빅데이터', '농업 IoT', '농업 사물인터넷', 
    '농업 센서', '농업 모니터링', '농업 제어', '농업 자동화 시스템', '농업 로봇 시스템', 
    '농업 기계화', '농업 드론', '농업 무인기', '농업 위성', '농업 GPS', '농업 위치 추적', 
    '농업 지도', '농업 분석 시스템', '농업 예측 시스템', '농업 지원 시스템', '농업 서비스 시스템', 
    '농업 관리 시스템', '농업 운영 시스템', '농업 전략 시스템', '농업 계획 시스템', '농업 기획 시스템', 
    '농업 마케팅 시스템', '농업 홍보 시스템', '농업 재정 시스템', '농업 기금 시스템', '농업 정책 시스템', 
    '농업 규제 시스템', '농업 법률 시스템', '농업 표준 시스템', '농업 인증 시스템', '농업 자격 시스템', 
    '농업 수료증 시스템', '농업 인증서 시스템', '농업 성과 시스템', '농업 평가 시스템', '농업 보고서 시스템', 
    '농업 인사이트 시스템', '농업 트렌드 시스템', '농업 전망 시스템', '농업 환경 시스템', '농업 기후 시스템', 
    '농업 날씨 시스템', '농업 물 관리 시스템', '농업 토양 시스템', '농업 비료 시스템', '농업 자재 시스템', 
    '농업 식물 시스템', '농업 작물 시스템', '농업 생산 시스템', '농업 품질 시스템', '농업 수확 시스템', 
    '농업 가공 시스템', '농업 유통 시스템', '농업 판매 시스템', '농업 시장 시스템', '농업 가격 시스템', 
    '농업 비용 시스템', '농업 효율성 시스템', '농업 생태계 시스템', '농업 바이오 시스템', 
    '농업 생명공학 시스템', '농업 유전자 시스템', '농업 품종 시스템', '농업 개량 시스템', '농업 실험 시스템'
]

# 연도 컬럼과 키워드가 포함된 타이틀의 개수를 저장할 딕셔너리 초기화
yearly_counts = {year: 0 for year in range(2013, 2025)}

# 각 연도별로 키워드가 포함된 타이틀의 개수를 계산
for index, row in df.iterrows():
    title = row['title']
    application_date = row['application_date']  # 연도 컬럼 이름이 'application_date'라고 가정
    if pd.notna(title) and pd.notna(application_date):
        year = int(str(application_date)[:4])  # 날짜의 앞 4자리를 연도로 추출
        if 2013 <= year <= 2024:
            for keyword in keywords:
                if keyword in title:
                    yearly_counts[year] += 1
                    break  # 한 번 카운트되면 다른 키워드는 확인하지 않음

print(yearly_counts)
# Out:
# {2013: 12, 2014: 4, 2015: 4, 2016: 10, 2017: 18, 2018: 20, 2019: 35, 2020: 37, 2021: 72, 2022: 88, 2023: 19, 2024: 1}

# %%
# 엔터테인먼트 관련 키워드 리스트
keywords = [
    '엔터테인먼트', '오락', '게임', '비디오 게임', '온라인 게임', '모바일 게임', '가상 현실 게임', 
    '증강 현실 게임', '콘솔 게임', 'PC 게임', '게임 개발', '게임 디자인', '게임 엔진', 
    '게임 플랫폼', '게임 소프트웨어', '게임 앱', '게임 기술', '게임 혁신', '게임 그래픽', 
    '게임 사운드', '게임 음악', '게임 캐릭터', '게임 스토리', '게임 시나리오', '게임 시뮬레이션', 
    '게임 인공지능', '게임 AI', '게임 머신러닝', '게임 빅데이터', '게임 분석', '게임 데이터', 
    '게임 통계', '게임 예측', '게임 마케팅', '게임 홍보', '게임 투자', '게임 재정', '게임 기금', 
    '게임 전략', '게임 기획', '게임 관리', '게임 운영', '게임 서비스', '게임 지원', '게임 커뮤니티', 
    '게임 네트워크', '게임 협력', '게임 파트너십', '게임 이벤트', '게임 대회', '게임 토너먼트', 
    '게임 리그', '게임 포럼', '게임 컨퍼런스', '게임 세미나', '게임 워크샵', '게임 전시회', 
    '게임 뉴스', '게임 블로그', '게임 미디어', '게임 스트리밍', '게임 방송', '게임 유튜브', 
    '게임 트위치', '게임 리뷰', '게임 평가', '게임 순위', '게임 랭킹', '게임 포털', '게임 웹사이트', 
    '게임 플랫폼', '게임 엔진', '게임 툴', '게임 개발 도구', '게임 개발 환경', '게임 테스트', 
    '게임 디버깅', '게임 품질 보증', '게임 QA', '게임 퍼블리싱', '게임 배급', '게임 유통', 
    '게임 상점', '게임 마켓플레이스', '게임 다운로드', '게임 인앱 결제', '게임 수익 모델', 
    '게임 경제', '게임 화폐', '게임 아이템', '게임 레벨 디자인', '게임 스킬', '게임 퀘스트', 
    '게임 업적', '게임 보상', '게임 멀티플레이어', '게임 협동', '게임 경쟁', '게임 소셜', 
    '게임 친구', '게임 길드', '게임 클랜', '게임 팀', '게임 커뮤니케이션', '게임 채팅', 
    '게임 음성 채팅', '게임 비디오 채팅', '게임 스트리밍', '게임 방송', '게임 방송 플랫폼', 
    '게임 스트리밍 플랫폼', '게임 방송 소프트웨어', '게임 스트리밍 소프트웨어', '게임 방송 도구', 
    '게임 스트리밍 도구', '게임 방송 기술', '게임 스트리밍 기술', '게임 방송 환경', '게임 스트리밍 환경', 
    '게임 방송 장비', '게임 스트리밍 장비', '게임 방송 시스템', '게임 스트리밍 시스템', '게임 방송 서비스', 
    '게임 스트리밍 서비스', '게임 방송 플랫폼', '게임 스트리밍 플랫폼', '게임 방송 소프트웨어', 
    '게임 스트리밍 소프트웨어', '게임 방송 도구', '게임 스트리밍 도구', '게임 방송 기술', '게임 스트리밍 기술', 
    '게임 방송 환경', '게임 스트리밍 환경', '게임 방송 장비', '게임 스트리밍 장비', '게임 방송 시스템', 
    '게임 스트리밍 시스템', '게임 방송 서비스', '게임 스트리밍 서비스', '영화', '드라마', '애니메이션', 
    '뮤지컬', '공연', '콘서트', '음악', '음원', '음반', '뮤직비디오', '라디오', '팟캐스트', 
    '오디오북', '웹툰', '웹소설', '디지털 콘텐츠', '콘텐츠 제작', '콘텐츠 기획', '콘텐츠 마케팅', 
    '콘텐츠 배급', '콘텐츠 유통', '콘텐츠 플랫폼', 'OTT', '스트리밍 서비스', '넷플릭스', '디즈니 플러스', 
    '아마존 프라임', '유튜브', '트위치', '틱톡', '페이스북', '인스타그램', '소셜 미디어', '미디어 플랫폼', 
    '미디어 기술', '미디어 혁신', '미디어 기기', '미디어 장비', '미디어 환경', '미디어 제작', 
    '미디어 배급', '미디어 유통', '미디어 마케팅', '미디어 광고', '미디어 홍보', '미디어 전략', 
    '미디어 기획', '미디어 관리', '미디어 운영', '미디어 서비스', '미디어 지원', '미디어 교육', 
    '미디어 훈련', '미디어 인력', '미디어 인재', '미디어 네트워크', '미디어 협력', '미디어 파트너십', 
    '미디어 이벤트', '미디어 대회', '미디어 토너먼트', '미디어 리그', '미디어 포럼', '미디어 컨퍼런스', 
    '미디어 세미나', '미디어 워크샵', '미디어 전시회', '미디어 뉴스', '미디어 블로그', '미디어 스트리밍', 
    '미디어 방송', '미디어 스트리밍 플랫폼', '미디어 방송 플랫폼', '미디어 스트리밍 소프트웨어', 
    '미디어 방송 소프트웨어', '미디어 스트리밍 도구', '미디어 방송 도구', '미디어 스트리밍 기술', 
    '미디어 방송 기술', '미디어 스트리밍 환경', '미디어 방송 환경', '미디어 스트리밍 장비', '미디어 방송 장비'
]

# 연도 컬럼과 키워드가 포함된 타이틀의 개수를 저장할 딕셔너리 초기화
yearly_counts = {year: 0 for year in range(2013, 2025)}

# 각 연도별로 키워드가 포함된 타이틀의 개수를 계산
for index, row in df.iterrows():
    title = row['title']
    application_date = row['application_date']  # 연도 컬럼 이름이 'application_date'라고 가정
    if pd.notna(title) and pd.notna(application_date):
        year = int(str(application_date)[:4])  # 날짜의 앞 4자리를 연도로 추출
        if 2013 <= year <= 2024:
            for keyword in keywords:
                if keyword in title:
                    yearly_counts[year] += 1
                    break  # 한 번 카운트되면 다른 키워드는 확인하지 않음

print(yearly_counts)
# Out:
# {2013: 109, 2014: 198, 2015: 181, 2016: 202, 2017: 228, 2018: 288, 2019: 322, 2020: 341, 2021: 404, 2022: 425, 2023: 101, 2024: 6}

# %%
# 보안 관련 키워드 리스트
keywords = [
    '보안', '사이버 보안', '정보 보안', '네트워크 보안', '데이터 보안', '시스템 보안', '컴퓨터 보안', 
    '인터넷 보안', '웹 보안', '모바일 보안', '클라우드 보안', '보안 솔루션', '보안 소프트웨어', 
    '보안 하드웨어', '보안 장비', '보안 도구', '보안 기술', '보안 서비스', '보안 관리', '보안 운영', 
    '보안 모니터링', '보안 분석', '보안 평가', '보안 감사', '보안 검사', '보안 정책', '보안 규제', 
    '보안 법률', '보안 표준', '보안 인증', '보안 자격', '보안 교육', '보안 훈련', '보안 인력', 
    '보안 인재', '보안 팀', '보안 조직', '보안 컨설팅', '보안 자문', '보안 대응', '보안 복구', 
    '보안 위험 관리', '위험 평가', '위험 분석', '위험 예측', '위험 대응', '위험 완화', '위험 방지', 
    '위험 모니터링', '침입 탐지', '침입 방지', '침입 대응', '침입 차단', '방화벽', '안티바이러스', 
    '안티멀웨어', '안티스파이웨어', '안티랜섬웨어', '피싱 방지', '스팸 필터링', 'DDoS 방어', 
    'IDS', 'IPS', 'SIEM', 'NAC', 'IAM', 'PKI', '암호화', '암호 해독', '암호 알고리즘', '키 관리', 
    '디지털 서명', '디지털 인증서', 'SSL', 'TLS', 'VPN', 'IPSec', '보안 토큰', '보안 프로토콜', 
    '보안 아키텍처', '보안 인프라', '보안 네트워크', '보안 서버', '보안 데이터베이스', '보안 애플리케이션', 
    '보안 플랫폼', '보안 클라우드', '보안 IoT', '보안 모바일', '보안 웹', '보안 이메일', '보안 메신저', 
    '보안 통신', '보안 연결', '보안 장치', '보안 장비', '보안 기기', '보안 솔루션', '보안 소프트웨어', 
    '보안 하드웨어', '보안 도구', '보안 기술', '보안 서비스', '보안 운영', '보안 관리', '보안 모니터링', 
    '보안 분석', '보안 평가', '보안 감사', '보안 검사', '보안 정책', '보안 규제', '보안 법률', 
    '보안 표준', '보안 인증', '보안 자격', '보안 교육', '보안 훈련', '보안 인력', '보안 인재', 
    '보안 팀', '보안 조직', '보안 컨설팅', '보안 자문', '보안 대응', '보안 복구', '보안 위험 관리', 
    '보안 위협', '위협 탐지', '위협 방지', '위협 분석', '위협 대응', '위협 완화', '위협 모니터링', 
    '위협 평가', '위협 예측', '위협 방어', '위협 차단', '위협 관리', '침해 탐지', '침해 방지', 
    '침해 분석', '침해 대응', '침해 완화', '침해 모니터링', '침해 평가', '침해 예측', '침해 방어', 
    '침해 차단', '침해 관리', '보안 운영 센터', 'SOC', '보안 관제', '보안 이벤트', '보안 사고', 
    '보안 사고 대응', '보안 사고 복구', '보안 사고 조사', '보안 사고 보고', '보안 사고 분석', 
    '보안 사고 평가', '보안 사고 모니터링', '보안 사고 관리', '보안 사고 예방', '보안 사고 방지', 
    '보안 사고 대응 전략', '보안 사고 대응 계획', '보안 사고 대응 체계', '보안 사고 대응 시스템', 
    '보안 사고 대응 팀', '보안 사고 대응 인력', '보안 사고 대응 자문', '보안 사고 대응 지원', 
    '보안 사고 대응 서비스', '보안 사고 대응 솔루션', '보안 사고 대응 도구', '보안 사고 대응 기술', 
    '보안 사고 대응 환경', '보안 사고 대응 장비', '보안 사고 대응 인프라', '보안 사고 대응 네트워크', 
    '보안 사고 대응 서버', '보안 사고 대응 데이터베이스', '보안 사고 대응 애플리케이션', '보안 사고 대응 플랫폼', 
    '보안 사고 대응 클라우드', '보안 사고 대응 모바일', '보안 사고 대응 웹', '보안 사고 대응 이메일', 
    '보안 사고 대응 메신저', '보안 사고 대응 통신', '보안 사고 대응 연결', '보안 사고 대응 장치', 
    '보안 사고 대응 장비', '보안 사고 대응 기기', '보안 사고 대응 솔루션 시스템', '보안 사고 대응 소프트웨어 시스템', 
    '보안 사고 대응 하드웨어 시스템', '보안 사고 대응 도구 시스템', '보안 사고 대응 기술 시스템', '보안 사고 대응 서비스 시스템', 
    '보안 사고 대응 운영 시스템', '보안 사고 대응 관리 시스템', '보안 사고 대응 모니터링 시스템', '보안 사고 대응 분석 시스템', 
    '보안 사고 대응 평가 시스템', '보안 사고 대응 감사 시스템', '보안 사고 대응 검사 시스템', '보안 사고 대응 정책 시스템', 
    '보안 사고 대응 규제 시스템', '보안 사고 대응 법률 시스템', '보안 사고 대응 표준 시스템', '보안 사고 대응 인증 시스템', 
    '보안 사고 대응 자격 시스템', '보안 사고 대응 교육 시스템', '보안 사고 대응 훈련 시스템', '보안 사고 대응 인력 시스템', 
    '보안 사고 대응 인재 시스템', '보안 사고 대응 팀 시스템', '보안 사고 대응 조직 시스템', '보안 사고 대응 컨설팅 시스템', 
    '보안 사고 대응 자문 시스템', '보안 사고 대응 복구 시스템', '보안 사고 대응 위협 탐지 시스템', '보안 사고 대응 위협 방지 시스템', 
    '보안 사고 대응 위협 분석 시스템', '보안 사고 대응 위협 대응 시스템', '보안 사고 대응 위협 완화 시스템', '보안 사고 대응 위협 모니터링 시스템', 
    '보안 사고 대응 위협 평가 시스템', '보안 사고 대응 위협 예측 시스템', '보안 사고 대응 위협 방어 시스템', '보안 사고 대응 위협 차단 시스템', 
    '보안 사고 대응 위협 관리 시스템'
]

# 연도 컬럼과 키워드가 포함된 타이틀의 개수를 저장할 딕셔너리 초기화
yearly_counts = {year: 0 for year in range(2013, 2025)}

# 각 연도별로 키워드가 포함된 타이틀의 개수를 계산
for index, row in df.iterrows():
    title = row['title']
    application_date = row['application_date']  # 연도 컬럼 이름이 'application_date'라고 가정
    if pd.notna(title) and pd.notna(application_date):
        year = int(str(application_date)[:4])  # 날짜의 앞 4자리를 연도로 추출
        if 2013 <= year <= 2024:
            for keyword in keywords:
                if keyword in title:
                    yearly_counts[year] += 1
                    break  # 한 번 카운트되면 다른 키워드는 확인하지 않음

print(yearly_counts)
# Out:
# {2013: 229, 2014: 517, 2015: 428, 2016: 413, 2017: 432, 2018: 434, 2019: 510, 2020: 634, 2021: 620, 2022: 567, 2023: 123, 2024: 11}

# %%
# 기술 유형별 키워드 리스트
keywords_dict = {
    '머신러닝': ['머신러닝', '기계 학습', '기계학습', 'Machine Learning', 'ML'],
    '딥러닝': ['딥러닝', '심층 학습', '심층학습', 'Deep Learning', 'DL'],
    '인공지능': ['인공지능', 'AI', 'Artificial Intelligence'],
    '컴퓨터 비전': ['컴퓨터 비전', 'Computer Vision', 'CV'],
    '자연어 처리': ['자연어 처리', 'Natural Language Processing', 'NLP'],
    '로봇공학': ['로봇공학', '로봇', 'Robotics'],
    '빅데이터': ['빅데이터', 'Big Data'],
    '사물인터넷': ['사물인터넷', 'IoT', 'Internet of Things'],
    '클라우드 컴퓨팅': ['클라우드 컴퓨팅', 'Cloud Computing'],
    '블록체인': ['블록체인', 'Blockchain'],
}

# 연도별로 기술 유형별 키워드가 포함된 타이틀의 개수를 저장할 딕셔너리 초기화
yearly_counts = {year: {tech: 0 for tech in keywords_dict.keys()} for year in range(2013, 2025)}

# 각 연도별로 기술 유형별 키워드가 포함된 타이틀의 개수를 계산
for index, row in df.iterrows():
    title = row['title']
    application_date = row['application_date']
    if pd.notna(title) and pd.notna(application_date):
        year = int(str(application_date)[:4])  # 날짜의 앞 4자리를 연도로 추출
        if 2013 <= year <= 2024:
            for tech, keywords in keywords_dict.items():
                if any(keyword.lower() in title.lower() for keyword in keywords):
                    yearly_counts[year][tech] += 1
                    break  # 한 번 카운트되면 다른 키워드는 확인하지 않음

# 결과 출력
for year, counts in yearly_counts.items():
    print(f"Year: {year}")
    for tech, count in counts.items():
        print(f"  {tech}: {count}")
# Out:
# Year: 2013
#   머신러닝: 15
#   딥러닝: 168
#   인공지능: 1630
#   컴퓨터 비전: 20
#   자연어 처리: 0
#   로봇공학: 85
#   빅데이터: 3
#   사물인터넷: 16
#   클라우드 컴퓨팅: 2
#   블록체인: 0
# Year: 2014
#   머신러닝: 23
#   딥러닝: 306
#   인공지능: 2548
#   컴퓨터 비전: 23
#   자연어 처리: 1
#   로봇공학: 148
#   빅데이터: 14
#   사물인터넷: 39
#   클라우드 컴퓨팅: 2
#   블록체인: 0
# Year: 2015
#   머신러닝: 34
#   딥러닝: 303
#   인공지능: 2488
#   컴퓨터 비전: 31
#   자연어 처리: 2
#   로봇공학: 152
#   빅데이터: 11
#   사물인터넷: 44
#   클라우드 컴퓨팅: 5
#   블록체인: 0
# Year: 2016
#   머신러닝: 52
#   딥러닝: 283
#   인공지능: 2490
#   컴퓨터 비전: 10
#   자연어 처리: 0
#   로봇공학: 190
#   빅데이터: 18
#   사물인터넷: 74
#   클라우드 컴퓨팅: 5
#   블록체인: 0
# Year: 2017
#   머신러닝: 96
#   딥러닝: 388
#   인공지능: 2746
#   컴퓨터 비전: 20
#   자연어 처리: 3
#   로봇공학: 216
#   빅데이터: 22
#   사물인터넷: 108
#   클라우드 컴퓨팅: 1
#   블록체인: 0
# Year: 2018
#   머신러닝: 159
#   딥러닝: 561
#   인공지능: 3392
#   컴퓨터 비전: 36
#   자연어 처리: 6
#   로봇공학: 296
#   빅데이터: 52
#   사물인터넷: 119
#   클라우드 컴퓨팅: 8
#   블록체인: 3
# Year: 2019
#   머신러닝: 232
#   딥러닝: 751
#   인공지능: 3930
#   컴퓨터 비전: 42
#   자연어 처리: 8
# ...

# %%
# 출원인 분류 키워드
applicant_dict = {
    '대기업': ['현대', 'HYUNDAI', '에이치디', '기아', 'KIA', '삼성', 'SAMSUNG', '엘지', 'LG', '한화', 'HANHWA', '엘에스', 'LS', '서울바이오시스', '린나이', '린나이코리아'],
    '연구기관': ['한국생산기술연구원', '한국과학기술연구원', '한국기계연구원', '한국에너지기술연구원', '한국건설기술연구원', '한국해양과학기술원', '한국전자통신연구원', 'ETRI', '한국세라믹기술원', '한국과학기술원', '한국지질자원연구원'],
    '대학교': ['가톨릭대학교', '서울대학교', '고려대학교', '연세대학교'],
    '해외': ['타이완세미컨덕터', 'TSMC', '캐논', '애플', '화웨이', '후아웨이', '인텔', '어플라이드 머티어리얼스', '도요타', '한도오따이 에네루기', '고베 세이코쇼', '도쿄엘렉트론', '퀄컴', '마이크론', '도레이', '후지', '도시바'],
    '기타': []
}

# 출원인을 분류할 함수
def classify_applicant(applicant):
    for category, keywords in applicant_dict.items():
        for keyword in keywords:
            if keyword.lower() in applicant.lower():
                return category
    return '기타'  # 키워드에 없는 출원인은 '기타'로 분류

# 각 출원인을 분류하여 새로운 열에 저장
df['category'] = df['applicant'].apply(classify_applicant)

# 각 분류별 개수 계산
category_counts = df['category'].value_counts()
# 결과 출력
print(category_counts)
# Out:
# category
# 기타      218560
# 대기업      90435
# 해외       26119
# 연구기관     24454
# 대학교       4644
# Name: count, dtype: int64

# %%
# 출원인별 키워드 리스트
applicants_dict = {
    '현대': ['현대', 'HYUNDAI', '에이치디'],
    '기아': ['기아', 'KIA'],
    '삼성': ['삼성', 'SAMSUNG'],
    '엘지': ['엘지', 'LG'],
    '한화': ['한화', 'HANHWA'],
    '엘에스': ['엘에스', 'LS'],
    '서울바이오시스': ['서울바이오시스', 'SEOUL VIOSYS'],
    '린나이코리아': ['린나이', 'RINNAI KOREA'],
    '한국 생산기술 연구원': ['한국 생산기술 연구원', 'KOREA INSTITUTE OF INDUSTRIAL TECHNOLOGY'],
    '한국과학기술연구원': ['한국과학기술연구원', 'KOREA INSTITUTE OF SCIENCE AND TECHNOLOGY'],
    '한국 기계 연구원': ['한국 기계 연구원', 'KOREA INSTITUTE OF MACHINERY AND MATERIALS'],
    '한국 에너지 기술 연구원': ['한국 에너지 기술 연구원', 'KOREA INSTITUTE OF ENERGY RESEARCH'],
    '한국 건설 기술 연구원': ['한국 건설 기술 연구원', 'KOREA INSTITUTE OF CIVIL ENGINEERING AND BUILDING TECHNOLOGY'],
    '한국해양과학기술원': ['한국해양과학기술원', 'KOREA INSTITUTE OF OCEAN SCIENCE AND TECHNOLOGY'],
    '한국전자통신 연구원 (ETRI)': ['한국전자통신 연구원', 'ETRI', 'ELECTRONICS AND TELECOMMUNICATIONS RESEARCH INSTITUTE'],
    '한국세라믹기술원': ['한국세라믹기술원', 'KOREA INSTITUTE OF CERAMIC ENGINEERING AND TECHNOLOGY'],
    '한국과학기술원': ['한국과학기술원', 'KOREA ADVANCED INSTITUTE OF SCIENCE AND TECHNOLOGY', 'KAIST'],
    '한국 지질 자원 연구원': ['한국 지질 자원 연구원', 'KOREA INSTITUTE OF GEOSCIENCE AND MINERAL RESOURCES'],
    '가톨릭대학교': ['가톨릭대학교', 'CATHOLIC UNIVERSITY'],
    '서울대학교': ['서울대학교', 'SEOUL NATIONAL UNIVERSITY'],
    '고려대학교': ['고려대학교', 'KOREA UNIVERSITY'],
    '연세대학교': ['연세대학교', 'YONSEI UNIVERSITY'],
    '그외(벤처/중소)': [],  # 나중에 벤처/중소기업 확인
    '타이완세미컨덕터 (TSMC)': ['타이완세미컨덕터', 'TSMC', 'TAIWAN SEMICONDUCTOR MANUFACTURING COMPANY'],
    '캐논': ['캐논', 'CANON'],
    '애플': ['애플', 'APPLE'],
    '화웨이 (후아웨이)': ['화웨이', '후아웨이', 'HUAWEI'],
    '인텔': ['인텔', 'INTEL'],
    '어플라이드 머티어리얼스': ['어플라이드 머티어리얼스', 'APPLIED MATERIALS'],
    '도요타': ['도요타', 'TOYOTA'],
    '한도오따이 에네루기': ['한도오따이 에네루기', 'HANDAOTAI ENERGY'],
    '고베 세이코쇼': ['고베 세이코쇼', 'KOBE STEEL'],
    '도쿄엘렉트론': ['도쿄엘렉트론', 'TOKYO ELECTRON'],
    '퀄컴': ['퀄컴', 'QUALCOMM'],
    '마이크론': ['마이크론', 'MICRON'],
    '도레이': ['도레이', 'TORAY'],
    '후지': ['후지', 'FUJI'],
    '도시바': ['도시바', 'TOSHIBA']
}

# 출원인별로 특허 개수를 저장할 딕셔너리 초기화
applicant_counts = {applicant: 0 for applicant in applicants_dict.keys()}

# 각 출원인의 특허 개수를 계산
for index, row in df.iterrows():
    applicant = row['applicant']
    if pd.notna(applicant):
        applicant = str(applicant).lower()
        found = False
        for applicant_key, keywords in applicants_dict.items():
            if any(keyword.lower() in applicant for keyword in keywords):
                applicant_counts[applicant_key] += 1
                found = True
                break
        if not found:
            applicant_counts['그외(벤처/중소)'] += 1

# 결과 출력
for applicant, count in applicant_counts.items():
    print(f"{applicant}: {count}")
# Out:
# 현대: 55509
# 기아: 136
# 삼성: 18066
# 엘지: 9818
# 한화: 4018
# 엘에스: 1073
# 서울바이오시스: 931
# 린나이코리아: 884
# 한국 생산기술 연구원: 0
# 한국과학기술연구원: 4457
# 한국 기계 연구원: 0
# 한국 에너지 기술 연구원: 0
# 한국 건설 기술 연구원: 0
# 한국해양과학기술원: 1780
# 한국전자통신 연구원 (ETRI): 0
# 한국세라믹기술원: 1577
# 한국과학기술원: 1271
# 한국 지질 자원 연구원: 0
# 가톨릭대학교: 1685
# 서울대학교: 1021
# 고려대학교: 1052
# 연세대학교: 886
# 그외(벤처/중소): 233929
# 타이완세미컨덕터 (TSMC): 0
# 캐논: 4321
# 애플: 2881
# 화웨이 (후아웨이): 1951
# 인텔: 2986
# 어플라이드 머티어리얼스: 1578
# 도요타: 2597
# 한도오따이 에네루기: 1089
# 고베 세이코쇼: 1047
# 도쿄엘렉트론: 899
# 퀄컴: 1826
# 마이크론: 955
# 도레이: 1705
# 후지: 1275
# 도시바: 1009

# %%
# 중복 특허 확인
duplicate_patents = df[df['priority_date'].notnull()]
num_duplicate_patents = len(duplicate_patents)

# 국제 출원 특허 확인
international_patents = df[df['international_filing_date'].notnull()]
num_international_patents = len(international_patents)

# 결과 출력
print(f"중복 특허 개수: {num_duplicate_patents}")
print(f"국제 출원 특허 개수: {num_international_patents}")
# Out:
# 중복 특허 개수: 147903
# 국제 출원 특허 개수: 101183
