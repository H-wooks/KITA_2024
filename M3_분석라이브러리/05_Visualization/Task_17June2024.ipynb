# %% [markdown]
# Task1_0617. 선그래프, 히스토그램, 산점도, 막대그래프 4개의 subplot으로 구성된 2 x 2 그래프를 작성하세요.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

filepath='/content/drive/MyDrive/KITA_2024/M3_분석라이브러리/01_Pandas/dataset/auto-mpg.xlsx'
df=pd.read_excel(filepath, engine='openpyxl')

# %%
df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
df.groupby('model year')['cylinders'].mean()
# Out:
# model year
# 70    6.758621
# 71    5.571429
# 72    5.821429
# 73    6.375000
# 74    5.259259
# 75    5.600000
# 76    5.647059
# 77    5.464286
# 78    5.361111
# 79    5.827586
# 80    4.137931
# 81    4.620690
# 82    4.193548
# Name: cylinders, dtype: float64

# %%
df.groupby('cylinders')['mpg'].mean()
# Out:
# cylinders
# 3    20.550000
# 4    29.286765
# 5    27.366667
# 6    19.985714
# 8    14.963107
# Name: mpg, dtype: float64

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Create a 2x2 subplot layout
fig, axes = plt.subplots(2, 2, figsize=(12, 10))

# First subplot (line plot of average MPG by model year)
df.groupby('model year')['mpg'].mean().plot(kind='line', marker='o', color='b', linestyle='-', linewidth=2, markersize=8, ax=axes[0,0])
axes[0, 0].set_title('Line Plot (Average MPG by Model Year)')
axes[0, 0].set_xlabel('Model Year')
axes[0, 0].set_ylabel('Average of MPG')

# Second subplot (histogram of MPG)
df['mpg'].plot(kind='hist', bins=100, ax=axes[0,1], title='Histogram of MPG')
axes[0, 1].set_xlabel('MPG')
axes[0, 1].set_ylabel('Frequency')

# Third subplot (scatter plot of MPG vs. Weight)
axes[1, 0].scatter(df['weight'], df['mpg'], alpha=0.5)  # Scatter plot requires `scatter` method
axes[1, 0].set_title('Scatter Plot (MPG vs. Weight)')
axes[1, 0].set_xlabel('Weight')
axes[1, 0].set_ylabel('MPG')

# Fourth subplot (box plot of displacement)
df['displacement'].plot(kind='box', ax=axes[1, 1])
axes[1, 1].set_title('Box Plot of Displacement')
axes[1, 1].set_ylabel('Displacement')

# Adjust layout and display the plot
plt.tight_layout()
plt.show()

# %%
fig=plt.figure(figsize=(12,10))
ax1=fig.add_subplot(2,2,1)
ax2=fig.add_subplot(2,2,2)
ax3=fig.add_subplot(2,2,3)
ax4=fig.add_subplot(2,2,4)
ax1.plot(df.groupby('model year')['mpg'].mean())
ax2.hist(df['mpg'], bins=100,alpha=0.5)
ax3.scatter(df['weight'], df['mpg'], alpha=0.5)
ax4.boxplot(df['displacement'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7d6de53f1db0>,
#   <matplotlib.lines.Line2D at 0x7d6de53f2050>],
#  'caps': [<matplotlib.lines.Line2D at 0x7d6de53f22f0>,
#   <matplotlib.lines.Line2D at 0x7d6de53f2590>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7d6de53f1b10>],
#  'medians': [<matplotlib.lines.Line2D at 0x7d6de53f27a0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7d6de53f2a40>],
#  'means': []}
