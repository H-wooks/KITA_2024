# %%
### 1.  시작 인터페이스
### PachinkoByMin-Jin-Lee
### 청천벽력ByShogo-Kawashima
### TwilightByStephenieMeyer
### 편지ByNatsume-Soseki
### TheNameOfTheRoseByUmbertoEco

# ### 외부 라이브러리인 googletrans 설치 여부 확인
# !pip list | grep googletrans
# ### 외부 라이브러리 googletrans가 install되어 있지 않으면, Package-Installer-of-python로부터 아래 구글 번역 라이브러리 install
# !pip install googletrans==4.0.0rc1
# ### install된 구글 번역 라이브러리 정보 double-Check
# !pip show googletrans


# ### 외부 라이브러리인 Google Text to Speech API 설치 여부 확인
# !pip list | grep gTTS
# ### 외부 라이브러리 googletrans가 install되어 있지 않으면, Package-Installer-of-python로부터 아래 구글 번역 라이브러리 install
# !pip install gTTS
# ### install된 구글 번역 라이브러리 정보 double-Check
# !pip show gTTS


# ### 외부 라이브러리인 Play Sound 설치 여부 확인
# !pip list | grep playsound
# ### 외부 라이브러리 Play Sound가 되어 있지 않으면, Package-Installer-of-python로부터 아래 구글 번역 라이브러리 install
# !pip install playsound
# ### install된 Play Sound 라이브러리 정보 double-Check
# !pip show playsound

deletingEntry=['the', 'when', 'two', 'twenty-eight', 'something', 'beside', 'want', 'eldest', 'of', 'near', 'next', 'mother', 'both', 'hands', 'eyes', 'have-this', 'like', 'for', 'son', 'some',
               '1911', 'legs', 'too', 'this','his', 'help', 'but', 'from', 'couldnt', 'wrong', 'girls','after', 'with','sons','washed', 'walk', 'lost', 'again', 'about', 'knew', 'never', 'a', 'extra',
               'at', 'just', 'that', 'her', 'having', 'old', 'middle', 'read', 'same', 'cold', 'one', 'did', 'foot;',  'korea', 'long', 'moved', 'kitchen;', 'didnt', 'happens', 'weak—the', 'orphans—were',
               'well', 'late', 'who', 'run', 'sleeping',  'an', 'korean', 'hoonies', 'aging', 'make', 'over', 'yeongdo', 'as','three', 'golden', 'made', 'himthe', 'themselves', 'father', 'wife', 'feet',
               'lived', 'on', 'koreahistory', 'work', 'daughter', 'larger', 'full', 'being', 'would', 'mouth', 'him',  'not', 'were', 'she', 'lodgersthe', 'other', 'have', 'sons—', 'way', 'cup', 'head',
               'increase', 'quicklyboth', 'along', 'couple', 'girl', 'no', 'worked', 'whod', 'than', 'him', 'let', 'he', 'habit', 'outdoor', 'keep', 'city', 'front', 'loved', 'twenty-seven', 'life', 'had',
               'needed', 'talk', 'strong', 'ricein', 'evening', 'japanese', 'how','their', 'to', 'could', 'know', 'eventually', 'paper', 'in', 'hot', 'most', 'fathers', 'write', 'however', 'stone', 'close',
               'countries', 'yet', 'survived', 'turn', 'man', 'avoided', 'its', 'benefit', 'wallat', 'seen', 'hundred', 'known', 'finished', 'called', 'generation', 'mild', 'well-shaped', 'share', 'century',
               'sums', 'wooden', 'pointless', 'resembled', 'twice', 'number', 'inky', 'peasants', 'things', 'guessed', 'quickly', 'has', 'rent', 'gave', 'home', 'there', 'up', 'born', 'heart', 'village',
               'snug', 'low', 'child', 'fathom', 'vegetable', 'decided', 'rivals', 'learned', 'someone', 'dining', 'say', 'busan', 'asked', 'steady', 'nimble', 'twisted', 'be', '1910', 'wanted', 'families',
               'thinking', 'because', 'carry', 'out', 'gone', 'birth', 'so', 'tables', 'what', 'i', 'and', 'raised', 'growing', 'stay', 'day', 'morning', 'rooms', 'spring', 'money', 'build', 'through', 'since',
               'elderly', 'years', 'hoonie', 'fisherman', 'us', 'himself', 'slept', 'take', 'do', 'by', 'they',  'possible', 'nature', 'it', 'five-mile-wide', 'house', 'even', 'young', 'more', 'japan', 'age',
               'any', 'doors', 'yeongdo—a', 'only', 'hardy', 'was', 'five', 'youngest', 'kitchen', 'bed', 'such','or','large','parents','lodgers', 'hed', 'weeks']

import googletrans
from gtts import gTTS
import playsound as ps
import os
import re
import pickle
import random
curpath='/content/drive/MyDrive/00_KITA_2404/M2_Program'
os.chdir(curpath)

str1="Welcome to Our Translation/Voiceenabled Program"
str2="\t\t용도 및 목적: 외국어 원문 Reading 학습을 위한 번역 및 Listening 학습을 위한 원어 음성 파일 생성 "
str3='\t\t기능:'
str4='\t\t(i) 사용자 입력 TEXT (1. sample-TEXTs, 2. File-Input, 3. Text-Input Window)로 부터 원하는 언어로 번역'
str5='\t\t(ii) 번역된 언어를 음성 파일(MP3)로 변환하여 Listening 반복 학습 기능 제공'
str6='\t\t(iii) 사용자 입력 외국어 원문으로부터 빈출 단어를 추출하여 사용자에게 제공하여 학습 효율 개선'
langs=['한국어','영어','일본어','중국어-간체','중국어-번체','러시아어','프랑스어','독일어','이탈리아어','스페인','베트남어','태국','인도시아어','체코어','덴마크','그리스어']
langCodes=['ko','en','ja','zh-CN','zh-TW','ru','fr','de','it','es','vi','th','id','cs','da','el']

class TransSpeech:

  def InitDisp(self):
    print("#"*200,end='');
    for i in range(2): print("\n##"+" "*195,"##",end='')
    print(f'\n##{str1:^195} ##',end='')
    for i in range(2): print("\n##"+" "*195,"##",end='')
    print(f'\n##{str2:<152} ##',end='')
    for i in range(2): print("\n##"+" "*195,"##",end='')
    print(f'\n##{str3:<181} ##',end='')
    print(f'\n##{str4:<167} ##',end='')
    print(f'\n##{str5:<160} ##',end='')
    print(f'\n##{str6:<145} ##',end='')
    for i in range(2): print("\n##"+" "*195,"##",end='')
    i=1
    for lang in langs:
          if i%8==1: print("\n##  ",end="")
          print(f"{i:<2}:\t{lang:<15}",end="")
          if i%8==0: print(" "*49+"##",end="")
          i += 1
    for i in range(4): print("\n##"+" "*195,"##",end='')
    print('\n'+"#"*200);

  def ProvidedLangs(self):
    i=1; print("\n"+"#"*20,"지원 원어")
    for lang in langs:
      print(f"{i:>2}:\t{lang:<15}",end="")
      if i%8==0: print();
      i += 1


  def TextLoad(self):
    TEXT_DB={1:'/content/drive/MyDrive/00_KITA_2404/M2_Program/TEXTs/Pachinko_ByMinJinLee.txt',2:'/content/drive/MyDrive/00_KITA_2404/M2_Program/TEXTs/ABoltfromtheBlue_ByShogoKawashima.txt', 3:'/content/drive/MyDrive/00_KITA_2404/M2_Program/TEXTs/Twilight_ByStephenieMeyer.txt'}
    print("\n"+"=="*60)
    print("1. 기본 제공 Sample:(영문소설)파친코\n")
    print("2. 기본 제공 Sample:(일문소설)청천벽력\n")
    print("3. 기본 제공 Sample:(영문소설)Twilight\n")
    print("4. Loading Text File(Entered The File-Path;ex:/content/drive/MyDrive/00_KITA_2404/M2_Program/TEXTs/Letter_ByNatsumeSoseki.txt)\n")
    print("5. Directly Type the TEXT string in the following input window\n")
    selectedInput = int(input(f"***** TEXT를 불러올 방법을 선택하세요 (1~5) >>> "))
    if 1 <= selectedInput <= 3:
      with open(TEXT_DB[selectedInput], 'r') as f:
        textString = f.read()
    elif selectedInput == 4:
      textFile = input(f"***** 읽어들일 TEXT 파일의 path를 입력하세요 >>> ")
      with open(textFile, 'r') as f:
        textString = f.read()
    elif selectedInput == 5:
      textString = input(f"***** 읽어들일 문자열을 직접 입력하세요 >>> ")
    return textString

  def TransString(self, textString):
    transObj = googletrans.Translator()
    self.ProvidedLangs()
    inText = int(input(f"\n***** 입력된 문자열의 언어를 선택하세요 (1-16 선택, 자동으로 인식하고자 할 경우 17) >>> "))
    if 1 <= inText <= 16:
      inLang=langCodes[inText-1]
    elif inText == 17:
      inLang='auto'
    else: print("\n**** 올바른 입력 언어를 선택하세요!")
    outText = int(input(f"\n***** 출력하고자 하는 언어를 선택하세요 (1-16 선택) >>> "))
    if 1 <= outText <= 16:
      outLang=langCodes[outText-1]
    else: print("\n**** 올바른 출력 언어를 선택하세요!")
    translatedString = transObj.translate(textString, dest=outLang, src=inLang)
    transOut=translatedString.text
    detectedInLan=translatedString.src
    inLang=detectedInLan
    print("\n"*2,transOut)
    saveTextYN = input(f"\n***** 번역된 TEXT를 저장할까요 (Y/N)? >>> ").lower()
    if saveTextYN == "y":
      saveText = input(f"\n***** 저장할 파일의 경로와 파일명을 입력하세요(/content/drive/MyDrive/00_KITA_2404/M2_Program/translatedText.txt) >>> ")
      with open(saveText,'wb') as f:
        pickle.dump(transOut,f)
      print(f"생성된 번역 TEXT가 {saveText}에 저장되었습니다.")
    #print(data)
    return textString, transOut, inLang, outLang

  def TextToSpeech(self, textString, inLang):
    tts = gTTS(text=textString, lang=inLang)
    saveAudioYN = input(f"\n***** 생성된 오디오 파일을 저장할까요 (Y/N)? >>> ").lower()
    if saveAudioYN == "y":
      saveAudio = input(f"\n***** 저장할 오디오 파일의 경로/파일명을 입력하세요(/content/drive/MyDrive/00_KITA_2404/M2_Program/translatedAudio.mp3) >>> ")
      tts.save(saveAudio)
      print(f"생성된 오디오 파일이 {saveAudio}에 저장되었습니다.")
    #ps.playsound(outMP3)

  def VocaBook(self, textString,inLagn,outLang):
    words_list=re.sub(r'[.,!#\n\';:]', '', textString).lower()
    words_list = words_list.split()
    words_set=set(words_list); words_db={}
    for W in words_set:
      words_db[W]=words_list.count(W)
    words_db2=sorted(words_db.items(), key=lambda x: -x[1])    ### .item으로 부르니까 얘는 list안에 tuple형태로 out된다.
    i=1
    nomVocas = int(input(f"\n***** 생성할 단어 개수를 입력하세요 >>> "))
    saveVocas = input(f"\n***** 저장할 단어장의 경로/파일명을 입력하세요(/content/drive/MyDrive/00_KITA_2404/M2_Program/VocaSummary.txt) >>> ")
    transObj2 = googletrans.Translator()
    print("\n\n","#"*58,'\n',"#"*24,"단 어 장","#"*24, "\n","#"*58)
    f_voca = open(saveVocas,'w')
    vocaDB={}
    for ckey in words_db2:
      if ckey[0] not in deletingEntry:
        if i <= nomVocas:
          translatedVoca=transObj2.translate(ckey[0], dest=outLang, src=inLang).text
          f_voca.write(ckey[0]+"\t"*2+translatedVoca+'\n')
          print(f" {ckey[0]:<10}\t\t{translatedVoca:<10}")
          vocaDB[ckey[0]]=translatedVoca
        i += 1
    f_voca.close()
    return vocaDB

  def Quiz(self, vocaDB):
    listKeys=list(vocaDB.keys())
    correct_no=0; wrong_no=0;
    i=1
    for voca in vocaDB:
      listKeys.remove(voca)
      sampling4=random.sample(listKeys,3)
      sampling4.append(voca); random.shuffle(sampling4)
      answer=sampling4.index(voca)+1
      print("\n ","#"*25,"\n ","#"*7,f"Quiz({i})번","#"*7,"\n ","#"*25,"\n ","="*80)
      reply=int(input(f"  {voca}:   (1)  {vocaDB[sampling4[0]]}   (2)  {vocaDB[sampling4[1]]}   (3)  {vocaDB[sampling4[2]]}   (4)  {vocaDB[sampling4[3]]} >> "))
      print(" ","="*80)
      listKeys.append(voca)
      if reply == answer:
        print(f"  정답입니다.\n"); correct_no += 1
      else: print(f"  오답입니다.\n"); wrong_no += 1
      i += 1
    print(f"  !!!! 수고하셨습니다. {correct_no+wrong_no}문항 중 {correct_no}문항 맞추셨습니다 !!!!!!!!!.\n")


obj1=TransSpeech()
obj1.InitDisp()
textString=obj1.TextLoad()
textString, transOut,inLang, outLang=obj1.TransString(textString)
genAudioYN = input(f"\n***** 음성 파일을 생성할까요 (Y/N)? >>> ").lower()
if genAudioYN == "y":
  obj1.TextToSpeech(textString, inLang)
vocaDB=obj1.VocaBook(textString,inLang,outLang)
obj1.Quiz(vocaDB)
# Out:
# ########################################################################################################################################################################################################
# ##                                                                                                                                                                                                    ##
# ##                                                                                                                                                                                                    ##
# ##                                                                          Welcome to Our Translation/Voiceenabled Program                                                                           ##
# ##                                                                                                                                                                                                    ##
# ##                                                                                                                                                                                                    ##
# ##		용도 및 목적: 외국어 원문 Reading 학습을 위한 번역 및 Listening 학습을 위한 원어 음성 파일 생성                                                                                       ##
# ##                                                                                                                                                                                                    ##
# ##                                                                                                                                                                                                    ##
# ##		기능:                                                                                                                                                                                 ##
# ##		(i) 사용자 입력 TEXT (1. sample-TEXTs, 2. File-Input, 3. Text-Input Window)로 부터 원하는 언어로 번역                                                                                 ##
# ##		(ii) 번역된 언어를 음성 파일(MP3)로 변환하여 Listening 반복 학습 기능 제공                                                                                                            ##
# ##		(iii) 사용자 입력 외국어 원문으로부터 빈출 단어를 추출하여 사용자에게 제공하여 학습 효율 개선                                                                                         ##
# ##                                                                                                                                                                                                    ##
# ##                                                                                                                                                                                                    ##
# ##  1 :	한국어            2 :	영어             3 :	일본어            4 :	중국어-간체         5 :	중국어-번체         6 :	러시아어           7 :	프랑스어           8 :	독일어                                                             ##
# ##  9 :	이탈리아어          10:	스페인            11:	베트남어           12:	태국             13:	인도시아어          14:	체코어            15:	덴마크            16:	그리스어                                                            ##
# ##                                                                                                                                                                                                    ##
# ##                                                                                                                                                                                                    ##
# ##                                                                                                                                                                                                    ##
# ##                                                                                                                                                                                                    ##
# ########################################################################################################################################################################################################
#
# ========================================================================================================================
# 1. 기본 제공 Sample:(영문소설)파친코
#
# 2. 기본 제공 Sample:(일문소설)청천벽력
#
# 3. 기본 제공 Sample:(영문소설)Twilight
#
# 4. Loading Text File(Entered The File-Path;ex:/content/drive/MyDrive/00_KITA_2404/M2_Program/TEXTs/Letter_ByNatsumeSoseki.txt)
#
# 5. Directly Type the TEXT string in the following input window
#
# ***** TEXT를 불러올 방법을 선택하세요 (1~5) >>> 1
#
# #################### 지원 원어
#  1:	한국어             2:	영어              3:	일본어             4:	중국어-간체          5:	중국어-번체          6:	러시아어            7:	프랑스어            8:	독일어
#  9:	이탈리아어          10:	스페인            11:	베트남어           12:	태국             13:	인도시아어          14:	체코어            15:	덴마크            16:	그리스어
#
# ***** 입력된 문자열의 언어를 선택하세요 (1-16 선택, 자동으로 인식하고자 할 경우 17) >>> 2
#
# ***** 출력하고자 하는 언어를 선택하세요 (1-16 선택) >>> 1
#
#
#  I. Yeongdo, 부산, 한국.
# 역사는 우리를 실패했지만 상관 없습니다.
# 세기 초에 노후 한 어부와 그의 아내는 추가 돈을 위해 숙소를 데려 가기로 결정했습니다.둘 다 Yeongdo의 어촌 마을에서 태어나고 자랐습니다. 항구 도시 부산 옆에있는 5 마일 너비의 섬.그들의 긴 결혼 생활에서 아내는 세 명의 아들을 낳았지만 장남이자 가장 약한 사람만이 살아 남았습니다.Hoonie는 갈라진 구개와 뒤틀린 발로 태어났습니다.그러나 그는 어깨, 쪼그리고 앉은 건물, 황금색의 안색을 부여 받았다.젊은이로서 그는 어렸을 때 가혹하고 사려 깊은 기질을 유지했습니다.Hoonie는 자신의 손으로 그의 손으로 입을 가렸을 때, 습관을 만나는 낯선 사람을 만나는 일을했을 때, 그는 같은 크고 웃는 눈을 가진 그의 멋진 아버지와 비슷했습니다.혹독한 눈썹은 그의 넓은 이마를 장식하여 야외 작업에서 끊임없이 무두질했습니다.그의 부모와 마찬가지로, Hoonie는 민첩한 화자가 아니었고, 일부는 빨리 말할 수 없기 때문에 마음에 문제가 있었지만 사실은 아니라고 생각하는 실수를 저질렀습니다.
# 1910 년 Hoonie가 27 세였던 일본은 한국을 합병했습니다.어부와 그의 아내 인 Thrifty and Hardy 농민은 도둑에게 국가를 잃은 나라의 무능한 귀족과 부패한 통치자들에 의해 산만 해지기를 거부했습니다.집의 임대료가 다시 자랐을 때 부부는 침실에서 나와 부엌 근처의 전통에서 잤다.
# 그들이 30 년 이상 임대 한 나무 집은 크지 않았으며 500 평방 피트의 부끄러워했습니다.슬라이딩 페이퍼 문은 내부를 3 개의 아늑한 방으로 나누었고, 어부들은 부산의 저택에서 화려함에 살았던 그의 집주인의 이익으로 붉은 점토 타일로 새는 잔디 지붕을 대체했습니다.결국, 부엌은 야채 정원으로 밀려 나고 더 큰 요리 냄비와 모르타르의 돌담을 따라 페그에 매달린 휴대용 식탁 수를 늘 렸습니다.
# 그의 아버지의 주장에 따라, Hoonie는 Boardinghouse 원장을 유지하고 시장에서 속임수를 쓰지 않아서 머리에 합을 걸기에 충분히 마을 학교 장에서 한국과 일본어를 읽고 쓰는 법을 배웠습니다.그가 이것을하는 방법을 알았을 때, 그의 부모는 그를 학교에서 끌어 내 렸습니다.청소년으로서, Hoonie는 두 번의 잘 형성된 다리로 나이를 두 배나 강한 사람처럼 거의 일했습니다.그는 손에 덱스테르가 있었고 무거운 짐을 싣지 못했지만 빨리 달리거나 걸을 수 없었습니다.
# Hoonie와 그의 아버지는 마을에서 와인 한 잔을 집어 들지 않는 것으로 알려졌습니다.어부와 그의 아내는 살아남은 아들 인 동네를 구두어 영리하고 부지런히 일으켰습니다. 왜냐하면 그들은 죽은 후 누가 그를 돌보는 지 몰랐기 때문입니다.
# 한 남자와 그의 아내가 한 마음을 공유 할 수 있다면, Hoonie는이 꾸준한 장기였습니다.그들은 다른 아들들을 잃어 버렸습니다. 막내에서 홍역과 중간에, 중간에, 무의미한 사고로 Goring Bull에게 좋은 사람을 잃었습니다.학교와 시장을 제외하고, 노인 부부는 젊은 Hoonie를 집 옆에 가깝게 유지했으며, 결국 청년으로서 Hoonie는 부모를 돕기 위해 집에 머물러야했습니다.그들은 그를 실망시킬 수 없었다.그러나 그들은 그를 그를 데트하지 않을 정도로 그를 사랑했습니다.
# 농민들은 버릇없는 아들이 죽은 사람보다 가족에게 더 많은 해를 끼쳤다는 것을 알고 있었고, 그들은 그를 너무 많이 탐닉하지 못했습니다.
# 그 땅의 다른 가족들은 두 명의 현명한 부모를 두는 것만 큼 운이 좋지 않았으며, 경쟁자 나 자연에 의해 약탈당하는 나라에서 발생하는 것처럼, 노인, 과부, 고아는 식민지 반도에서 그 어느 때보 다 절망적이었습니다.하나 더 먹이를 줄 수있는 모든 가정의 경우, 보리 쌀 한 그릇을 위해 하루 종일 일할 의향이있었습니다.
# Hoonie가 28 살이 된 지 2 주 후인 1911 년 봄, 마을의 붉은 뺨 매치 메이커는 그의 어머니를 불렀습니다.
# Hoonie의 어머니는 매치 메이커를 부엌으로 이끌었습니다.하숙인들이 앞 방에서 자고 있었기 때문에 그들은 낮은 색조로 말해야했습니다.늦은 아침이었고 저녁에 낚시를 한 숙소들은 뜨거운 만남을 마치고 씻어서 잠자리에 들었습니다.Hoonie의 어머니는 매치 메이커에게 차가운 보리 차 한 잔을 부었지만 자신의 일에서 벗어나지 않았습니다.
# 당연히, 어머니는 매치 메이커가 원하는 것을 추측했지만, 그녀는 무엇을 말할지 추측 할 수 없었습니다.Hoonie는 부모에게 신부를 요구 한 적이 없습니다.괜찮은 가족이 딸이 기형으로 누군가와 결혼하게하는 것은 생각할 수 없었습니다.그녀는 아들이 여자와 이야기하는 것을 본 적이 없다.대부분의 마을 소녀들은 그를 시력을 피했으며, Hoonie는 그가 가질 수없는 것을 원하지 않을 정도로 충분히 알고 있었을 것입니다.이 관용은 평범한 농민이 자신의 삶과 그가 원하는 것을 받아 들였을 것입니다.
#
# ***** 번역된 TEXT를 저장할까요 (Y/N)? >>> y
#
# ***** 저장할 파일의 경로와 파일명을 입력하세요(/content/drive/MyDrive/00_KITA_2404/M2_Program/translatedText.txt) >>> /content/drive/MyDrive/00_KITA_2404/M2_Program/translatedText.txt
# 생성된 번역 TEXT가 /content/drive/MyDrive/00_KITA_2404/M2_Program/translatedText.txt에 저장되었습니다.
#
# ***** 음성 파일을 생성할까요 (Y/N)? >>> y
#
# ***** 생성된 오디오 파일을 저장할까요 (Y/N)? >>> y
#
# ***** 저장할 오디오 파일의 경로/파일명을 입력하세요(/content/drive/MyDrive/00_KITA_2404/M2_Program/translatedAudio.mp3) >>> /content/drive/MyDrive/00_KITA_2404/M2_Program/translatedAudio.mp3
# 생성된 오디오 파일이 /content/drive/MyDrive/00_KITA_2404/M2_Program/translatedAudio.mp3에 저장되었습니다.
#
# ***** 생성할 단어 개수를 입력하세요 >>> 20
#
# ***** 저장할 단어장의 경로/파일명을 입력하세요(/content/drive/MyDrive/00_KITA_2404/M2_Program/VocaSummary.txt) >>> /content/drive/MyDrive/00_KITA_2404/M2_Program/VocaSummary.txt
#
#
#  ##########################################################
#  ######################## 단 어 장 ########################
#  ##########################################################
#  matchmaker		결혼 중매인
#  enough    		충분한
#  kept      		유지된
#  barley    		보리
#  speak     		말하다
#  school    		학교
#  market    		시장
#  family    		가족
#  fortunate 		운이 좋다
#  pushed    		밀렸다
#  picking   		선발
#  hefty     		무거운
#  retained  		유지
#  tiles     		타일
#  tanned    		검게 그을린
#  bowl      		그릇
#  turned    		돌린
#  decades   		수십 년
#  clever    		영리한
#  meeting   		회의
#
#   #########################
#   ####### Quiz(1)번 #######
#   #########################
#   ================================================================================
#   matchmaker:   (1)  결혼 중매인   (2)  선발   (3)  영리한   (4)  그릇 >> 1
#   ================================================================================
#   정답입니다.
#
#
#   #########################
#   ####### Quiz(2)번 #######
#   #########################
#   ================================================================================
#   enough:   (1)  돌린   (2)  보리   (3)  타일   (4)  충분한 >> 4
#   ================================================================================
#   정답입니다.
#
#
#   #########################
#   ####### Quiz(3)번 #######
#   #########################
#   ================================================================================
#   kept:   (1)  타일   (2)  시장   (3)  유지된   (4)  보리 >> 3
#   ================================================================================
#   정답입니다.
#
#
#   #########################
#   ####### Quiz(4)번 #######
#   #########################
#   ================================================================================
#   barley:   (1)  선발   (2)  유지   (3)  검게 그을린   (4)  보리 >> 4
#   ================================================================================
#   정답입니다.
#
#
#   #########################
#   ####### Quiz(5)번 #######
#   #########################
#   ================================================================================
#   speak:   (1)  보리   (2)  충분한   (3)  타일   (4)  말하다 >> 4
#   ================================================================================
#   정답입니다.
#
#
#   #########################
#   ####### Quiz(6)번 #######
#   #########################
#   ================================================================================
#   school:   (1)  가족   (2)  학교   (3)  선발   (4)  유지 >> 2
#   ================================================================================
#   정답입니다.
#
#
#   #########################
#   ####### Quiz(7)번 #######
#   #########################
#   ================================================================================
#   market:   (1)  운이 좋다   (2)  유지된   (3)  시장   (4)  보리 >> 3
#   ================================================================================
#   정답입니다.
#
#
#   #########################
#   ####### Quiz(8)번 #######
#   #########################
#   ================================================================================
#   family:   (1)  유지   (2)  유지된   (3)  충분한   (4)  가족 >> 4
#   ================================================================================
#   정답입니다.
#
#
#   #########################
#   ####### Quiz(9)번 #######
#   #########################
#   ================================================================================
#   fortunate:   (1)  운이 좋다   (2)  무거운   (3)  밀렸다   (4)  회의 >> 1
#   ================================================================================
#   정답입니다.
#
#
#   #########################
#   ####### Quiz(10)번 #######
#   #########################
#   ================================================================================
#   pushed:   (1)  밀렸다   (2)  영리한   (3)  돌린   (4)  가족 >> 1
#   ================================================================================
#   정답입니다.
#
#
#   #########################
#   ####### Quiz(11)번 #######
#   #########################
#   ================================================================================
#   picking:   (1)  선발   (2)  무거운   (3)  학교   (4)  운이 좋다 >> 1
#   ================================================================================
#   정답입니다.
#
#
#   #########################
#   ####### Quiz(12)번 #######
#   #########################
#   ================================================================================
#   hefty:   (1)  검게 그을린   (2)  밀렸다   (3)  보리   (4)  무거운 >> 4
#   ================================================================================
#   정답입니다.
#
#
#   #########################
#   ####### Quiz(13)번 #######
#   #########################
#   ================================================================================
#   retained:   (1)  타일   (2)  충분한   (3)  선발   (4)  유지 >> 4
#   ================================================================================
#   정답입니다.
#
#
#   #########################
#   ####### Quiz(14)번 #######
#   #########################
#   ================================================================================
#   tiles:   (1)  타일   (2)  회의   (3)  선발   (4)  가족 >> 1
#   ================================================================================
#   정답입니다.
#
#
#   #########################
#   ####### Quiz(15)번 #######
#   #########################
#   ================================================================================
#   tanned:   (1)  충분한   (2)  유지   (3)  검게 그을린   (4)  돌린 >> 3
#   ================================================================================
#   정답입니다.
#
#
#   #########################
#   ####### Quiz(16)번 #######
#   #########################
#   ================================================================================
#   bowl:   (1)  그릇   (2)  유지   (3)  영리한   (4)  충분한 >> 1
#   ================================================================================
#   정답입니다.
#
#
#   #########################
#   ####### Quiz(17)번 #######
#   #########################
#   ================================================================================
#   turned:   (1)  영리한   (2)  유지된   (3)  결혼 중매인   (4)  돌린 >> 4
#   ================================================================================
#   정답입니다.
#
#
#   #########################
#   ####### Quiz(18)번 #######
#   #########################
#   ================================================================================
#   decades:   (1)  운이 좋다   (2)  돌린   (3)  보리   (4)  수십 년 >> 4
#   ================================================================================
#   정답입니다.
#
#
#   #########################
#   ####### Quiz(19)번 #######
#   #########################
#   ================================================================================
#   clever:   (1)  결혼 중매인   (2)  유지된   (3)  영리한   (4)  가족 >> 3
#   ================================================================================
#   정답입니다.
#
#
#   #########################
#   ####### Quiz(20)번 #######
#   #########################
#   ================================================================================
#   meeting:   (1)  그릇   (2)  회의   (3)  보리   (4)  유지된 >> 2
#   ================================================================================
#   정답입니다.
#
#   !!!! 수고하셨습니다. 20문항 중 20문항 맞추셨습니다 !!!!!!!!!.

# %% [markdown]
# It was a beautful morning at the end of November During the night it had snowed, but only a little, and the earth was covered with a cool blanket no more than three fingers high. In the dark-ness, immediately after lauds, we heard Mass in a village in the valley.
# Then, as the sun first appeared, we set off toward the mountains.
# While we toiled up the steep path that wound around the moun-tain, I saw the abbey. I was amazed, not by the walls that girded it on every side, similar to others to be seen in all the Christian world, but by the bulk of what I later learned was the Aedificium. This was an octagonal construction that from a distance seemed a tetragon (a perfect form, which expresses the sturdiness and impregnability of the City of God), whose southern sides stood on the plateau of the abbey, while the northern ones seemed to grow from the steep side of the mountain, a sheer drop, to which they were bound. I might say that from below, at certain points, the cliff seemed to extend, reaching up toward the heavens, with the rock's same colors and mate-rial, which at a certain point became keep and tower (work of giants who had great familiarity with earth and sky). Three rows of windows proclaimed the triune rhythm of its elevation, so that what was physically squared on the earth was spiritually triangular in the sky. As we came closer, we realized that the quadrangular form included, at each of its corners, a heptagonal tower, five sides of which were visible on the outside —four of the eight sides, then, of the greater octagon producing four minor heptagons, which from the outside appeared as pentagons. And thus anyone can see the admirable concord of so many holy numbers, each revealing a subtle spiritual significance.
# Eight, the number of perfection for every tetragon; four, the number of the Gospels; five, the number of the zones of the world; seven, the number of the gifts of the Holy Ghost. In its bulk and in its form, the Aedificium resembled Castel Ursino or Castel del Monte, which I was to see later in the south of the Italian peninsula, but its inaccessible position made it more awesome than those, and capable of inspiring fear in the traveler who approached it gradually. And it was fortunate that, since it was a very clear winter morning, I did not first see the building as it appears on stormy days.
# I will not say, in any case, that it prompted feelings of jollity. I felt fear, and a subtle uneasiness. God knows these were not phantoms of my immature spirit, and I was rightly interpreting indubitable omens inscribed in the stone the day that the giants began their work, and before the deluded determination of the monks dared consecrate the building to the preservation of the divine word.
# As our little mules strove up the last curve of the mountain, where the main path divided into three, producing two side paths, my master stopped for a while, to look around: at the sides of the road, at the road itself, and above the road, where, for a brief stretch, a series of evergreen pines formed a natural roof, white with snow.
# "A rich abbey," he said. "The abbot likes a great display on public occasions." /
# Accustomed as I was to hear him make the most unusual declara-tions, I did not question him. This was also because, after another bit of road, we heard some noises, and at the next turn an agitated band of monks and servants appeared. One of them, seeing us, came toward us with great cordiality. "Welcome, sir," he said, "and do not be surprised if I can guess who you are, because we have been advised of your visit. I am Remigio of Varagine, the cellarer of the monastery.
# And if you, as I believe, are Brother William of Baskerville, the abbot must be informed. You"— he commanded one of his party —"go up and tell them that our visitor is about to come inside the walls."
# "I thank you, Brother Cellarer," my master replied politely, "and I appreciate your courtesy all the more since, in order to greet me, you have interrupted your search. But don't worry. The horse came this way and took the path to the right. He will not get far, because he will have to stop when he reaches the dungheap. He is too intelligent to plunge down that precipitous slope..."
# "When did you see him?" the cellarer asked.
# "We haven't seen him at all, have we, Adso?" William said, turning toward me with an amused look. "But if you are hunting for Brunel-lus, the horse can only be where I have said."
# The cellarer hesitated. He looked at William, then at the path, and finally asked, "Brunellus? How did you know?"

# %% [markdown]
# ## 예전꺼 backup: 아래

# %%
### 1.  시작 인터페이스
### PachinkoByMin-Jin-Lee
### 청천벽력ByShogo-Kawashima
### TwilightByStephenieMeyer
### 편지ByNatsume-Soseki
### TheNameOfTheRoseByUmbertoEco

# ### 외부 라이브러리인 googletrans 설치 여부 확인
# !pip list | grep googletrans
# ### 외부 라이브러리 googletrans가 install되어 있지 않으면, Package-Installer-of-python로부터 아래 구글 번역 라이브러리 install
# !pip install googletrans==4.0.0rc1
# ### install된 구글 번역 라이브러리 정보 double-Check
# !pip show googletrans


# ### 외부 라이브러리인 Google Text to Speech API 설치 여부 확인
# !pip list | grep gTTS
# ### 외부 라이브러리 googletrans가 install되어 있지 않으면, Package-Installer-of-python로부터 아래 구글 번역 라이브러리 install
# !pip install gTTS
# ### install된 구글 번역 라이브러리 정보 double-Check
# !pip show gTTS


# ### 외부 라이브러리인 Play Sound 설치 여부 확인
# !pip list | grep playsound
# ### 외부 라이브러리 Play Sound가 되어 있지 않으면, Package-Installer-of-python로부터 아래 구글 번역 라이브러리 install
# !pip install playsound
# ### install된 Play Sound 라이브러리 정보 double-Check
# !pip show playsound


import googletrans
from gtts import gTTS
import playsound as ps
import os
os.chdir('/content/drive/MyDrive/00_KITA_2404/M2_Program')

str1="Welcome to Our Translation/Voiceenabled Program"
str2="\t\t용도 및 목적: 외국어 원문 Reading 학습을 위한 번역 및 Listening 학습을 위한 원어 음성 파일 생성 "
str3='\t\t기능:'
str4='\t\t(i) 사용자 입력 TEXT (1. sample-TEXTs, 2. File-Input, 3. Text-Input Window)로 부터 원하는 언어로 번역'
str5='\t\t(ii) 번역된 언어를 음성 파일(MP3)로 변환하여 Listening 반복 학습 기능 제공'
str6='\t\t(iii) 사용자 입력 외국어 원문으로부터 빈출 단어를 추출하여 사용자에게 제공하여 학습 효율 개선'
langs=['한국어','영어','일본어','중국어-간체','중국어-번체','러시아어','프랑스어','독일어','이탈리아어','스페인','베트남어','태국','인도시아어','체코어','덴마크','그리스어']
langCodes=['ko','en','ja','zh-CN','zh-TW','ru','fr','de','it','es','vi','th','id','cs','da','el']

class TransSpeech:

  def InitDisp(self):
    print("#"*200,end='');
    for i in range(2): print("\n##"+" "*195,"##",end='')
    print(f'\n##{str1:^195} ##',end='')
    for i in range(2): print("\n##"+" "*195,"##",end='')
    print(f'\n##{str2:<152} ##',end='')
    for i in range(2): print("\n##"+" "*195,"##",end='')
    print(f'\n##{str3:<181} ##',end='')
    print(f'\n##{str4:<167} ##',end='')
    print(f'\n##{str5:<160} ##',end='')
    print(f'\n##{str6:<145} ##',end='')
    for i in range(2): print("\n##"+" "*195,"##",end='')
    i=1
    for lang in langs:
          if i%8==1: print("\n##\t\t",end="")
          print(f"{i:<2}.{lang:>6}",end="")
          if i%8==0: print(" "*49+"##",end="")
          i += 1
    for i in range(4): print("\n##"+" "*195,"##",end='')
    print('\n'+"#"*200);

  def ProvidedLangs(self):
    i=1; print("\n"+"#"*20,"지원 원어")
    for lang in langs:
      print(f"{i:>2}:{lang:<7}",end="")
      if i%8==0: print();
      i += 1


  def TextLoad(self):
    TEXT_DB={1:'/content/drive/MyDrive/00_KITA_2404/M2_Program/TEXTs/Pachinko_ByMinJinLee.txt',2:'/content/drive/MyDrive/00_KITA_2404/M2_Program/TEXTs/ABoltfromtheBlue_ByShogoKawashima.txt', 3:'/content/drive/MyDrive/00_KITA_2404/M2_Program/TEXTs/Twilight_ByStephenieMeyer.txt'}
    print("\n"+"=="*60)
    print("1. 기본 제공 Sample:(영문소설)파친코\n")
    print("2. 기본 제공 Sample:(일문소설)청천벽력\n")
    print("3. 기본 제공 Sample:(영문소설)Twilight\n")
    print("4. Loading Text File(Entered The File-Path;ex:/content/drive/MyDrive/00_KITA_2404/M2_Program/TEXTs/Letter_ByNatsumeSoseki.txt)\n")
    print("5. Directly Type the TEXT string in the following input window\n")
    selectedInput = int(input(f"***** TEXT를 불러올 방법을 선택하세요 (1~5) >>> "))
    if 1 <= selectedInput <= 3:
      with open(TEXT_DB[selectedInput], 'r') as f:
        textString = f.read()
    elif selectedInput == 4:
      textFile = input(f"***** 읽어들일 TEXT 파일의 path를 입력하세요 >>> ")
      with open(textFile, 'r') as f:
        textString = f.read()
    elif selectedInput == 5:
      textString = input(f"***** 읽어들일 문자열을 직접 입력하세요 >>> ")
    return textString

  def TransString(self, textString):
    transObj = googletrans.Translator()
    self.ProvidedLangs()
    inText = int(input(f"\n***** 입력된 문자열의 언어를 선택하세요 (1-16 선택, 자동으로 인식하고자 할 경우 17) >>> "))
    if 1 <= inText <= 16:
      inLang=langCodes[inText-1]
    elif inText == 17:
      inLang='auto'
    else: print("\n**** 올바른 입력 언어를 선택하세요!")
    outText = int(input(f"\n***** 출력하고자 하는 언어를 선택하세요 (1-16 선택) >>> "))
    if 1 <= outText <= 16:
      outLang=langCodes[outText-1]
    else: print("\n**** 올바른 출력 언어를 선택하세요!")
    translatedString = transObj.translate(textString, dest=outLang, src=inLang)
    transOut=translatedString.text
    detectedInLan=translatedString.src
    inLang=detectedInLan
    return textString, transOut, inLang

  def TextToSpeech(self, textString, inLang):
    tts = gTTS(text=textString, lang=inLang)
    outMP3="outSpeech_"+ inLang+".mp3"
    tts.save(outMP3)
    #ps.playsound(outMP3)


obj1=TransSpeech()
obj1.InitDisp()
textString=obj1.TextLoad()
textString, transOut,inLang=obj1.TransString(textString)
obj1.TextToSpeech(textString, inLang)



# 7. 3번에서 선택한 언어 외 다른 언어로 번역을 원하는지 선택: Y 선택 시 (2~4) 반복  최환욱

# 8. 추가로 번역할 새로운 text를 입력할 지 선택: Y 선택 시 (1~7)반복  -최환욱

# 9. 종료 >> Extra) 사용자가 공부할 수 있도록 추천 단어장 30선 (단어: 원어 > 번역 언어) 제공
# Out:
# WARNING:playsound:playsound is relying on another python subprocess. Please use `pip install pygobject` if you want playsound to run more efficiently.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-bbd80feb8203> in <cell line: 36>()
#      34 import playsound as ps
#      35 import os
# ---> 36 os.chdir('/content/drive/MyDrive/00_KITA_2404/M2_Program')
#      37
#      38 str1="Welcome to Our Translation/Voiceenabled Program"
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/00_KITA_2404/M2_Program'
