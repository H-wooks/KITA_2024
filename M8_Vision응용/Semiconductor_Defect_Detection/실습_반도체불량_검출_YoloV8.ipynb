# %% [markdown]
# ## 반도체 웨이퍼 불량 검출 솔류션 실습 w/ Yolo V8

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %pip install ultralytics -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.0/883.0 kB 52.8 MB/s eta 0:00:00

# %%
# !pip install roboflow -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.4/80.4 kB 7.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 5.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 4.6 MB/s eta 0:00:00

# %%
## !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="nSpvoDIk04DXxr9J5aRN")
project = rf.workspace("hwan-wook-choi").project("defect_detection_v8")
version = project.version(1)
dataset = version.download("yolov8")

# %%
# !pip install PyYAML -q

# %%
# yaml 파일을 학습이 가능하도록 경로 설정.
# key-value 데이터인 dict 데이터타입으로 data['train'], data['val'], data['nc'], data['names'] 에 넣어주는데,
# 가장 중요한 부분은 데이터 경로 설정임.

import yaml

data = { 'train' : '/content/drive/MyDrive/KITA_2024/M8_Vision응용/Semiconductor/data/train/images',
         'val' : '/content/drive/MyDrive/KITA_2024/M8_Vision응용/Semiconductor/data/valid/images',
         'test' : '/content/drive/MyDrive/KITA_2024/M8_Vision응용/Semiconductor/data/test/images',
         'names' : ['Bdot', 'curve', 'dot', 'straight'],
         'nc' : 4 }

with open('/content/drive/MyDrive/KITA_2024/M8_Vision응용/Semiconductor/data/data.yaml', 'w') as f:
  yaml.dump(data, f)


with open('/content/drive/MyDrive/KITA_2024/M8_Vision응용/Semiconductor/data/data.yaml', 'r') as f:
  data_yaml = yaml.safe_load(f)
  display(data_yaml)
# Out:
# {'names': ['Bdot', 'curve', 'dot', 'straight'],
#  'nc': 4,
#  'test': '/content/drive/MyDrive/KITA_2024/M8_Vision응용/Semiconductor/data/test/images',
#  'train': '/content/drive/MyDrive/KITA_2024/M8_Vision응용/Semiconductor/data/train/images',
#  'val': '/content/drive/MyDrive/KITA_2024/M8_Vision응용/Semiconductor/data/valid/images'}

# %%
# !cat /content/drive/MyDrive/kdt_240424/m8_vision/semiconductor/data/data.yaml
# Out:
# cat: /content/drive/MyDrive/kdt_240424/m8_vision/semiconductor/data/data.yaml: No such file or directory

# %% [markdown]
# ## 데이터 세트
# - 데이터 형식: JPG 이미지(1000*1000 px)
# - 데이터 개수: 280장
# - 동일한 환경에서 촬영된 반도체 웨이퍼 사진

# %%
# Load YOLOv8n

from ultralytics import YOLO

model = YOLO('yolov8n.pt')  # load a pretrained YOLOv8n detection model
# Out:
# ...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 339MB/s]

# %%
print(type(model.names), len(model.names))

print(model.names)
# Out:
# <class 'dict'> 80
# ...

# %%
from ultralytics import YOLO

model = YOLO('yolov8n.pt')
model.train(data='/content/drive/MyDrive/KITA_2024/M8_Vision응용/Semiconductor/data/data.yaml',batch=32,patience=10, epochs=50, imgsz=640)
# Out:
# Ultralytics 8.3.7 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# - Fitness는 모델의 전체적인 성능을 나타내는 종합 지표입니다. YOLOv8에서 다양한 평가 지표(precision, recall, mAP 등)를 기반으로 모델의 적합성을 계산한 값입니다. 이 값은 0에서 1 사이의 값이며, 값이 클수록 모델의 성능이 좋다고 볼 수 있습니다.
# - keys: ['metrics/precision(B)', 'metrics/recall(B)', 'metrics/mAP50(B)', 'metrics/mAP50-95(B)']
# 이 항목은 YOLOv8에서 학습 후 평가에 사용된 주요 지표들의 목록을 보여줍니다.
#   - Precision (정밀도): 모델이 탐지한 객체 중에서 올바르게 탐지된 객체의 비율입니다.
#   - Recall (재현율): 실제로 존재하는 객체 중에서 모델이 올바르게 탐지한 비율입니다.
#   - mAP50 (Mean Average Precision at IoU=0.50): Intersection over Union (IoU) 값이 0.5일 때의 평균 정밀도입니다.
#   - mAP50-95 (Mean Average Precision at IoU=0.50 to 0.95): IoU 값이 0.5부터 0.95까지의 평균 정밀도입니다. 더 세밀한 평가를 반영하는 지표입니다.
# - maps: array([...])
#   - Mean Average Precision (mAP) 값들의 배열을 나타냅니다. 각 클래스에 대해 mAP50-95 점수를 보여줍니다.
# - names: 이 항목은 클래스 ID와 클래스 이름을 매핑한 딕셔너리입니다.
# - results_dict: {...}
#   - Precision, Recall, mAP50, mAP50-95, fitness 등의 평가 지표를 다시 한 번 딕셔너리 형태로 요약해서 보여줍니다

# %%
print(type(model.names), len(model.names))

print(model.names)
# Out:
# <class 'dict'> 4
# {0: 'Bdot', 1: 'curve', 2: 'dot', 3: 'straight'}

# %%
from PIL import Image
from IPython.display import Image, clear_output
Image(filename='/content/runs/detect/train2/train_batch0.jpg',width=1000)

# %%
Image(filename='/content/runs/detect/train2/val_batch0_labels.jpg',width=1000)

# %%
results = model.predict(source='/content/drive/MyDrive/KITA_2024/M8_Vision응용/Semiconductor/data/valid/images/', save=True)
# Out:
# image 1/41 /content/drive/MyDrive/KITA_2024/M8_Vision응용/Semiconductor/data/valid/images/pattern_1-1-1-10-D_jpg.rf.365d28133bb353574b836a4d5d48280b.jpg: 640x640 (no detections), 11.7ms
# image 2/41 /content/drive/MyDrive/KITA_2024/M8_Vision응용/Semiconductor/data/valid/images/pattern_1-1-1-20-D_jpg.rf.7c908a8097ae8cfbb51f580a2c85fb0d.jpg: 640x640 (no detections), 7.2ms
# image 3/41 /content/drive/MyDrive/KITA_2024/M8_Vision응용/Semiconductor/data/valid/images/pattern_1-1-1-36-D_jpg.rf.97e7c47b7bea7e3fc3fc38b3c81d7de4.jpg: 640x640 (no detections), 7.8ms
# image 4/41 /content/drive/MyDrive/KITA_2024/M8_Vision응용/Semiconductor/data/valid/images/pattern_1-1-1-38-D_jpg.rf.64a7c680aab4702d7fc770fabfd4b018.jpg: 640x640 (no detections), 7.2ms
# image 5/41 /content/drive/MyDrive/KITA_2024/M8_Vision응용/Semiconductor/data/valid/images/pattern_1-1-2-01-D_jpg.rf.0a8a7fc81d9446c43c343039a67e0fb5.jpg: 640x640 (no detections), 7.2ms
# ...

# %%
print(type(results), len(results))
# Out:
# <class 'list'> 41

# %%
import glob
import random
from IPython.display import Image, display

image_name = random.choice(glob.glob('/content/runs/detect/train2/*.jpg'))
display(Image(filename=image_name,width=600,height=600))
