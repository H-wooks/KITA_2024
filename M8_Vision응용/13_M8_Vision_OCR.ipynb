# %% [markdown]
# ## **Tesseract OCR**
# - 오픈 소스 OCR(Optical Character Recognition, 광학 문자 인식) 라이브러리로, 이미지나 PDF 파일에서 텍스트를 추출하는 데 사용됩니다. 이 라이브러리는 문자 인식의 정확성과 강력함으로 인해 다양한 애플리케이션에서 널리 사용됩니다. 아래에 Tesseract 라이브러리에 대한 주요 사항을 자세히 설명하겠습니다.
#
# ### 1. **역사 및 배경**
# - **개발 초기**: Tesseract는 1985년에 Hewlett-Packard(HP) 연구소에서 개발되었습니다. 오랜 기간 동안 내부적으로 사용되다가, 2005년에 오픈 소스로 공개되었습니다.
# - **Google 지원**: 2006년에 Google이 Tesseract 프로젝트를 후원하면서 활발히 발전하게 되었고, 현재 Google이 개발을 이어받아 유지하고 있습니다.
#
# ### 2. **기능 및 특징**
# - **광학 문자 인식(OCR)**: Tesseract는 이미지나 스캔한 문서에서 문자를 인식하여 텍스트로 변환하는 OCR 기능을 제공합니다.
# - **다양한 언어 지원**: 100개 이상의 언어를 지원하며, 한국어를 포함한 여러 언어를 인식할 수 있습니다. 사용자 정의 언어 학습을 통해 새 언어를 추가하거나 기존 언어 인식 성능을 개선할 수도 있습니다.
# - **오픈 소스 라이브러리**: GNU GPL(GNU General Public License) 하에서 제공되며, 무료로 사용하고 배포할 수 있습니다.
# - **이미지 전처리**: 이미지의 품질에 따라 다양한 전처리 기술이 사용될 수 있습니다. Tesseract는 이미지에서의 잡음을 줄이고 글자 인식을 향상시키기 위한 여러 이미지 전처리 기술을 지원합니다.
# - **Pytesseract**: Python에서 Tesseract를 사용할 수 있는 래퍼 라이브러리입니다. 이를 통해 Python 코드 내에서 Tesseract의 기능을 쉽게 사용할 수 있습니다.
#
# #### **Python에서 사용하기 (Pytesseract)**
# Pytesseract를 사용하면 Python 코드 내에서 Tesseract의 기능을 사용할 수 있습니다.
# ```python
# from PIL import Image
# import pytesseract
#
# # 이미지 파일 열기
# image = Image.open('input_image.png')
#
# # 이미지에서 텍스트 추출
# text = pytesseract.image_to_string(image, lang='eng')
#
# print(text)
# ```
# - **Pillow 라이브러리**: 이미지 파일을 열고 처리하기 위해 사용됩니다.
# - **`image_to_string()`**: 이미지에서 텍스트를 추출하는 기본 함수입니다.
#
# ### 3. **언어 데이터 파일**
# Tesseract는 언어 인식을 위해 `.traineddata` 파일을 사용합니다. Tesseract 설치 시 기본적으로 여러 언어가 포함되어 있지만, 추가 언어가 필요한 경우 `tessdata` 폴더에 `.traineddata` 파일을 추가로 다운로드하여 넣어야 합니다.
#
# - **언어 데이터 파일 다운로드**: [tesseract-ocr 언어 데이터 GitHub 저장소](https://github.com/tesseract-ocr/tessdata)에서 필요한 언어 데이터를 다운로드할 수 있습니다.
# - **사용 예시**:
#   ```bash
#   tesseract input_image.png output_text -l kor
#   ```
#   위 명령어는 한국어를 인식하기 위해 `kor` 언어 데이터를 사용합니다.
#
# ### 4. **Tesseract의 주요 옵션**
# - **`-l` 옵션**: 사용할 언어를 지정합니다. 예를 들어 `-l eng`는 영어를 의미하며, 여러 언어를 함께 사용할 수도 있습니다(`-l eng+kor`).
# - **`--psm` 옵션**: 페이지 세분화 모드를 지정합니다. Tesseract는 페이지 레이아웃을 어떻게 분석할지에 대한 여러 모드를 제공합니다.
#   - **예시**: `--psm 6`은 "단일 블록의 균일한 텍스트"로 간주하고 인식합니다.
# - **`--oem` 옵션**: OCR 엔진 모드를 설정합니다.
#   - `0`: Legacy 엔진만 사용.
#   - `1`: LSTM 엔진만 사용.
#   - `2`: 두 엔진 혼합 사용.
#   - `3`: 기본 엔진을 자동 선택.
#
# ### 5. **Tesseract의 응용 분야**
# - **문서 디지털화**: 책이나 문서를 디지털 형식으로 변환하여 데이터베이스에 저장할 때 사용됩니다.
# - **명함 인식**: 명함에서 이름, 연락처 등의 정보를 추출하여 자동으로 주소록에 추가하는 데 사용됩니다.
# - **자동화된 데이터 입력**: 서류나 청구서의 데이터를 자동으로 추출하여 데이터베이스에 입력하는 등 수작업을 줄이고 효율성을 높이는 데 활용됩니다.
# - **차량 번호판 인식**: 차량 번호판 이미지에서 번호를 인식하여 교통 관리 시스템에 적용하는 등 실시간 분석에서 사용됩니다.
#
# ### 6. **장점과 단점**
# #### **장점**:
# - **오픈 소스**: 무료로 사용 가능하고, 사용자 정의를 통해 모델 학습 및 개선이 가능합니다.
# - **다양한 언어 지원**: 많은 언어를 지원하고 추가 학습이 가능합니다.
# - **적응성**: 다양한 플랫폼에서 사용할 수 있으며, Python과 같은 언어에서 연동하기도 쉽습니다.
#
# #### **단점**:
# - **정확도**: 이미지 품질이 나쁘거나 복잡한 레이아웃의 경우 인식 정확도가 떨어질 수 있습니다.
# - **글꼴 의존성**: 인식하려는 텍스트의 글꼴이 Tesseract가 학습한 데이터와 많이 다를 경우 오류가 발생할 수 있습니다.
# - **속도**: 대규모 문서나 고해상도 이미지의 경우 처리 속도가 느릴 수 있습니다.
#
# ### 7. **Tesseract 활용 팁**
# - **이미지 전처리**: 이미지의 노이즈를 줄이거나 명확하게 하기 위해 대비 조정, 이진화 등을 통해 OCR 정확도를 높일 수 있습니다.
# - **다양한 라이브러리와의 연동**: OpenCV와 같은 이미지 처리 라이브러리를 함께 사용하여 이미지 전처리 단계를 추가함으로써 인식 성능을 개선할 수 있습니다.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !sudo apt install tesseract-ocr
# !pip install pytesseract -q
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 49 not upgraded.

# %%
# !tesseract --version
# Out:
# tesseract 4.1.1
#  leptonica-1.82.0
#   libgif 5.1.9 : libjpeg 8d (libjpeg-turbo 2.1.1) : libpng 1.6.37 : libtiff 4.3.0 : zlib 1.2.11 : libwebp 1.2.2 : libopenjp2 2.4.0
#  Found AVX2
#  Found AVX
#  Found FMA
#  Found SSE
#  Found libarchive 3.6.0 zlib/1.2.11 liblzma/5.2.5 bz2lib/1.0.8 liblz4/1.9.3 libzstd/1.4.8

# %% [markdown]
# ### install language (언어 설치)
#
# Ex) Kor
#
# ```sudo apt-get install tesseract-ocr-kor```
#
# EX) All languages
#
# ```sudo apt-get install tesseract-ocr-all```

# %%
# !sudo apt-get install tesseract-ocr-kor tesseract-ocr-jpn tesseract-ocr-eng
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr-eng is already the newest version (1:4.00~git30-7274cfa-1.1).
# tesseract-ocr-jpn is already the newest version (1:4.00~git30-7274cfa-1.1).
# tesseract-ocr-kor is already the newest version (1:4.00~git30-7274cfa-1.1).
# 0 upgraded, 0 newly installed, 0 to remove and 49 not upgraded.

# %%
## OSD는 이미지 내에서 문서의 언어를 자동으로 감지하는 기능을 의미
# !tesseract --list-langs
# Out:
# List of available languages (4):
# eng
# jpn
# kor
# osd

# %%
# !pip install opencv-python

# %%
import pytesseract
import cv2
import os
from PIL import Image
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt

# %% [markdown]
# ## 숫자

# %%
image=cv2.imread('/content/drive/MyDrive/KITA_2024/M8_Vision응용/OCR/ocr_number.png')
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=286x140>

# %%
## 이미지를 불러와 그레이 스케일로 변환
image=cv2.imread('/content/drive/MyDrive/KITA_2024/M8_Vision응용/OCR/ocr_number.png')
gray=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)


## pytesseract에서는 numpy array를 읽지를 못하고 파일로 저장된 이미지 파일을 입력으로 하는 것이 필요
filename="{}.jpg".format(os.getpid())
cv2.imwrite(filename,gray)    ## <-- numpy 대신에 파일 네임으로 써줌

## pytesseract의 image to string을 써준다
# 숫자니까 lang=None

text=pytesseract.image_to_string(Image.open(filename), lang=None)
os.remove(filename)
print(text)
# Out:
# 650 3428

# %%
filename='/content/drive/MyDrive/KITA_2024/M8_Vision응용/OCR/ocr_number.png'
text=pytesseract.image_to_string(filename, lang=None)
print(text)
# Out:
# 650 3428

# %% [markdown]
# ## 영문 텍스트

# %%
image=cv2.imread('/content/drive/MyDrive/KITA_2024/M8_Vision응용/OCR/ocr_text.png')
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=1097x317>

# %%
filename='/content/drive/MyDrive/KITA_2024/M8_Vision응용/OCR/ocr_text.png'
image=Image.open(filename)

## 이미지 출력
plt.imshow(image)
plt.show()

text=pytesseract.image_to_string(image, lang='eng')
print(text)
# Out:
# 1.1 Whatis computer vision?
#
# As humans, we perceive the three-dimensional Structure of the world around us with apparent
# case. Think of how vivid the three-dimensional percept is when you look at a vase of flowers
# sitting on the table next to you. You can tell the shape and translucency of each petal through
# the subtle patterns of light and shading that play across its surface and effortlessly segment
# each flower from the background of the scene (Figure 1.1). Looking at a framed group por-
# trait, you can easily count (and name) all of the people in the picture and even guess at their
# emotions from their facial appearance. Perceptual psychologists have spent decades trying to
# understand how the visual system works and, even though they can devise optical illusions
#
# to tease apart some of its principles (Figure 1.3), a complete solution to this puzzle remains
# elusive (Marr 1982; Palmer 1999; Livingstone 2008)

# %% [markdown]
# #### 이미지를 불러오는 다양한 방법
# - request를 이용하여 읽어와서 cv2_imshow로 출력

# %%
import requests
import numpy as np

url = 'https://user-images.githubusercontent.com/69428232/148318703-ef6bd43f-ec4f-42f5-a336-3b584a662982.jpg'
image_nparray=np.asarray(bytearray(requests.get(url).content), dtype=np.uint8) ## bytearray 가져온 컨텐츠를 바이트 배열로 변환
org_image=cv2.imdecode(image_nparray, cv2.IMREAD_COLOR)
cv2_imshow(org_image)
# Out:
# <PIL.Image.Image image mode=RGB size=572x361>

# %% [markdown]
# -matplotlib을 이용하여 출력

# %%
## matplotlib을 이용하여 출력
import matplotlib.pyplot as plt

plt.imshow(org_image)
plt.axis('off')
plt.show()

# %%
## matplotlib을 이용하여 출력
import matplotlib.pyplot as plt
from PIL import Image
import requests
from io import BytesIO

url = 'https://user-images.githubusercontent.com/69428232/148318703-ef6bd43f-ec4f-42f5-a336-3b584a662982.jpg'

response=requests.get(url)
image=Image.open(BytesIO(response.content))

plt.imshow(image)
plt.axis('off')
plt.show()

# %% [markdown]
# - OpenCV는 기본적으로 BGR 색상 체계를 사용. imageio.imread로 읽은 이미지는 RGB 색상 체계를 사용하므로, OpenCV에서 처리하기 전에 BGR로 변환하는 것이 일반적인 관행.
# - OCR 처리를 위해서는 추가적으로 그레이스케일로 변환하는 것이 좋으며, 이는 cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)를 사용하여 수행할 수 있다.
# - OCR을 위한 최적의 성능을 원한다면, BGR에서 그레이스케일로의 변환 단계를 추가하는 것이 좋다.

# %%
import imageio

url = 'https://user-images.githubusercontent.com/69428232/148318703-ef6bd43f-ec4f-42f5-a336-3b584a662982.jpg'

img = imageio.imread(url)
img= cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
img= cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cv2_imshow(img)
# Out:
# <ipython-input-47-05c4d8684dbb>:5: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   img = imageio.imread(url)
# <PIL.Image.Image image mode=L size=572x361>

# %%
import imageio
import matplotlib.pyplot as plt

url = 'https://user-images.githubusercontent.com/69428232/148318703-ef6bd43f-ec4f-42f5-a336-3b584a662982.jpg'
img = imageio.imread(url)

plt.imshow(img)
plt.axis('off')
plt.show()
# Out:
# <ipython-input-48-d15af9b52bd2>:5: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   img = imageio.imread(url)

# %% [markdown]
# - 테스트 하려는 이미지는 한글 영어 숫자가 혼합된 이미지

# %%
import imageio

# url = 'https://user-images.githubusercontent.com/69428232/148318703-ef6bd43f-ec4f-42f5-a336-3b584a662982.jpg'

# img = imageio.imread(url)
# img= cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
# img= cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

text=pytesseract.image_to_string(img, lang='kor+eng')
print(text)
# Out:
# 김윤웅
#
# Kim Yunwoong
#
# 0123456789#$

# %% [markdown]
# - 다양한 음영과 노이즈가 존재하는 경우

# %%
import requests
from io import BytesIO

url = 'https://user-images.githubusercontent.com/69428232/148330274-237d9b23-4a79-4416-8ef1-bb7b2b52edc4.jpg'

response=requests.get(url)
image=Image.open(BytesIO(response.content))

plt.imshow(image)
plt.axis('off')
plt.show()

text=pytesseract.image_to_string(img, lang='eng')
print(text)
# Out:
# ARS
#
# Kim Yunwoong
#
# 0123456789#$

# %%
import imageio

url = 'https://user-images.githubusercontent.com/69428232/148330274-237d9b23-4a79-4416-8ef1-bb7b2b52edc4.jpg'

img = imageio.imread(url)
img= cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
img= cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cv2_imshow(img)

text=pytesseract.image_to_string(img, lang='eng')
print(text)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
### 전처리를 통한 개선 작업
import numpy as np

url = 'https://user-images.githubusercontent.com/69428232/148330274-237d9b23-4a79-4416-8ef1-bb7b2b52edc4.jpg'

image_nparray=np.asarray(bytearray(requests.get(url).content), dtype=np.uint8) ## bytearray 가져온 컨텐츠를 바이트 배열로 변환
org_image2=cv2.imdecode(image_nparray, cv2.IMREAD_COLOR)
rgb_image2=cv2.cvtColor(org_image2, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(16,10))

plt.subplot(1,1,1)
plt.imshow(rgb_image2)
plt.title('additional exmaple image')
plt.xticks([]), plt.yticks([])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
text=pytesseract.image_to_string(rgb_image2, lang='eng')
print(text)
# Out:
# y - wesTPoRT,CT 06880
#
# yHOLE FOODS NARKE
# 399 post RD WEST ~ ;
#
# 903) 227-6858
#
# pAcoN LS NP
# pacon LS N
#
# BACON LS NP
# pacon tS N
#
# 365

# %%
# 제목(title), 이미지(img), 그리고 이미지를 표시할 때 사용할 그림 크기(figsize)를 매개변수로 받는다.
def plt_imshow(title='image', img=None, figsize=(8 ,5)):
    plt.figure(figsize=figsize)

    if type(img) == list:
        if type(title) == list:
            titles = title
        else:
            titles = []

            for i in range(len(img)):
                titles.append(title)

        for i in range(len(img)):
            if len(img[i].shape) <= 2:
                rgbImg = cv2.cvtColor(img[i], cv2.COLOR_GRAY2RGB)
            else:
                rgbImg = cv2.cvtColor(img[i], cv2.COLOR_BGR2RGB)

            plt.subplot(1, len(img), i + 1), plt.imshow(rgbImg)
            plt.title(titles[i])
            plt.xticks([]), plt.yticks([])

        plt.show()
    else: # 매개변수가 리스트가 아닌 경우
        if len(img.shape) < 3:
            rgbImg = cv2.cvtColor(img, cv2.COLOR_GRAY2RGB)
        else:
            rgbImg = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

        plt.imshow(rgbImg)
        plt.title(title)
        plt.xticks([]), plt.yticks([])
        plt.show()

# %%
url = 'https://user-images.githubusercontent.com/69428232/148330274-237d9b23-4a79-4416-8ef1-bb7b2b52edc4.jpg'

image_nparray=np.asarray(bytearray(requests.get(url).content), dtype=np.uint8) ## bytearray 가져온 컨텐츠를 바이트 배열로 변환
org_image=cv2.imdecode(image_nparray, cv2.IMREAD_COLOR)
plt_imshow("original Image", org_image)

# %%
# !pip install imutils

# %%
import imutils

image=org_image.copy()
image=imutils.resize(image,width=500)
ratio=org_image.shape[1]/float(image.shape[1])

## 이미지를 그레이스케일로 변환, 블러 처리
## 모서리를 찾기위한 이미지 연산
gray=cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
blurred=cv2.GaussianBlur(gray, (5,5,), 0) ## 블러 처리
## 케니 가장자리 검출은 이미지에서 엣지를 검출, 이중 임계값을 사용하여 강한 엣지, 약한 엣지, 노이즈 분류, 75: 최소 임계, 200: 최대 임계
edged=cv2.Canny(blurred, 75, 200)

plt_imshow(['gray', 'blurred', 'edged'], [gray, blurred, edged])

# %%
## 케니 가장 자리 검출을 통해 찾은 가장 자리의 윤곽을 검출
## 함수는 이미지에서 윤곽을 찾아 리스트로 반환
## RETR_EXTERNAL 플래크를 사용하여 가장 바깥쪽 윤곽만을 검출, CHAIN_APPROX_SIMPLE 플래그를 사용하여 윤곽을 간단한 방법으로 압축
cnts=cv2.findContours(edged.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
cnts=imutils.grab_contours(cnts)      ## openCV 버전에 따라 반환되는 값의 차이를 처리, 이함수를 사용하면 안전하게 윤곽을 추출
cnts=sorted(cnts, key=cv2.contourArea, reverse=True)    ## 윤곽을 크기순으로 정렬

receiptCnt=None       ## 영수증 윤곽을 저장할 변수 초기화

## 정렬된 contours를 반복문으로 수행하여 4개의 꼭지점을 갖는 도형을 검출
for c in cnts:
    peri=cv2.arcLength(c, True)     ## 윤곽의 둘레를 계산
    approx=cv2.approxPolyDP(c, 0.02*peri, True)     ## 윤곽을 단순화, 0.02 * peri는 근사화 정확도를 조절하는 파라미터

    ## 컨투어가 크기순으로 정렬되어 있기 때문에 제일 첫번째 사각형을 영수증 영역으로 판단하고 break
    if len(approx)==4:
        receiptCnt=approx   ## 영수증 윤곽을 저장
        break

## 만약 추출한 윤곽이 없을 경우 오류 처리
if receiptCnt is None:
    raise Exception(("Could not find receipt outline."))

output = image.copy()
cv2.drawContours(output, [receiptCnt], -1, (0, 255, 0), 2)    ## 이미지에 윤곽을 그리는 함수. -1로 설정하면 모든 윤곽을 그림
plt_imshow('Receipt Outline', output)

# %%
from imutils.perspective import four_point_transform

## four_point_transform함수는 opencv를 사용한 이미지 처리에서 이미지의 특정 영역을 네개의 꼭짓점을 기준으로 변환하는데 사용
## 원본이미지에서 찾을 윤곽을 기준으로 이미지를 보정
receipt=four_point_transform(org_image, receiptCnt.reshape(4,2)*ratio)      ## 언본 이미지에서 영수증 영역을 추출하고 변환
plt_imshow('Receipt Transform', receipt)

# %% [markdown]
# options = "--psm 4":
#
# - --psm은 Tesseract의 페이지 분할 모드(Page Segmentation Mode) 옵션입니다.
# - psm 4는 Tesseract에 이미지가 "변수 크기의 텍스트를 포함하는 단일 열"로 구성되어 있다고 알려주는 모드입니다.
# - Tesseract에는 여러 가지 psm 모드가 있는데, 4는 텍스트의 레이아웃이 하나의 열로 구성된 경우에 적합합니다.
#   - psm 3: 자동 페이지 세그멘테이션. OCR 기본 모드입니다.
#   - psm 6: 단락 텍스트를 인식하는 모드입니다.
# - psm 모드를 적절히 설정하는 것은 이미지에 있는 텍스트의 구조에 맞춰 OCR의 성능을 개선할 수 있습니다.

# %%
options='--psm 4'
text=pytesseract.image_to_string(cv2.cvtColor(receipt, cv2.COLOR_BGR2GRAY), config=options)
# OCR 결과 출력
print("[INFO] OCR 결과")
print("=============================")
print(text)
print("\n")
# Out:
# [INFO] OCR 결과
# ...
#
#
# WHOLE
# FOODS
#
# WHOLE FOODS MARKET - WESTPORT, CT 06880
# 399 POST RD WEST - (203) 227-6858
#
# 365 BACON LS NP 4.99
#
# 365 BACON LS NP 4.99
#
# 365 BACON LS NP 4.99
#
# 365  BACONLS NP 4.99
# BROTH CHIC NP 2.19
#
# FLOUR ALMOND NP.11.99
#
# CHKN BRST BNLSS SK NP 18.80
# HEAVY CREAM NP 3.39
#
# BALSMC REDUCT NP 6.49
#
# BEEF GRND 85/15 NP 5.04
# JUICE COF CASHEW C NP 8.99
# DOCS PINT ORGANIC NP 14.49
# HNY ALMOND BUTTER NP 9.99
# wee* TAX 100 BAL 101.33

# %% [markdown]
# Q. 입력된 이미지를 전처리 과정을 통해 Scan한 이미지로 변경하는 과정을 모두 포함하는 사용자 함수 run_tesseract_ocr를 활용하여 명함 이미지를 텍스트로 변환하세요.
# <br>
# -url = 'https://user-images.githubusercontent.com/69428232/155486780-55525c3c-8f5f-4313-8590-dd69d4ce4111.jpg'

# %%
url = 'https://user-images.githubusercontent.com/69428232/155486780-55525c3c-8f5f-4313-8590-dd69d4ce4111.jpg'

#### 전처리 이전
img = imageio.imread(url)
plt.imshow(img)
plt.axis('off')
plt.show()
text=pytesseract.image_to_string(img, lang='kor+eng')
print(text)
# Out:
# <ipython-input-66-0fa235be1d76>:4: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   img = imageio.imread(url)
#
#
# o &
# 김 윤 웅
#
# 스스
#
# 수
# T Biz. Digital l= | C&C
#
# SK 2415141
#
# 13486, 경기도 성남시 분당구 판교로 255번길 38
# (< 주식회사 판교캠퍼스
#
# Tel
#
# Mobile
#
# www.sk.co.kr

# %%
import requests
from io import BytesIO
import imageio
import matplotlib.pyplot as plt
import numpy as np
import imutils
from imutils.perspective import four_point_transform


url = 'https://user-images.githubusercontent.com/69428232/155486780-55525c3c-8f5f-4313-8590-dd69d4ce4111.jpg'

#### 전처리 이전
# img = imageio.imread(url)
# plt.imshow(img)
# plt.axis('off')
# plt.show()
# text=pytesseract.image_to_string(img, lang='kor+eng')
# print(text)

#### 전처리 이후
image_nparray=np.asarray(bytearray(requests.get(url).content), dtype=np.uint8) ## bytearray 가져온 컨텐츠를 바이트 배열로 변환
org_image=cv2.imdecode(image_nparray, cv2.IMREAD_COLOR)

image=org_image.copy()
image=imutils.resize(image,width=500)
ratio=org_image.shape[1]/float(image.shape[1])

## 그레이/블러/에지 처리
gray=cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
blurred=cv2.GaussianBlur(gray, (5,5,), 0) ## 블러 처리
edged=cv2.Canny(blurred, 25, 100)
plt_imshow(['gray', 'blurred', 'edged'], [gray, blurred, edged], figsize=(4 ,3))
##
cnts=cv2.findContours(edged.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
cnts=imutils.grab_contours(cnts)      ## openCV 버전에 따라 반환되는 값의 차이를 처리, 이함수를 사용하면 안전하게 윤곽을 추출
cnts=sorted(cnts, key=cv2.contourArea, reverse=True)    ## 윤곽을 크기순으로 정렬

bizcardCnt=None

## 정렬된 contours를 반복문으로 수행하여 4개의 꼭지점을 갖는 도형을 검출
for c in cnts:
    peri=cv2.arcLength(c, True)     ## 윤곽의 둘레를 계산
    approx=cv2.approxPolyDP(c, 0.02*peri, True)     ## 윤곽을 단순화, 0.02 * peri는 근사화 정확도를 조절하는 파라미터

    ## 컨투어가 크기순으로 정렬되어 있기 때문에 제일 첫번째 사각형을 영수증 영역으로 판단하고 break
    if len(approx)==4:
        bizcardCnt=approx   ## 영수증 윤곽을 저장
        break

## 만약 추출한 윤곽이 없을 경우 오류 처리
if bizcardCnt is None:
    raise Exception(("Could not find biz card outline."))

output = image.copy()
cv2.drawContours(output, [receiptCnt], -1, (0, 255, 0), 2)    ## 이미지에 윤곽을 그리는 함수. -1로 설정하면 모든 윤곽을 그림

bizcard=four_point_transform(org_image, receiptCnt.reshape(4,2)*ratio)      ## 원본 이미지에서 영수증 영역을 추출하고 변환
plt_imshow('Transformed Biz Card', bizcard, figsize=(4 ,3))

options='--psm 4'
text=pytesseract.image_to_string(cv2.cvtColor(bizcard, cv2.COLOR_BGR2GRAY), config=options, lang='kor+eng')
# OCR 결과 출력
print("[INFO] OCR 결과")
print("=============================")
print(text)
print("\n")
# Out:
# [INFO] OCR 결과
# ...
# = =
# 김 윤 웅
# 수석
#
# T Biz. Digital l= | C&C
#
# $《 주식회사
#
# 13486, 경기도 성남시 분당구 판교로 255번길 38
#
# 9 주식회사 판교캠퍼스
# Tel
# Mobile
#
# www.sk.co.kr

# %%
import requests
from io import BytesIO
import imageio
import matplotlib.pyplot as plt
import numpy as np
import imutils
from imutils.perspective import four_point_transform


url = 'https://user-images.githubusercontent.com/69428232/155486780-55525c3c-8f5f-4313-8590-dd69d4ce4111.jpg'

#### 전처리 이전
# img = imageio.imread(url)
# plt.imshow(img)
# plt.axis('off')
# plt.show()
# text=pytesseract.image_to_string(img, lang='kor+eng')
# print(text)

#### 전처리 이후
image_nparray=np.asarray(bytearray(requests.get(url).content), dtype=np.uint8) ## bytearray 가져온 컨텐츠를 바이트 배열로 변환
org_image=cv2.imdecode(image_nparray, cv2.IMREAD_COLOR)

image=org_image.copy()
image=imutils.resize(image,width=500)
ratio=org_image.shape[1]/float(image.shape[1])

## 그레이/블러/에지 처리
gray=cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# CLAHE 적용 (대비 향상)
clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
gray_clahe = clahe.apply(gray)
# 조명 보정
dilated_img = cv2.dilate(gray_clahe, np.ones((7,7), np.uint8))
bg_img = cv2.medianBlur(dilated_img, 21)
diff_img = 255 - cv2.absdiff(gray_clahe, bg_img)
norm_img = cv2.normalize(diff_img, None, alpha=0, beta=255, norm_type=cv2.NORM_MINMAX)

# 블러 처리 및 에지 검출 (강한 빛 문제로 낮은 임계값 사용)
blurred = cv2.GaussianBlur(norm_img, (5, 5), 0)
edged = cv2.Canny(blurred, 25, 100)

plt_imshow(['gray', 'blurred', 'edged'], [gray, blurred, edged], figsize=(4 ,3))
##
cnts=cv2.findContours(edged.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
cnts=imutils.grab_contours(cnts)      ## openCV 버전에 따라 반환되는 값의 차이를 처리, 이함수를 사용하면 안전하게 윤곽을 추출
cnts=sorted(cnts, key=cv2.contourArea, reverse=True)    ## 윤곽을 크기순으로 정렬

bizcardCnt=None

## 정렬된 contours를 반복문으로 수행하여 4개의 꼭지점을 갖는 도형을 검출
for c in cnts:
    peri=cv2.arcLength(c, True)     ## 윤곽의 둘레를 계산
    approx=cv2.approxPolyDP(c, 0.02*peri, True)     ## 윤곽을 단순화, 0.02 * peri는 근사화 정확도를 조절하는 파라미터

    ## 컨투어가 크기순으로 정렬되어 있기 때문에 제일 첫번째 사각형을 영수증 영역으로 판단하고 break
    if len(approx)==4:
        bizcardCnt=approx   ## 영수증 윤곽을 저장
        break

## 만약 추출한 윤곽이 없을 경우 오류 처리
if bizcardCnt is None:
    raise Exception(("Could not find biz card outline."))

output = image.copy()
cv2.drawContours(output, [receiptCnt], -1, (0, 255, 0), 2)    ## 이미지에 윤곽을 그리는 함수. -1로 설정하면 모든 윤곽을 그림

bizcard=four_point_transform(org_image, receiptCnt.reshape(4,2)*ratio)      ## 원본 이미지에서 영수증 영역을 추출하고 변환
plt_imshow('Transformed Biz Card', bizcard, figsize=(4 ,3))

# OCR 처리 옵션 및 텍스트 추출
options = '--oem 3 --psm 4'  # OEM 1은 LSTM만, PSM 6은 단일 블록의 텍스트 탐색
text=pytesseract.image_to_string(cv2.cvtColor(bizcard, cv2.COLOR_BGR2GRAY), config=options, lang='kor+eng')
# OCR 결과 출력
print("[INFO] OCR 결과")
print("=============================")
print(text)
print("\n")
# Out:
# [INFO] OCR 결과
# ...
# = =
# 김 윤 웅
# 수석
#
# T Biz. Digital l= | C&C
#
# $《 주식회사
#
# 13486, 경기도 성남시 분당구 판교로 255번길 38
#
# 9 주식회사 판교캠퍼스
# Tel
# Mobile
#
# www.sk.co.kr

# %%
################################################################### 강사님

# %%
# !sudo apt install tesseract-ocr
# !pip install pytesseract -q
# !sudo apt-get install tesseract-ocr-kor tesseract-ocr-jpn #### 영어는 기본 설치 따로 설치 필요 없음
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 49 not upgraded.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr-jpn is already the newest version (1:4.00~git30-7274cfa-1.1).
# tesseract-ocr-kor is already the newest version (1:4.00~git30-7274cfa-1.1).
# 0 upgraded, 0 newly installed, 0 to remove and 49 not upgraded.

# %%
import pytesseract
import cv2
import os
from PIL import Image
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt

from imutils.perspective import four_point_transform # 이미지에서 특정 영역을 직사각형으로 변환하는 데 사용
import imutils # 이미지 처리를 단순화하고 코드를 더 간결하게 만드는 데 사용
import re
import requests

# %%
# 제목(title), 이미지(img), 그리고 이미지를 표시할 때 사용할 그림 크기(figsize)를 매개변수로 받는다.
def plt_imshow(title='image', img=None, figsize=(8 ,5)):
    plt.figure(figsize=figsize)

    if type(img) == list:
        if type(title) == list:
            titles = title
        else:
            titles = []

            for i in range(len(img)):
                titles.append(title)

        for i in range(len(img)):
            if len(img[i].shape) <= 2:
                rgbImg = cv2.cvtColor(img[i], cv2.COLOR_GRAY2RGB)
            else:
                rgbImg = cv2.cvtColor(img[i], cv2.COLOR_BGR2RGB)

            plt.subplot(1, len(img), i + 1), plt.imshow(rgbImg)
            plt.title(titles[i])
            plt.xticks([]), plt.yticks([])

        plt.show()
    else: # 매개변수가 리스트가 아닌 경우
        if len(img.shape) < 3:
            rgbImg = cv2.cvtColor(img, cv2.COLOR_GRAY2RGB)
        else:
            rgbImg = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

        plt.imshow(rgbImg)
        plt.title(title)
        plt.xticks([]), plt.yticks([])
        plt.show()

# %%
import numpy as np

url = 'https://user-images.githubusercontent.com/69428232/155486780-55525c3c-8f5f-4313-8590-dd69d4ce4111.jpg'
image_nparray=np.asarray(bytearray(requests.get(url).content), dtype=np.uint8) ## bytearray 가져온 컨텐츠를 바이트 배열로 변환
org_image=cv2.imdecode(image_nparray, cv2.IMREAD_COLOR)
plt_imshow("original Image", org_image)

# %%
def run_tesseract_ocr(image, width, ksize=(5,5), min_threshold=75, max_threshold=200, lang='eng'):
  image_list_title = []
  image_list = []

  image = imutils.resize(image, width=width)
  ratio = org_image.shape[1] / float(image.shape[1])

  # 이미지를 grayscale로 변환하고 blur를 적용
  # 모서리를 찾기위한 이미지 연산
  gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
  blurred = cv2.GaussianBlur(gray, ksize, 0)
  edged = cv2.Canny(blurred, min_threshold, max_threshold)

  image_list_title = ['gray', 'blurred', 'edged']
  image_list = [gray, blurred, edged]

  # contours를 찾아 크기순으로 정렬
  cnts = cv2.findContours(edged.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
  cnts = imutils.grab_contours(cnts)
  cnts = sorted(cnts, key=cv2.contourArea, reverse=True)

  receiptCnt = None

  # 정렬된 contours를 반복문으로 수행하며 4개의 꼭지점을 갖는 도형을 검출
  for c in cnts:
    peri = cv2.arcLength(c, True)
    approx = cv2.approxPolyDP(c, 0.02 * peri, True)

    # contours가 크기순으로 정렬되어 있기때문에 제일 첫번째 사각형을 영수증 영역으로 판단하고 break
    if len(approx) == 4:
      receiptCnt = approx
      break


  # 만약 추출한 윤곽이 없을 경우 오류
  if receiptCnt is None:
    raise Exception(("Could not find receipt outline."))


  output = image.copy()
  cv2.drawContours(output, [receiptCnt], -1, (0, 255, 0), 2)

  image_list_title.append("Receipt Outline")
  image_list.append(output)

  # 원본 이미지에 찾은 윤곽을 기준으로 이미지를 보정
  receipt = four_point_transform(org_image, receiptCnt.reshape(4, 2) * ratio)

  plt_imshow(image_list_title, image_list)
  plt_imshow("Receipt Transform", receipt)

  options = "--psm 4" # --psm 4는 '단일 블록' 세그멘테이션 모드로 이미지에 있는 모든 텍스트를 하나의 블록으로 처리.

  text = pytesseract.image_to_string(cv2.cvtColor(receipt, cv2.COLOR_BGR2RGB), lang=lang, config=options)

  # OCR결과 출력
  print("[INFO] OCR결과:")
  print("==================")
  print(text)

# %%
run_tesseract_ocr(org_image, width=200, ksize=(5, 5), min_threshold=20, max_threshold=100, lang='kor+eng')
# Out:
# [INFO] OCR결과:
# ...
# oS  oS
# 김 윤 웅
# 수석
# T Biz. Digital | C&C
#
# $《 주식회사
#
# 13486, 경기도 성남시 분당구 판교로 255번길 38
# < 주식회사 판교캠퍼스
#
# Tel
# Mobile
#
# www.sk.co.kr
