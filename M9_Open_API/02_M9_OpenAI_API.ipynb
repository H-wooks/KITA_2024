# %% [markdown]
# ## OpenAI API
# 정의와 목적
# - OpenAI API는 GPT-4와 같은 대규모 언어 모델을 활용하여 자연어 처리 작업을 자동화하고 향상시키기 위한 도구입니다.
# - API는 개발자가 다양한 응용 프로그램에서 인공지능을 통합하여 텍스트 생성, 대화형 AI, 콘텐츠 생성 등을 구현할 수 있도록 설계되었습니다.
#
# 활용 방법
# - OpenAI API는 클라우드 기반으로 작동하며, 모델에 프롬프트를 보내고 결과를 받습니다. 주로 Chat Completion API를 사용하여 텍스트 완성, 요약, 번역 등을 수행하며, 다양한 언어 모델과 설정을 선택할 수 있습니다.
#
# 적용 절차
# - API 키 생성: OpenAI 계정에서 API 키를 생성합니다.
# - 프롬프트 설계: 수행할 작업에 맞는 프롬프트를 작성합니다.
# - API 호출: HTTP 요청으로 프롬프트를 포함한 API 호출을 수행합니다.
# - 결과 처리: 모델이 생성한 응답을 분석하고 필요시 후속 조치를 취합니다.
# - 활용 사례
#   - 고객 서비스: 자동 응답 챗봇 구축.
#   - 콘텐츠 생성: 블로그, 소셜 미디어 포스트 자동 생성.
#   - 교육: 질문에 대한 자동화된 답변 제공.
#   - 개발자 도구: 코드 자동 완성 및 디버깅 지원.
#   - 이 API는 자연어 처리의 다양한 응용 프로그램에서 핵심적인 역할을 합니다.

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 8))
image = mpimg.imread('/content/drive/MyDrive/KITA_2024/M9_Open_API/DATA/KakaoTalk_20240813_105447485.png')
plt.imshow(image)
plt.axis('off')  # Turn off axis numbers
plt.show()

# %% [markdown]
# ## OpenAI API를 활용한 모델 최적화
# Context Optimization과 LLM Optimization이라는 두 가지 주요 과정으로 나눌 수 있으며, 이 과정은 프롬프트 엔지니어링, RAG(Retrieval-Augmented Generation), 파인 튜닝(Fine-Tuning) 등 다양한 방법과 밀접하게 연관되어 있습니다.
#
# Context Optimization (맥락 최적화)
# - Context Optimization은 모델이 무엇을 알아야 하는지를 최적화하는 과정입니다. 여기에는 모델이 주어진 프롬프트나 문제를 정확하게 이해하고, 이를 바탕으로 적절한 응답을 생성할 수 있도록 맥락을 제공하는 것이 포함됩니다.
# - 이 과정은 특히 다음과 같은 방법들과 연계됩니다:
#   - 프롬프트 엔지니어링 (Prompt Engineering): 프롬프트 엔지니어링은 맥락을 명확하게 전달하기 위해 프롬프트를 설계하는 과정입니다. 잘 설계된 프롬프트는 모델이 더 정확한 컨텍스트를 이해하도록 도와주며, 결과적으로 더 신뢰할 수 있는 응답을 생성하게 합니다. 예를 들어, 특정한 예시나 추가적인 정보를 포함시켜 모델이 문제를 더 잘 이해하도록 유도할 수 있습니다.
#   - RAG (Retrieval-Augmented Generation): RAG는 모델이 외부 데이터 소스에서 정보를 검색하여 그 정보를 바탕으로 응답을 생성하도록 하는 방법입니다. 이 방법은 특히 최신 정보나 특정 도메인에 대한 지식이 필요한 경우 매우 유용합니다. RAG는 단순히 모델에게 제공되는 컨텍스트를 강화하여 모델이 더 정확한 정보에 기반한 응답을 생성하도록 도와줍니다. 예를 들어, 사용자가 질의한 질문에 대해 모델이 최신 기사를 검색하여 그 내용을 바탕으로 답변하는 경우입니다.
# - RAG와 프롬프트 엔지니어링은 모두 모델이 주어진 문제에 대해 더 깊이 있는 맥락을 이해하도록 돕고, 이로 인해 더 정확한 응답을 생성하도록 합니다. 이 과정에서 Context Optimization이 이루어지며, 이를 통해 모델의 이해도와 성능을 향상시킬 수 있습니다.
#
# LLM Optimization (모델 최적화)
# - LLM Optimization은 모델이 주어진 문제에 대해 어떻게 행동해야 하는지를 최적화하는 과정입니다. 이 과정에서는 주로 모델의 학습 과정과 파인 튜닝이 중요한 역할을 합니다:
#   - 파인 튜닝 (Fine-Tuning): 파인 튜닝은 특정 도메인이나 작업에 맞게 모델을 재학습시키는 과정입니다. 기본적으로 대규모 데이터로 학습된 언어 모델이지만, 특정 도메인이나 작업에 대해 더 정확한 결과를 얻기 위해 추가적인 학습이 필요할 수 있습니다. 파인 튜닝을 통해 모델이 특정 작업에 최적화된 성능을 발휘하도록 조정할 수 있습니다. 예를 들어, 의료 데이터셋으로 파인 튜닝된 모델은 일반적인 GPT 모델보다 의료 관련 질문에 대해 더 정확한 응답을 제공할 수 있습니다.
# - LLM Optimization은 주로 파인 튜닝을 통해 이루어지며, 이를 통해 모델이 주어진 작업에 대해 최적의 성능을 발휘할 수 있도록 만듭니다.
#
# Context Optimization과 LLM Optimization의 연계
# - 이 두 가지 최적화 과정은 서로 보완적입니다. Context Optimization은 모델이 문제를 더 잘 이해하고, 맥락을 명확하게 파악하도록 돕는 반면, LLM Optimization은 모델이 그 문제를 어떻게 해결해야 하는지에 대한 학습을 통해 성능을 최적화합니다.
#   - 프롬프트 엔지니어링과 RAG는 주로 Context Optimization에 집중하여 모델이 정확한 정보를 기반으로 적절한 맥락을 이해하도록 도와줍니다.
#   - 파인 튜닝은 LLM Optimization에 초점을 맞추어, 모델이 주어진 작업에 대해 최적화된 성능을 발휘할 수 있도록 합니다.
# - 이 과정들이 결합되어 OpenAI API를 활용한 모델이 다양한 응용 분야에서 최대의 성능을 발휘할 수 있게 합니다. 최종적으로, 이러한 최적화 방법들은 모델이 더 일관되고 신뢰할 수 있는 결과를 생성할 수 있도록 지원합니다.

# %%
# %pip install -q openai
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 361.3/361.3 kB 7.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 4.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 4.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.9/318.9 kB 17.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 3.3 MB/s eta 0:00:00

# %% [markdown]
# [GPT-4o-mini Model Information](https://openai.com/index/gpt-4o-mini-advancing-cost-efficient-intelligence/)
#
# | MODEL                   | DESCRIPTION                                                                                                      | CONTEXT WINDOW | MAX OUTPUT TOKENS | TRAINING DATA  |
# |-------------------------|------------------------------------------------------------------------------------------------------------------|----------------|-------------------|----------------|
# | gpt-4o-mini             | **New GPT-4o-mini** <br> Our affordable and intelligent small model for fast, lightweight tasks. <br> GPT-4o mini is cheaper and more capable than GPT-3.5 Turbo. <br> Currently points to gpt-4o-mini-2024-07-18. | 128,000 tokens | 16,384 tokens     | Up to Oct 2023 |
# | gpt-4o-mini-2024-07-18  | gpt-4o-mini currently points to this version.                                                                    | 128,000 tokens | 16,384 tokens     | Up to Oct 2023 |

# %%
from openai import OpenAI
client = OpenAI(api_key="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")

completion = client.chat.completions.create(
  model="gpt-4o-mini-2024-07-18",
  messages=[
    {"role": "system", "content": "당신은 AI 모델 개발자이다"},
    {"role": "user", "content": "LLM에 대해 설명해줘"}
  ]
)

print(completion.choices[0].message.content)
# Out:
# LLM은 "대규모 언어 모델"(Large Language Model)의 약자로, 자연어 처리(NLP) 분야에서 사용되는 기계 학습 모델입니다. LLM은 대량의 텍스트 데이터를 기반으로 학습하여, 언어를 이해하고 생성하는 능력을 갖추고 있습니다. 이 모델은 주로 인공지능 시스템에 자연어 이해, 생성, 번역, 요약, 질문 답변 등의 기능을 제공하는 데 사용됩니다.
#
# ### 주요 특징
#
# 1. **규모**: LLM은 수십억 개의 매개변수를 가지고 있으며, 이는 모델의 복잡성과 표현력을 의미합니다. 더 많은 매개변수를 가진 모델은 일반적으로 더 높은 성능을 나타냅니다.
#
# 2. **사전 훈련 및 미세 조정**: LLM은 보통 두 단계로 훈련됩니다. 첫 번째는 대규모 데이터셋을 사용하여 사전 훈련된 후, 특정 작업에 맞게 미세 조정하는 단계입니다.
#
# 3. **텍스트 생성**: LLM은 주어진 프롬프트(입력 문장)에 따라 자연스럽고 일관된 텍스트를 생성할 수 있습니다.
#
# 4. **컨텍스트 이해**: LLM은 전후 문맥을 고려하여 의미를 파악하고, 관련된 정보를 제공하는 것이 가능합니다.
#
# 5. **다양한 적용 분야**: LLM은 챗봇, 자동 번역기, 글쓰기 도우미, 질의응답 시스템 등 다양한 분야에서 활용될 수 있습니다.
#
# ### 예시 모델
# - OpenAI의 GPT-3 및 그 후속 모델들이 유명한 LLM의 예입니다.
# - Google's BERT는 다른 형태의 언어 모델로, 주로 마스크된 언어 모델링에 중점을 둡니다.
#
# ### 한계
# - **편향과 윤리적 문제**: LLM은 학습한 데이터에 포함된 편향을 반영할 수 있으며, 이로 인해 윤리적 문제를 발생시킬 수 있습니다.
# - **정보의 정확성**: LLM이 제공하는 정보는 항상 정확하지 않을 수 있으며, 가짜 정보나 허위 사실을 생성할 위험이 있습니다.
#
# LLM은 언어 처리의 혁신을 가져왔지만, 그 사용에서 발생할 수 있는 사회적 책임과 윤리적 이슈에 대한 고민도 필요합니다.

# %% [markdown]
# ## Chat Completion의 API 파라미터의 효과

# %% [markdown]
# - max_tokens적용
#   - 효과: 응답의 길이를 조절

# %%
from openai import OpenAI
client = OpenAI(api_key="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")

completion = client.chat.completions.create(
  model="gpt-4o-mini-2024-07-18",
  messages=[
    {"role": "system", "content": "You are a helpful assistant"},
    {"role": "user", "content": "What are the benefits of reqular exersise?"}
  ],
  max_tokens=100
)

print(completion.choices[0].message.content)
# Out:
# Regular exercise offers a wide range of benefits for both physical and mental health. Here are some of the key advantages:
#
# ### Physical Benefits:
# 1. **Improved Cardiovascular Health**: Regular exercise strengthens the heart, improves circulation, and reduces the risk of heart disease.
# 2. **Weight Management**: Exercise helps regulate weight by burning calories and increasing metabolism.
# 3. **Stronger Muscles and Bones**: Weight-bearing activities help build and maintain muscle mass and bone density, reducing the risk of

# %% [markdown]
# - temperature 적용
#   - 응답의 창의성 조절
#   - 창의적이거나 무작위적인지를 조절: 0에 가까울수록 모델은 더 결정적이고 예측 가능한 출력, 1에 가까울수록 더 무작위적이고 다양한 응답을 생성

# %%
from openai import OpenAI
client = OpenAI(api_key="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")

completion = client.chat.completions.create(
  model="gpt-4o-mini-2024-07-18",
  messages=[
    {"role": "system", "content": "당신은 매우 논리적이고 정확한 어시시턴트입니다."},
    {"role": "user", "content": "여행을 준비할 때 필요한 필수항목은 무엇인가요"}
  ],
  temperature=1,
  max_tokens=200
)

print(completion.choices[0].message.content)
# Out:
# 여행을 준비할 때 필요한 필수 항목은 다음과 같습니다:
#
# 1. **여권**: 해외 여행 시 필수.
# 2. **비자**: 목적지에 따라 필요할 수 있으므로 미리 확인.
# 3. **항공권**: 예약한 항공편의 확인서.
# 4. **숙박 예약 확인서**: 호텔 또는 숙소 예약 증명서.
# 5. **여행 보험**: 사고나 질병에 대비한 보험 가입 확인서.
# 6. **금융 수단**: 현금, 신용카드 또는 여행자 수표 등.
# 7. **의류**: 목적지의 날씨에 맞는 적절한 옷.
# 8. **세면도구**: 개인 용품 및 위생 용품.
# 9. **전자기기**: 스마트폰, 카메라 등과 충전기.
# 10. **약품**: 개인적으로 필요한 약과 기본

# %% [markdown]
# - Top P(또는 nucleus sampling)
#   - Top P의 값을 0.9로 설정하면, 모델은 누적 확률이 90%에 도달할 때까지 가장 높은 확률의 토큰들을 선택하고, 나머지 토큰들은 무시하게 됩니다.
#   - top_p=1이면, 모델은 확률이 가장 높은 단어들을 모두 고려하여 응답을 생성, top_p 값이 낮아지면, 모델은 더 적은 수의 단어들만 고려하게 되어 응답이 더 집중되지만 덜 창의적

# %%
from openai import OpenAI
client = OpenAI(api_key="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")

completion = client.chat.completions.create(
  model="gpt-4o-mini-2024-07-18",
  messages=[
    {"role": "system", "content": "당신은 매우 논리적이고 정확한 어시시턴트입니다."},
    {"role": "user", "content": "여행을 준비할 때 필요한 필수항목은 무엇인가요"}
  ],
  top_p=0.9,
  max_tokens=200
)

print(completion.choices[0].message.content)
# Out:
# 여행을 준비할 때 필요한 필수 항목은 다음과 같습니다:
#
# 1. **여권 및 비자**: 해외 여행 시 유효한 여권과 필요한 경우 비자를 준비해야 합니다.
#
# 2. **항공권 및 예약 확인서**: 항공권을 확인할 수 있는 서류와 호텔 또는 숙소 예약 확인서를 챙겨야 합니다.
#
# 3. **여행자 보험**: 여행 중 발생할 수 있는 사고나 질병에 대비해 여행자 보험에 가입하는 것이 좋습니다.
#
# 4. **경비 및 결제 수단**: 여행 중 사용할 현금, 신용카드, 체크카드 등을 준비하고, 해당 국가의 화폐를 준비해야 합니다.
#
# 5. **의류 및 개인 용품**: 여행 기간과 기후에 맞는 의류, 세면도구, 개인 위생 용품 등을 준비합니다.
#
# 6. **전자기기 및 충전기**: 스마트

# %% [markdown]
# **Temperature와 Top P를 같이 사용**
# - 응답의 다양성과 일관성 사이에서 균형을 맞출 수 있습니다.
#
#
# #### 1. **높은 Temperature (1.0 이상) + 높은 Top-p (0.9~1.0)**
#    - **특징**:
#      - 생성된 텍스트가 매우 창의적이고 다양하며, 예측하기 어려운 결과가 나올 수 있습니다.
#      - 확률이 낮은 단어들도 자주 선택되기 때문에, 결과가 독특하거나 비논리적일 수 있습니다.
#    - **사용 사례**:
#      - 창의적인 글쓰기, 스토리텔링, 아이디어 브레인스토밍 등에서 예상치 못한 결과를 원할 때.
#      - 실험적인 콘텐츠 생성.
#
# #### 2. **높은 Temperature (1.0 이상) + 낮은 Top-p (0.3~0.7)**
#    - **특징**:
#      - 매우 창의적이지만, 텍스트가 때때로 비논리적이거나 일관성이 떨어질 수 있습니다.
#      - 제한된 단어 집합에서 불확실한 선택이 이루어져 결과가 예상치 못한 방향으로 갈 수 있습니다.
#    - **사용 사례**:
#      - 독특하고 실험적인 텍스트 생성.
#      - 예술적인 표현이나 새로운 아이디어를 탐색할 때.
#
# #### 3. **낮은 Temperature (0.2\~0.5) + 높은 Top-p (0.9~1.0)**
#    - **특징**:
#      - 일관되고 예측 가능한 텍스트를 생성하며, 안정적이고 논리적인 결과를 제공합니다.
#      - 다양한 단어를 고려하면서도, 확률이 높은 단어를 중심으로 선택합니다.
#    - **사용 사례**:
#      - 정보 전달, 기술 문서 작성, 공식적인 답변 등에서 일관된 결과가 필요할 때.
#      - 실용적인 응용 프로그램에서의 안정적 출력.
#
# #### 4. **낮은 Temperature (0.2\~0.5) + 낮은 Top-p (0.3~0.7)**
#    - **특징**:
#      - 매우 보수적이고 제한적인 텍스트 생성. 확률이 높은 단어들만 선택되어 결과가 단조롭고 반복적일 수 있습니다.
#      - 텍스트의 창의성이 제한되며, 매우 일관된 결과가 나옵니다.
#    - **사용 사례**:
#      - 매우 안정적이고 보수적인 텍스트 생성이 필요할 때.
#      - 규칙이 명확히 정의된 상황에서의 응답 (예: 특정한 포맷의 문장 생성, 공식 문서 작성).

# %% [markdown]
# Task2_0813. Temperature 와 Top-P의 조합으로 4가지 사례를 작성하고 결과에 대해 의미를 확인하세요.

# %%
from openai import OpenAI
client = OpenAI(api_key="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")

completion = client.chat.completions.create(
  model="gpt-4o-mini-2024-07-18",
  messages=[
    {"role": "system", "content": "당신은 매우 논리적이고 정확한 어시시턴트입니다."},
    {"role": "user", "content": "생산성을 높일 수 있는 방안에 대해 알려주세요"}
  ],
  top_p=1,
  temperature=1
)

print(completion.choices[0].message.content)
# Out:
# 생산성을 높이기 위한 여러 가지 방안이 있습니다. 아래에 몇 가지 주요 방법을 제시합니다:
#
# 1. **목표 설정**: SMART(구체적, 측정 가능, 달성 가능, 관련성, 시간 제한) 원칙에 따라 목표를 설정하여 구체적인 방향성을 제공합니다.
#
# 2. **우선순위 정하기**: 중요한 작업을 우선적으로 처리하기 위해 아이젠하워 매트릭스를 사용하여 긴급성과 중요성을 기준으로 작업을 분류합니다.
#
# 3. **시간 관리**: Pomodoro 기법과 같은 시간 관리 기법을 활용하여 집중력을 높이고, 일정한 작업 후 간단한 휴식을 통해 재충전할 수 있습니다.
#
# 4. **기술 활용**: 생산성 향상 도구(예: Trello, Asana, Notion 등)를 사용하여 작업을 관리하고 팀원과의 협업을 원활하게 합니다.
#
# 5. **일의 환경 개선**: 근무 환경을 정리하고, 편안하고 집중할 수 있는 공간을 마련하여 생산성 향상에 기여합니다.
#
# 6. **정기적인 휴식**: 지속적인 작업은 피로를 유발할 수 있으므로 정기적으로 짧은 휴식을 취해 재충전합니다.
#
# 7. **학습과 자기 개선**: 새로운 기술이나 지식을 지속적으로 습득하여 업무의 효율성을 높입니다.
#
# 8. **원활한 커뮤니케이션**: 팀 내의 소통을 강화하여 정보의 흐름을 원활히 하고, 불필요한 오해를 방지합니다.
#
# 9. **최소한의 멀티태스킹**: 여러 작업을 같은 시간에 처리하기보다는 한 가지 작업에 집중하여 질과 속도를 높입니다.
#
# 10. **피드백 수집**: 정기적으로 동료나 상사로부터 피드백을 받아 개선할 점을 찾고, 성과를 반영하여 활동을 조정합니다.
#
# 이 방법들을 상황에 맞게 적절히 조합하고 활용하면 생산성을 크게 향상시킬 수 있습니다.

# %%
from openai import OpenAI
client = OpenAI(api_key="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")

completion = client.chat.completions.create(
  model="gpt-4o-mini-2024-07-18",
  messages=[
    {"role": "system", "content": "당신은 생산관리 전문가이다."},
    {"role": "user", "content": "생산성을 높일 수 있는 방안에 대해 알려주세요"}
  ],
  top_p=0.1,
  temperature=0.1
)

print(completion.choices[0].message.content)
# Out:
# 생산성을 높이기 위한 방안은 여러 가지가 있으며, 기업의 특성과 산업에 따라 다르게 적용될 수 있습니다. 다음은 일반적으로 효과적인 생산성 향상 방안입니다:
#
# 1. **자동화 및 기술 도입**: 최신 기술과 자동화 시스템을 도입하여 생산 과정을 효율화합니다. 로봇 공학, 인공지능, IoT(사물인터넷) 등을 활용하여 작업의 정확성과 속도를 높일 수 있습니다.
#
# 2. **프로세스 개선**: Lean 생산 방식이나 Six Sigma와 같은 방법론을 통해 불필요한 낭비를 줄이고, 프로세스를 최적화합니다. 이를 통해 생산 시간을 단축하고 품질을 향상시킬 수 있습니다.
#
# 3. **직원 교육 및 훈련**: 직원들이 최신 기술과 프로세스에 대해 잘 이해하고 활용할 수 있도록 정기적인 교육과 훈련을 제공합니다. 숙련된 인력은 생산성을 높이는 데 중요한 역할을 합니다.
#
# 4. **작업 환경 개선**: 안전하고 쾌적한 작업 환경을 조성하여 직원들의 집중력과 동기를 높입니다. 적절한 조명, 통풍, 작업 공간 배치 등이 중요합니다.
#
# 5. **효율적인 자원 관리**: 원자재, 인력, 기계 등의 자원을 효율적으로 관리하여 낭비를 줄이고 생산성을 높입니다. 재고 관리 시스템을 도입하여 적시 생산(JIT)을 실현할 수 있습니다.
#
# 6. **팀워크 및 커뮤니케이션 강화**: 부서 간의 원활한 커뮤니케이션과 협업을 통해 문제를 신속하게 해결하고, 생산 과정에서의 시너지를 창출합니다.
#
# 7. **성과 측정 및 피드백**: 생산성과 관련된 지표를 설정하고 정기적으로 성과를 측정하여 개선점을 찾아냅니다. 피드백을 통해 지속적으로 프로세스를 개선할 수 있습니다.
#
# 8. **유연한 생산 시스템**: 시장의 변화에 빠르게 대응할 수 있는 유연한 생산 시스템을 구축하여 고객의 요구에 맞춘 생산이 가능하도록 합니다.
#
# 이러한 방안들을 종합적으로 고려하고, 기업의 상황에 맞게 적절히 조정하여 실행하는 것이 중요합니다.

# %% [markdown]
# - n 적용
#   - 효과: 여러 응답 생성

# %%
from openai import OpenAI
client = OpenAI(api_key="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")

completion = client.chat.completions.create(
  model="gpt-4o-mini-2024-07-18",
  messages=[
    {"role": "system", "content": "당신은 생산관리 전문가이다"},
    {"role": "user", "content": "생산성을 높이는 팁을 알려주세요"}
  ],
  n=3
)

for i , choice in enumerate(completion.choices):
  print(f"Choice {i+1}:")
  print(choice.message.content)
#print(completion.choices[0].message.content)
# Out:
# Choice 1:
# 생산성을 높이는 데 도움이 되는 몇 가지 팁을 소개합니다:
#
# 1. **목표 설정**: 명확하고 구체적인 목표를 설정하세요. SMART(구체적, 측정 가능, 달성 가능, 관련성, 시간 제한) 기준을 따르는 것이 좋습니다.
#
# 2. **우선순위 정하기**: 업무를 중요도와 긴급도로 분류하여 우선순위를 매기세요. 중요한 일에 집중할 수 있도록 도와줍니다.
#
# 3. **작업 환경 최적화**: 정돈된 작업 환경을 유지하고, 필요한 도구와 자료를 쉽게 접근할 수 있는 곳에 배치하여 비효율성을 줄이세요.
#
# 4. **자동화 도구 활용**: 반복적인 작업은 자동화 도구나 소프트웨어를 활용해 효율성을 높이세요. 예를 들어, 프로젝트 관리 도구나 데이터 분석 소프트웨어를 사용할 수 있습니다.
#
# 5. **팀워크 증진**: 팀원들과의 커뮤니케이션을 강화하고, 협업 툴을 사용하여 정보 공유와 피드백을 원활하게 만들어 생산성을 향상시킵니다.
#
# 6. **정기적 리뷰 및 피드백**: 정기적으로 진행 상황을 점검하고, 필요한 경우 조정하세요. 팀원들에게 피드백을 제공하고, 개선점에 대해 논의하세요.
#
# 7. **스트레스 관리**: 휴식을 취하고 스트레스를 관리하는 것이 중요합니다. 정기적으로 짧은 휴식을 취하거나, 운동, 명상 등을 통해 집중력을 유지하세요.
#
# 8. **지속적 교육**: 직원들에게 새로운 기술이나 지식을 가르치는 교육 프로그램을 제공하여 역량을 강화하고, 변화에 적응할 수 있도록 합니다.
#
# 9. **원가 절감 및 자원 관리**: 자원을 효율적으로 관리하고, 낭비를 줄여 생산성을 높이는 방법도 중요합니다.
#
# 10. **적시 생산(Just In Time)**: 재고를 최소화하면서 필요한 자재를 적시에 공급받아 운영 효율성을 높이는 방법입니다.
#
# 이러한 방법들을 통해 생산성을 높이고 업무의 효율성을 개선할 수 있습니다.
# Choice 2:
# 생산성을 높이는 데 도움이 되는 여러 가지 팁이 있습니다. 다음은 주의 깊게 고려할 수 있는 몇 가지 방법입니다:
#
# 1. **목표 설정**: 명확하고 측정 가능한 목표를 설정하세요. 목표는 팀과 개인의 동기를 부여하고 집중력을 유지하는 데 도움이 됩니다.
#
# 2. **업무 우선순위 정하기**: 중요도와 긴급성을 기준으로 업무를 우선순위에 따라 정리하세요. 이를 통해 가장 중요한 작업에 집중할 수 있습니다.
#
# 3. **시간 관리**: 일정 관리 도구나 기술을 사용하여 시간을 효율적으로 관리하세요. Pomodoro 기법과 같은 기술을 통해 시간 블록을 설정하고 집중할 수 있습니다.
#
# 4. **자동화 도구 활용**: 반복적인 작업은 자동화 도구를 사용하여 효율성을 높이세요. 소프트웨어나 기술을 활용하면 시간과 인력을 절약할 수 있습니다.
#
# 5. **팀워크 강화**: 팀원 간의 의사소통과 협력을 강화하세요. 정기적인 회의와 피드백을 통해 팀워크를 개선하고 문제를 조기에 식별할 수 있습니다.
#
# 6. **교육 및 훈련**: 팀원의 기술과 지식을 향상시키기 위한 교육과 훈련을 제공하세요. 이는 작업의 품질을 높이고 오류를 줄이는 데 도움이 됩니다.
#
# 7. **자원 최적화**: 필요한 자원(인력, 장비, 자재 등)을 효율적으로 관리하고 활용하세요. 자원의 낭비를 줄이는 것이 중요합니다.
#
# 8. **개선 피드백 수렴**: 직원들의 피드백을 통해 업무 프로세스를 개선할 수 있는 기회를 찾으세요. 현장의 의견은 매우 중요합니다.
#
# 9. **건강한 작업 환경 조성**: 동기 부여와 생산성을 높일 수 있는 긍정적이고 안전한 작업 환경을 조성하세요. 직원의 웰빙이 생산성에 큰 영향을 미칠 수 있습니다.
#
# 10. **업무 흐름 분석**: 생산 공정이나 업무 흐름을 정기적으로 분석하여 비효율적인 부분을 개선하세요. Lean 생산 방식이나 Six Sigma와 같은 기법을 활용할 수 있습니다.
#
# 이러한 전략을 통해 생산성을 높일 수 있으며, 각 조직의 특성과 환경에 맞게 조정하여 적용하는 것이 중요합니다.
# Choice 3:
# 생산성을 높이는 방법은 여러 가지가 있습니다. 아래에 몇 가지 팁을 소개합니다:
#
# 1. **목표 설정**: 명확하고 측정 가능한 목표를 설정하세요. 단기 및 장기 목표를 설정하고 이를 주기적으로 검토해 진척 상황을 확인합니다.
#
# 2. **우선순위 정하기**: 작업의 중요도에 따라 우선순위를 정하세요. 에이젠 활동인 매트릭스(긴급성-중요성 매트릭스)를 활용하여 어떤 일을 먼저 처리할지 결정할 수 있습니다.
#
# 3. **효율적인 작업 환경 조성**: 작업 공간이 깔끔하고 정돈되어 있으면 집중력을 높일 수 있습니다. 필요 없는 물건을 치우고, 자주 사용하는 도구를 쉽게 접근할 수 있는 곳에 두세요.
#
# 4. **소통 강화**: 팀원들과의 원활한 소통은 작업 진행 상황을 빠르게 파악하고 문제를 조기에 해결하는 데 도움이 됩니다. 정기적인 회의를 통해 정보 공유를 하세요.
#
# 5. **자동화 도입**: 반복적인 작업은 자동화를 통해 처리할 수 있습니다. 소프트웨어 도구나 기계를 사용하여 수작업을 줄이는 것이 좋습니다.
#
# 6. **시간 관리**: Pomodoro 기법(25분 작업 후 5분 휴식)과 같은 시간 관리 기법을 이용해 집중력을 유지하세요. 자신에게 맞는 방식으로 시간을 관리하세요.
#
# 7. **계속 배우기**: 산업 동향이나 새로운 기술에 대해 지속적으로 학습하세요. 교육과 훈련을 통해 자신의 스킬을 향상시키면 작업 효율이 높아집니다.
#
# 8. **유연한 작업 프로세스**: 작업 프로세스를 주기적으로 검토하여 비효율적인 단계를 제거하고 개선할 수 있는 부분을 찾습니다.
#
# 9. **직원 참여 유도**: 팀원들이 업무에 대한 주인의식을 갖게 하여 자율적으로 문제를 해결할 수 있도록 격려합니다.
#
# 10. **취업 체계 마련**: 직원들이 적절한 워크라이프밸런스를 유지할 수 있도록 지원합니다. 스트레스 관리와 건강한 근무 환경이 생산성에 긍정적인 영향을 미칠 수 있습니다.
#
# 이러한 팁을 통해 생산성을 높이고 팀과 개인의 성과를 극대화할 수 있을 것입니다.

# %% [markdown]
# - stop 적용
#   - 효과: 특정 단어에서 응답 멈추기

# %%
from openai import OpenAI
client = OpenAI(api_key="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")

completion = client.chat.completions.create(
  model="gpt-4o-mini-2024-07-18",
  messages=[
    {"role": "system", "content": "당신은 커피 전문가입니다."},
    {"role": "user", "content": "커피 한 잔을 만드는 과정을 설명해주세요"}
  ],
  stop=["\n"]
)

print(completion.choices[0].message.content)
# Out:
# 커피 한 잔을 만드는 과정은 여러 단계로 이루어져 있습니다. 아래에 그 과정을 간단하게 설명하겠습니다:

# %% [markdown]
# - 이미지 input

# %%
from openai import OpenAI
client = OpenAI(api_key="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")

completion = client.chat.completions.create(
  model="gpt-4o-mini-2024-07-18",
  messages=[
    {"role": "system", "content": "당신은 감성이 풍부한 화가이다."},
    {"role": "user", "content": "이미지에 보이는 풍경을 말해줘"},
    {"role": "user", "content": "https://upload.wikimedia.org/wikipedia/commons/thumb/d/dd/Gfp-wisconsin-madison-the-nature-boardwalk.jpg/2560px-Gfp-wisconsin-madison-the-nature-boardwalk.jpg"}
  ],
  max_tokens=200
)

print(completion.choices[0].message.content)
# Out:
# 그 이미지는 위스콘신 주 매디슨에 있는 자연 산책로의 풍경을 담고 있습니다. 고요한 호수의 물결이 잔잔하게 일렁이고, 주변에는 푸른 나무들과 다양한 식물들이 조화를 이루고 있습니다. 나무 데크가 자연과 가까운 곳에 위치해 있어, 방문객들이 자연을 만끽하며 산책할 수 있는 멋진 공간입니다.
#
# 햇빛이 나뭇잎 사이로 비추며 따뜻한 느낌을 주고, 잔잔한 풍경이 마음을 평화롭게 해줍니다. 이곳은 자연의 아름다움을 느끼며 일상의 스트레스를 잊을 수 있는 안식처 같습니다. 자연의 소리와 함께 바라보는 이 풍경은 생명과 조화로움이 가득한 장소인 듯 보입니다.

# %% [markdown]
# - Streaming
#   - 스트리밍을 통해 모델의 응답이 점진적으로 생성되고 있음을 보여줍니다.스트리밍 모드는 모델이 긴 응답을 한번에 생성하지 않고,
